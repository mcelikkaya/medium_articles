# %%
#Self-attention in Transformer 
#In this notebook, I tried various visualizations

# %%
import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import spacy
import numpy as np
import matplotlib

import random
import math
import time
import random
from yellowbrick.text import TSNEVisualizer
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# %%
#these are initial parameters you can change but, u have to play with configurations
#so best is keeping these simple,and testing as is
HID_DIM = 64
ENC_LAYERS = 1
DEC_LAYERS = 1
ENC_HEADS = 1
DEC_HEADS = 1
ENC_PF_DIM = 128
DEC_PF_DIM = 128
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1

def get_head_count():
    return ENC_HEADS

def get_row_count():
    return 1

def get_col_count():
    return 1

# %%
#utility class to log all intermediate steps
#here saving all tensors send to add_info
#then we can query these tensors. When we want to have a seperate logger, create new instance.

class StepLogger():
    def __init__(self,capacity):
        self.tensor_datas = {}        
        self.capacity = capacity
        self.added_labels = []
        
    
    def add_info(self,tensor_data,tensor_label):
        if tensor_label not in self.added_labels:
            self.added_labels.append( tensor_label )
        
        if tensor_label in self.tensor_datas.keys():
            current_arr = self.tensor_datas.get(tensor_label)
            if len(current_arr) < self.capacity:
                current_arr = self.tensor_datas.get(tensor_label, [])
                current_arr.append(tensor_data)
        else:
            self.tensor_datas[tensor_label] = [tensor_data]
    
    def get_default_summary(self,show_data=False,summary_count=1):
        self.get_summary(self.added_labels,show_data,show_info=True,summary_count=summary_count)
        
    def get_summary(self,labels,show_data=False,show_info=False,summary_count=1):
        if show_info:
            print("summary_count",summary_count,"   self.capacity ",self.capacity)
        count = 0
        values = []
        for i in range(summary_count):
            #print(i," ------------------------------------------------")
            for l in labels:
                if i < len(self.tensor_datas.get(l)):
                    label_data = self.tensor_datas.get(l)[i]
                    values.append(label_data)
                    if show_info:
                        print(l)
                    if torch.is_tensor(label_data):
                        if show_info:
                            print( list(label_data.size() ) )
                    if not show_data and not torch.is_tensor(label_data):
                        if show_info:
                            print(label_data)
                    if show_data:    
                        print(label_data)
        return values              
                    
loggers = {}                    
current_logger = StepLogger(100)   
def add_new_logger(logger_label):
    global current_logger
    if logger_label in loggers.keys() :
        print("using existing logger")
        current_logger = loggers[logger_label]
    else:    
        loggers[logger_label]  = StepLogger(50)
        current_logger = loggers[logger_label]
    

def add_infos(datas,labels,labels_prefix=""):
    #print( id(current_logger))
    for i in range(len(datas)):
        final_label = labels_prefix+"@"+labels[i]
        current_logger.add_info(datas[i],final_label.strip())
    
#add_info   tensor_data,tensor_label                  currentLogger.get_default_summary(show_data=False)

data_pipeline = []
pipeline_enabled = True
#do no want to log during eval mode
def disable_pipeline():
    global pipeline_enabled
    pipeline_enabled = False

def enable_pipeline():
    global pipeline_enabled
    pipeline_enabled = True

#sometimes i want to log some values selectively by enable/disable
#u can check how do i do use this at code, my intention is to collect
#some intermediate values
def add_pipeline_info(label,data):
    if pipeline_enabled:
        data_pipeline.append( (label,data) )

# %%
#my dummy variables for enabling/disabling some parts of network
APPLY_EVERYTHING = 1
APPLY_ONLY_TARGET_WITHOUT_SCALE = 2
APPLY_ONLY_TARGET_EMBEDDING = 3
APPLY_ONLY_SOURCE_EMBEDDING = 4
APPLY_ONLY_POS_EMBEDDING = 5
APPLY_ONLY_TARGET_WITH_SCALE = 6
#7 missing :) 9 also missing
APPLY_NOT_ATTENTION = 8

APPLY_NOT_DECODER_SELFATTENTION = 10
APPLY_ONLY_NORM_DECODER_SELFATTENTION = 11
APPLY_ONLY_DECODER_SELFATTENTION = 12
APPLY_ONLY_DROPOUT_DECODER_SELFATTENTION = 13
APPLY_NOT_POSITIONWISE = 14


#---------- Attention Types
#according to these values i create attention vectors and change the 
#work flow of network
ATTENTION_DEFAULT = 1
ATTENTION_EQUAL_DISTRIBUTED = 2
ATTENTION_AT_BEGINNING = 3
ATTENTION_AT_END = 4

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
def tokenize(text):
    return [tok for tok in text.split(" ")]

SRC = Field(tokenize = tokenize, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

TRG = Field(tokenize = tokenize, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

# %%
#read csv file
tabular_set = torchtext.data.TabularDataset(
path='D:/nnmedium/eng_de.csv', format='csv',
fields=[('src', SRC),('trg', TRG)])

# %%
#dump a sample
print(tabular_set[0].src)
print(tabular_set[0].trg)
# Out:
# ['i', 'want', 'to', 'eat', 'bread']
# ['ich', 'mochten', 'brot', 'essen']

# %%
train_data, valid_data, test_data = tabular_set ,tabular_set, tabular_set

# %%
#all of our vocublary is used at least 2 times,  check the csv file
SRC.build_vocab(train_data, min_freq = 2)
TRG.build_vocab(train_data, min_freq = 2)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
#our tranining size is so small so batch size will also be small
BATCH_SIZE = 8

# %%
#create an iterator
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
     batch_size = BATCH_SIZE,
     sort_key = lambda x:  len(x.src),
     device = device)

# %%
class Encoder(nn.Module):
    def __init__(self, 
                 input_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim,
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()

        self.device = device
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([EncoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim,
                                                  dropout, 
                                                  device) 
                                     for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
    
    
    def forward(self, src, src_mask,attention_type):
    
        add_infos([src],["src_source"],"Encoder") #log vectors
        add_pipeline_info(label="Encoder->attention",data=src) #log vectors
        
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
                
        src_embedding = self.tok_embedding(src) 
        add_infos([src,pos,src_embedding],["src","pos","src_embedding"],"Encoder")   
        src = self.dropout((src_embedding * self.scale) + self.pos_embedding(pos))                
        
        for layer in self.layers:
            src = layer(src, src_mask,attention_type)
            
        #log vectors
        add_infos([src],["src_final"],"Encoder")            
            
        return src

# %%
class EncoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim,  
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"encoder")
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_mask,attention_type):
                        
           
        #self attention
        _src, sattention = self.self_attention(src, src, src,attention_type, src_mask) #return x, attention
        
        #dropout, residual connection and layer norm
        src2 = self.self_attn_layer_norm(src + self.dropout(_src))
        
        ###At the end attention is learning a new representation for a sentence,here _src is a helper representation
        add_pipeline_info(label="EncoderSSS"+"@SSS",data=[src,_src,src2])  
                        
        #positionwise feedforward
        _src2 = self.positionwise_feedforward(src2)
        
        #dropout, residual and layer norm
        src3 = self.ff_layer_norm(src + self.dropout(_src2))
        
        add_infos([_src,src2,_src2,src3,src_mask,sattention],["_src","src2","_src2","src3","src_mask","sattention"],"EncoderLayer")        
        
        return src3

# %%
class MultiHeadAttentionLayer(nn.Module):
    #since this layer is common while logging there must be a label to differantiate labels
    def __init__(self, hid_dim, n_heads, dropout, device,layer_label):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        #!!! head_dim is encoding per head so ,hid_dim must divide n_heads
        self.head_dim = hid_dim // n_heads
        self.layer_label = layer_label
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        add_infos([self.hid_dim,self.n_heads,self.head_dim],["hid_dim","n_heads","head_dim"],self.layer_label)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value,attention_type, mask = None):
        
        batch_size = query.shape[0]
                        
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)        
                
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)        
        
        add_infos([Q,K,V],["Q","K","V"],self.layer_label)
                        
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale               
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
                            
        attention = torch.softmax(energy, dim = -1)                
        
        ### attention is a weight over dimensions
        if attention_type == ATTENTION_EQUAL_DISTRIBUTED: #normally distributed literally means no attention            
            attention = torch.tensor(np.full(attention.shape, 1/attention.shape[3]),dtype=torch.float32 )
        #just pay attention to beginning
        if attention_type == ATTENTION_AT_BEGINNING:           
            if attention.shape[3] > 2: 
                real_shape = attention.shape
                att1 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], 3), 1/3) ,dtype=torch.float32 )
                att2 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], real_shape[3] - 3), 1/7) ,dtype=torch.float32 )
                att3 = torch.cat( (att1,att2),3 )
                attention = torch.softmax(att3, dim = -1)
        #just pay attention to end         
        if attention_type == ATTENTION_AT_END :           
            if attention.shape[3] > 2: 
                real_shape = attention.shape                
                att1 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], real_shape[3] - 1), 0) ,dtype=torch.float32 )
                att2 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], 1), 1) ,dtype=torch.float32 )
                att3 = torch.cat( (att1,att2),3 )
                attention = torch.softmax(att3, dim = -1)         
            
                
        x1 = torch.matmul(self.dropout(attention), V)        
        add_pipeline_info(label=self.layer_label+"@QKV",data=[Q,K,V,mask,energy,attention,mask,x1])        
        
        x2 = x1.permute(0, 2, 1, 3).contiguous()                
        x3 = x2.view(batch_size, -1, self.hid_dim)                
        x4 = self.fc_o(x3)        
        
        add_infos([energy,mask,attention],["energy","mask","attention"],self.layer_label)
        add_infos([x1,x2,x3,x4],["x1","x2","x3","x4"],self.layer_label)
        
        return x4, attention

# %%
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):                
        x1 = self.dropout(torch.relu(self.fc_1(x)))                
        x2 = self.fc_2(x1)        
        add_infos([x1,x2],["x1","x2"],"PositionwiseFeedforwardLayer")        
        return x2

# %%
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()
        
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask,attention_type=1,flow_type=1):        
       
        add_pipeline_info(label="Decoder_original->trg",data=trg)         
           
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
                            
        trg_embedding   = self.tok_embedding(trg)
        if flow_type == APPLY_EVERYTHING : #apply everything (default)
            trg = self.dropout( (trg_embedding * self.scale) + self.pos_embedding(pos))
        elif flow_type == APPLY_ONLY_TARGET_WITHOUT_SCALE: #apply only target embedding wihtout scale
            trg = self.dropout( trg_embedding )
        elif flow_type == APPLY_ONLY_TARGET_EMBEDDING: #apply without dropout
            trg = trg_embedding
        elif flow_type == APPLY_ONLY_SOURCE_EMBEDDING: #just give encoder embedding,very bad embedding,expect worse!!!
            trg = enc_src    
        elif flow_type == APPLY_ONLY_POS_EMBEDDING: # apply only positional embedding
            trg = self.pos_embedding(pos)        
        elif flow_type == APPLY_ONLY_TARGET_WITH_SCALE: #apply only target embedding with scale
            trg = self.dropout( (trg_embedding * self.scale) )
        else:#put also default to not known type   
            trg = self.dropout( (trg_embedding * self.scale) + self.pos_embedding(pos))
                
        trg_before_attention = trg 
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask,attention_type,flow_type)
        
        if flow_type == APPLY_NOT_ATTENTION : #revert back to vector before attention
            trg = trg_before_attention
            
        
        output = self.fc_out(trg)
        
        add_infos([pos,trg,output,attention,trg_embedding],["pos","trg","output","attention","trg_embedding"],"Decoder")
            
        return output, attention

# %%
class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"decoder_self")
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"decoder_encoder_attention")
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask,attention_type,flow_type):
        
        
        #self attention
        add_pipeline_info(label="Decoder_self->attention",data=trg) 
        if flow_type == APPLY_NOT_DECODER_SELFATTENTION:
            _trg1 = trg
        else:
            _trg1, _ = self.self_attention(trg, trg, trg,attention_type, trg_mask)
        
        #dropout, residual connection and layer norm
        trg2 = self.self_attn_layer_norm(trg + self.dropout(_trg1))
                                    
        #encoder attention
        add_pipeline_info(label="Decoder->encoder_attention",data=trg2) 
        _trg2, attention = self.encoder_attention(trg2, enc_src, enc_src,attention_type, src_mask)
        
        if flow_type == APPLY_ONLY_NORM_DECODER_SELFATTENTION : #only apply decoder self attention with layer
            trg3 = self.enc_attn_layer_norm(trg2 )
        elif flow_type == APPLY_ONLY_DECODER_SELFATTENTION: #only apply decoder self attention
            trg3 = trg2    
        elif flow_type == APPLY_ONLY_DROPOUT_DECODER_SELFATTENTION: # only apply encoder attention
            trg3 = self.dropout(_trg2)        
        else:    
            #dropout, residual connection and layer norm
            trg3 = self.enc_attn_layer_norm(trg2 + self.dropout(_trg2))
                            
        #positionwise feedforward
        if flow_type == APPLY_NOT_POSITIONWISE:
            _trg3 = trg3
        else:    
            _trg3 = self.positionwise_feedforward(trg3)
        
        #dropout, residual and layer norm
        trg4 = self.ff_layer_norm(trg3 + self.dropout(_trg3))
                
        add_infos([_trg1,trg2,_trg2,trg3,_trg3,trg4,attention,trg_mask, src_mask],["_trg1","trg2","_trg2","trg3","_trg3","trg4","attention","trg_mask", "src_mask"],"DecoderLayer")
        
        return trg4, attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, 
                 encoder, 
                 decoder, 
                 src_pad_idx, 
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device
        
    def make_src_mask(self, src):
                
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)

        return src_mask
    
    def make_trg_mask(self, trg):
                
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
                
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device = self.device)).bool()
                    
        trg_mask = trg_pad_mask & trg_sub_mask
                
        return trg_mask

    def forward(self, src, trg,attention_type):        
                
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        
        enc_src = self.encoder(src, src_mask,attention_type)
                        
        output, attention = self.decoder(trg, enc_src, trg_mask, src_mask,attention_type)
        
        add_infos([src_mask,trg_mask,enc_src,output,attention,src,trg],["src_mask","trg_mask","enc_src","output","attention","src","trg"],"Seq2Seq")        
        
        return output, attention

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)


enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT, 
              device)

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)

# %%
SRC_PAD_IDX = SRC.vocab.stoi[SRC.pad_token]
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]

model = Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX, device).to(device)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 99,857 trainable parameters

# %%
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

# %%
#dump model architecture
model.apply(initialize_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (tok_embedding): Embedding(18, 64)
#     (pos_embedding): Embedding(100, 64)
#     (layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=64, out_features=128, bias=True)
#           (fc_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): Decoder(
#     (tok_embedding): Embedding(17, 64)
#     (pos_embedding): Embedding(100, 64)
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=64, out_features=128, bias=True)
#           (fc_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (fc_out): Linear(in_features=64, out_features=17, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
LEARNING_RATE = 0.0005
optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

# %%
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)

# %%
def train(model, iterator, optimizer, criterion, clip,attention_type):
    
    model.train()    
    epoch_loss = 0
    
    
    for i, batch in enumerate(iterator):        
        
        src = batch.src
        trg = batch.trg
        
        optimizer.zero_grad()
        add_pipeline_info(label="train"+"@srctrg",data=[src,trg[:,:-1]]) 
        output, _ = model(src, trg[:,:-1],attention_type)        
            
        output_dim = output.shape[-1]                
            
        output = output.contiguous().view(-1, output_dim)
        trg = trg[:,1:].contiguous().view(-1)
                            
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion,attention_type):
    
    model.eval()    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):
            src = batch.src
            trg = batch.trg
            
            output, _ = model(src, trg[:,:-1],attention_type)            
            output_dim = output.shape[-1]
            
            output = output.contiguous().view(-1, output_dim)
            trg = trg[:,1:].contiguous().view(-1)
            
            loss = criterion(output, trg)
            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import os
import gc
N_EPOCHS = 30
CLIP = 1
best_valid_loss = float('inf')

add_new_logger("training")


model_save_path = "D:/nnmedium/tut6-model_en_de.pt"
model_to_train = model
for epoch in range(N_EPOCHS):
    gc.collect()
    if os.path.isfile(model_save_path) :
        print("loading model",model_save_path)
        #If you want to save the model enable below,do it for big datasets
        #model_to_train.load_state_dict(torch.load(model_save_path))
    
    start_time = time.time()
    
    enable_pipeline()
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP,attention_type=1)
    
    disable_pipeline()
    valid_loss = evaluate(model, valid_iterator, criterion,attention_type=1)    
    
    end_time = time.time()
    
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    
    if valid_loss < best_valid_loss:
        print("saving model",model_save_path," with loss ",valid_loss)
        best_valid_loss = valid_loss
        torch.save(model_to_train.state_dict(), model_save_path)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  2.7126770496368406
# Epoch: 01 | Time: 0m 0s
# 	Train Loss: 3.247 | Train PPL:  25.706
# 	 Val. Loss: 2.713 |  Val. PPL:  15.070
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  2.2611355066299437
# Epoch: 02 | Time: 0m 0s
# 	Train Loss: 2.657 | Train PPL:  14.253
# 	 Val. Loss: 2.261 |  Val. PPL:   9.594
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  1.9791063785552978
# Epoch: 03 | Time: 0m 0s
# 	Train Loss: 2.348 | Train PPL:  10.464
# 	 Val. Loss: 1.979 |  Val. PPL:   7.236
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  1.7458755254745484
# Epoch: 04 | Time: 0m 0s
# 	Train Loss: 2.174 | Train PPL:   8.791
# 	 Val. Loss: 1.746 |  Val. PPL:   5.731
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  1.5395087957382203
# Epoch: 05 | Time: 0m 0s
# 	Train Loss: 1.944 | Train PPL:   6.988
# 	 Val. Loss: 1.540 |  Val. PPL:   4.662
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  1.3546358585357665
# Epoch: 06 | Time: 0m 0s
# 	Train Loss: 1.792 | Train PPL:   6.001
# 	 Val. Loss: 1.355 |  Val. PPL:   3.875
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  1.204009199142456
# Epoch: 07 | Time: 0m 0s
# 	Train Loss: 1.544 | Train PPL:   4.682
# 	 Val. Loss: 1.204 |  Val. PPL:   3.333
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  1.0545082807540893
# Epoch: 08 | Time: 0m 0s
# 	Train Loss: 1.476 | Train PPL:   4.376
# 	 Val. Loss: 1.055 |  Val. PPL:   2.871
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.9105247139930726
# Epoch: 09 | Time: 0m 0s
# 	Train Loss: 1.277 | Train PPL:   3.585
# 	 Val. Loss: 0.911 |  Val. PPL:   2.486
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.7964496970176697
# Epoch: 10 | Time: 0m 0s
# 	Train Loss: 1.221 | Train PPL:   3.390
# 	 Val. Loss: 0.796 |  Val. PPL:   2.218
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.7017689347267151
# Epoch: 11 | Time: 0m 0s
# 	Train Loss: 1.070 | Train PPL:   2.916
# 	 Val. Loss: 0.702 |  Val. PPL:   2.017
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.6082049310207367
# Epoch: 12 | Time: 0m 0s
# 	Train Loss: 0.946 | Train PPL:   2.574
# 	 Val. Loss: 0.608 |  Val. PPL:   1.837
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.5353344321250916
# Epoch: 13 | Time: 0m 0s
# 	Train Loss: 0.866 | Train PPL:   2.377
# 	 Val. Loss: 0.535 |  Val. PPL:   1.708
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.4721280515193939
# Epoch: 14 | Time: 0m 0s
# 	Train Loss: 0.765 | Train PPL:   2.149
# 	 Val. Loss: 0.472 |  Val. PPL:   1.603
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.41139188408851624
# Epoch: 15 | Time: 0m 0s
# 	Train Loss: 0.685 | Train PPL:   1.983
# 	 Val. Loss: 0.411 |  Val. PPL:   1.509
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.3640752375125885
# Epoch: 16 | Time: 0m 0s
# 	Train Loss: 0.662 | Train PPL:   1.938
# 	 Val. Loss: 0.364 |  Val. PPL:   1.439
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.3245373874902725
# Epoch: 17 | Time: 0m 0s
# 	Train Loss: 0.652 | Train PPL:   1.919
# 	 Val. Loss: 0.325 |  Val. PPL:   1.383
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.29142214059829713
# Epoch: 18 | Time: 0m 0s
# 	Train Loss: 0.521 | Train PPL:   1.684
# 	 Val. Loss: 0.291 |  Val. PPL:   1.338
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.2649347633123398
# Epoch: 19 | Time: 0m 0s
# 	Train Loss: 0.519 | Train PPL:   1.681
# 	 Val. Loss: 0.265 |  Val. PPL:   1.303
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.23722401559352874
# Epoch: 20 | Time: 0m 0s
# 	Train Loss: 0.520 | Train PPL:   1.682
# 	 Val. Loss: 0.237 |  Val. PPL:   1.268
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.21323275566101074
# Epoch: 21 | Time: 0m 0s
# 	Train Loss: 0.436 | Train PPL:   1.547
# 	 Val. Loss: 0.213 |  Val. PPL:   1.238
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.1990005999803543
# Epoch: 22 | Time: 0m 0s
# 	Train Loss: 0.421 | Train PPL:   1.523
# 	 Val. Loss: 0.199 |  Val. PPL:   1.220
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.18268104791641235
# Epoch: 23 | Time: 0m 0s
# 	Train Loss: 0.455 | Train PPL:   1.576
# 	 Val. Loss: 0.183 |  Val. PPL:   1.200
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.1647768124938011
# Epoch: 24 | Time: 0m 0s
# 	Train Loss: 0.383 | Train PPL:   1.467
# 	 Val. Loss: 0.165 |  Val. PPL:   1.179
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.15431320816278457
# Epoch: 25 | Time: 0m 0s
# 	Train Loss: 0.361 | Train PPL:   1.434
# 	 Val. Loss: 0.154 |  Val. PPL:   1.167
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.14153423756361008
# Epoch: 26 | Time: 0m 0s
# 	Train Loss: 0.349 | Train PPL:   1.418
# 	 Val. Loss: 0.142 |  Val. PPL:   1.152
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.13207995444536208
# Epoch: 27 | Time: 0m 0s
# 	Train Loss: 0.348 | Train PPL:   1.416
# 	 Val. Loss: 0.132 |  Val. PPL:   1.141
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.12237315624952316
# Epoch: 28 | Time: 0m 0s
# 	Train Loss: 0.335 | Train PPL:   1.398
# 	 Val. Loss: 0.122 |  Val. PPL:   1.130
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.11711241155862809
# Epoch: 29 | Time: 0m 0s
# 	Train Loss: 0.336 | Train PPL:   1.400
# 	 Val. Loss: 0.117 |  Val. PPL:   1.124
# loading model D:/nnmedium/tut6-model_en_de.pt
# saving model D:/nnmedium/tut6-model_en_de.pt  with loss  0.1128562182188034
# Epoch: 30 | Time: 0m 0s
# 	Train Loss: 0.312 | Train PPL:   1.366
# 	 Val. Loss: 0.113 |  Val. PPL:   1.119

# %%
import pandas as pd
import seaborn as sns

#Utility method for translating a sentence and then displaying Attention and Logits
#Logits = the vector of raw (non-normalized) predictions that a classification model generates, 
#which is ordinarily then passed to a normalization function(softmax).
#The softmax function generates a vector of (normalized) probabilities with one value for each possible class.
def translate_info(src,draw_charts,attention_type=1,dump_result=True,flow_type=1):
    
    if isinstance(src,str):
        src = src.split(" ")
    logger_name = "".join(src)+str( random.randint(1,180001) )
    add_new_logger(logger_name)
    if dump_result:
        print(f'source = {src}')

    translation, attention,all_outputs = translate_sentence(src, SRC, TRG, model, device,attention_type=attention_type,flow_type=flow_type)

    if dump_result:
        print(f'predicted target = {translation}')
    output_words = translation
    
    
    indexes = []
    for index_w,w in enumerate(translation):
        if index_w == 0:
            indexes.append("sos->"+w.replace("<","").replace(">",""))
        else:    
            indexes.append(translation[index_w -1 ]+"->"+w.replace("<","").replace(">",""))        
    
    indexes = [ str(i+1)+")"+index for i,index in enumerate(indexes) ]
    #for better display i do not include "unk","pad",    
    all_outputs = np.array(all_outputs)[:,2:]
    df2 = pd.DataFrame(all_outputs,columns=["sos","eos"]+TRG.vocab.itos[4:],index=indexes)
    
    pd.options.display.float_format = '{:,.2f}'.format
    cm = sns.light_palette("blue", as_cmap=True)
    
    df2.style.format("{:.2%}")
    
    df2.style.set_table_attributes("style='display:inline'").set_caption('Logits for translation')
    styled_df = df2.style.background_gradient(cmap=cm).set_precision(2)     
    
    pd.options.display.float_format = '{:,.2f}'.format
    if draw_charts:
        print("Logits")
        display(styled_df)    
        display_attention(src, indexes, attention,n_heads=get_head_count(),n_rows = get_row_count(), n_cols = get_col_count())
    return loggers[logger_name],all_outputs,translation



#show multiple items in 2d with different colors
def show_on_vis_multi(new_input_embeddings,input_sentences,valid_sentences_embeddings,valid_sentences,fig_size=[18,8]):    
    Xs = valid_sentences_embeddings
    Ys = valid_sentences
   
    #I want to mark sentences 
    if len(input_sentences)> 0 :
        input_sentences = [ "<<<"+s+">>>" for s in input_sentences]
        Xs = Xs+ [embed for embed in new_input_embeddings]
        Ys = Ys + input_sentences 
            
    pca = PCA(n_components=2)
    result = pca.fit_transform(np.array(Xs))

    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(fig_size[0], fig_size[1])

    #scatter result words
    plt.scatter(result[:, 0], result[:, 1])
    words = list(Ys)
    #put an annotation on x,y cordinates for words, color according to verb
    for i, word in enumerate(words):
        if word in input_sentences:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00ff')
        elif "eat" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff0000')     
        else:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00dd')
    plt.show()    
    

def get_color(word):
    cmap = plt.get_cmap('viridis')
    distinct_words = SRC.vocab.itos[4:]

    colors = cmap(np.linspace(0, 1, len(distinct_words)))
    color_map = { w:colors[i] for i,w in enumerate(distinct_words) }

    for distinct_word in distinct_words:
        if  word.find(distinct_word) == 0: #if starstwith
            return color_map[distinct_word]
    return color_map[distinct_words[0]]
    
#map the input on a 3d space    
def map_on_3d(data_2d,words,color_mapping:None,exceptional_words=[],use_word_colors=False,fig_size=[19,11]):
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(fig_size[0], fig_size[1])

    ax = plt.axes(projection ="3d")
    #scatter result words
    ax.scatter3D(data_2d[:, 0], data_2d[:, 1], data_2d[:, 2])
            
    #put an annotation on x,y cordinates for words
    for i, word in enumerate(words):
        if color_mapping is not None:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color=color_mapping[i] )
        elif word in exceptional_words:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#0000ff' )
        elif use_word_colors:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color=get_color(word))
        elif "eat" in word:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#0000ff')
        elif "drink" in word:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#00ff00')
        elif "read" in word:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#ff0000')     
        else:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#ff00dd')
    plt.show()
    
#map the input on a 2d space      
def map_on_2d(data_2d,words,color_mapping:None,exceptional_words=[],use_word_colors=False,fig_size=[19,11]):
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(fig_size[0], fig_size[1])

    #scatter result words
    plt.scatter(data_2d[:, 0], data_2d[:, 1])        
    
    #put an annotation on x,y cordinates for words
    for i, word in enumerate(words):
        if color_mapping is not None:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color=color_mapping[i] )
        elif word in exceptional_words:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#0000ff' )
        elif use_word_colors:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color=get_color(word))
        elif "eat" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff0000')     
        else:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff00dd')
    plt.show()      
    
def encoding_to_sentence(encodings,language):
    return [encoding_to_word(i,language) for i in encodings ]   

def encoding_to_word(embedding_index,language):
    return language.vocab.itos[embedding_index]     

#show a dataframe with style
def draw_df(data,columns,indexes):
    df2 = pd.DataFrame(data,columns=columns,index=indexes)
    cm = sns.light_palette("blue", as_cmap=True)
    styled_df = df2.style.background_gradient(cmap=cm).set_precision(2)
    display(styled_df)
    
def translate_sentence(sentence, src_field, trg_field, model, device,attention_type, max_len = 10,flow_type=1):
    
    model.eval()
        
    if isinstance(sentence, str):
        nlp = spacy.load('de')
        tokens = [token.text.lower() for token in nlp(sentence)]
    else:
        tokens = [token.lower() for token in sentence]

    tokens = [src_field.init_token] + tokens + [src_field.eos_token]
        
    src_indexes = [src_field.vocab.stoi[token] for token in tokens]

    src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
    
    src_mask = model.make_src_mask(src_tensor)
    
    #generate all encoder state
    with torch.no_grad():
        enc_src = model.encoder(src_tensor, src_mask,attention_type)

    #add Start of sentence token for target    
    trg_indexes = [trg_field.vocab.stoi[trg_field.init_token]]

    ### hold output of linear layer at everytime step generate 1 output
    all_outputs = []
    for i in range(max_len):
        
        trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)

        trg_mask = model.make_trg_mask(trg_tensor)
        #generate next word
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask,attention_type,flow_type)
        
        all_outputs.append(output[:, -1:, :].numpy().flatten())
        pred_token = output.argmax(2)[:,-1].item()
        
        trg_indexes.append(pred_token)

        if pred_token == trg_field.vocab.stoi[trg_field.eos_token]:
            break
    
    
    trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]
    
    return trg_tokens[1:], attention,all_outputs

def display_attention(sentence, translation, attention, n_heads = get_head_count(), n_rows = get_row_count(), n_cols = get_col_count()):
    
    assert n_rows * n_cols == n_heads
    figsize = (5,5) if n_cols == 1 else (20,15)
    fig = plt.figure(figsize=figsize) 
    
    for i in range(n_heads):
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        
        _attention = attention.squeeze(0)[i].cpu().detach().numpy()

        cax = ax.matshow(_attention, cmap='bone')

        ax.tick_params(labelsize=12)
        ax.set_xticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'], 
                           rotation=45)
        ax.set_yticklabels(['']+translation)

        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close()

# %%
_ = translate_info("we can eat apple",attention_type=ATTENTION_DEFAULT,draw_charts=True)
# Out:
# source = ['we', 'can', 'eat', 'apple']
# predicted target = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_144912ee_484c_11eb_877a_c49ded8dff66row0_col0,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col1,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col4,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col9,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col10,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col11,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col12,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col13,#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col2,#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col3,#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col8,#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col5,#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col6,#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col14,#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col4,#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col2,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col3,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col12,#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col14,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col0,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col5,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col6,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col7,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col8,#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col9,#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col10,#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col13,#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col4,#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col1,#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col5,#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col2,#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col7{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col6{
#             background-color:  #3131fd;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col7{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col8{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row0_col13,#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col2{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col1{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col3{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col4{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col9{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col10{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col11{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row1_col14{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col0{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col1{
#             background-color:  #9696f7;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col4{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col5{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col6{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col11{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col12{
#             background-color:  #1e1efd;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row2_col14,#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col12{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col0{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col1{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col3{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col7{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col8{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col9{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col10{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col11{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col12{
#             background-color:  #7373f9;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row3_col13{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col0{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col2{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col3{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col5{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col6{
#             background-color:  #5858fb;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col8{
#             background-color:  #6e6ef9;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col9{
#             background-color:  #2828fd;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col10{
#             background-color:  #4444fc;
#             color:  #f1f1f1;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col13{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_144912ee_484c_11eb_877a_c49ded8dff66row4_col14{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }</style><table id="T_144912ee_484c_11eb_877a_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thea

# %%
_ = translate_info("eat apple can i",attention_type=ATTENTION_DEFAULT,draw_charts=True)
# Out:
# source = ['eat', 'apple', 'can', 'i']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_14685478_484c_11eb_85cd_c49ded8dff66row0_col0,#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col2,#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col3,#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col14,#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col5,#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col6,#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col7,#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col8,#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col9,#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col10,#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col12,#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col13,#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col4,#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col1,#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col1,#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col5,#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col9,#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col10,#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col11,#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col2,#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col12,#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col13,#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col3,#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col8,#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col6,#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col14,#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col0,#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col4,#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col4{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col6{
#             background-color:  #6c6cf9;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col7{
#             background-color:  #5151fb;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col8{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col12{
#             background-color:  #5656fb;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row0_col13,#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col12{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col0{
#             background-color:  #5a5afa;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col1{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col3{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col4,#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col13{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col9{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col10{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col11{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row1_col14{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col0{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col1{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col2{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col4{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col5{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col6{
#             background-color:  #8080f8;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col7{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col11,#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col10{
#             background-color:  #3f3ffc;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row2_col14{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col0{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col1{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col2{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col3{
#             background-color:  #8484f8;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col5{
#             background-color:  #d4d4f4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col7{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col8{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col9{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col10{
#             background-color:  #7a7af9;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col11{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row3_col13{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col2{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col3{
#             background-color:  #5f5ffa;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col5{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col6{
#             background-color:  #7b7bf9;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col8{
#             background-color:  #6868fa;
#             color:  #000000;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col9{
#             background-color:  #2f2ffd;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col12{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_14685478_484c_11eb_85cd_c49ded8dff66row4_col14{
#             background-color:  #4343fc;
#             color:  #f1f1f1;
#         }</style><table id="T_14685478_484c_11eb_85cd_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_head

# %%
_ = translate_info("i can eat apple",attention_type=ATTENTION_DEFAULT,draw_charts=True)
#at konnen -> attention is at apfel
#at apfel attention is at eat
# Out:
# source = ['i', 'can', 'eat', 'apple']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_14879826_484c_11eb_823c_c49ded8dff66row0_col0,#T_14879826_484c_11eb_823c_c49ded8dff66row0_col2,#T_14879826_484c_11eb_823c_c49ded8dff66row0_col3,#T_14879826_484c_11eb_823c_c49ded8dff66row0_col14,#T_14879826_484c_11eb_823c_c49ded8dff66row1_col5,#T_14879826_484c_11eb_823c_c49ded8dff66row1_col6,#T_14879826_484c_11eb_823c_c49ded8dff66row1_col7,#T_14879826_484c_11eb_823c_c49ded8dff66row1_col8,#T_14879826_484c_11eb_823c_c49ded8dff66row2_col9,#T_14879826_484c_11eb_823c_c49ded8dff66row2_col10,#T_14879826_484c_11eb_823c_c49ded8dff66row2_col12,#T_14879826_484c_11eb_823c_c49ded8dff66row2_col13,#T_14879826_484c_11eb_823c_c49ded8dff66row3_col4,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col1,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row0_col1,#T_14879826_484c_11eb_823c_c49ded8dff66row0_col5,#T_14879826_484c_11eb_823c_c49ded8dff66row0_col9,#T_14879826_484c_11eb_823c_c49ded8dff66row0_col10,#T_14879826_484c_11eb_823c_c49ded8dff66row0_col11,#T_14879826_484c_11eb_823c_c49ded8dff66row1_col2,#T_14879826_484c_11eb_823c_c49ded8dff66row1_col12,#T_14879826_484c_11eb_823c_c49ded8dff66row1_col13,#T_14879826_484c_11eb_823c_c49ded8dff66row2_col3,#T_14879826_484c_11eb_823c_c49ded8dff66row2_col8,#T_14879826_484c_11eb_823c_c49ded8dff66row3_col6,#T_14879826_484c_11eb_823c_c49ded8dff66row3_col14,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col0,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col4,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row0_col4{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row0_col6{
#             background-color:  #6868fa;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row0_col7{
#             background-color:  #5252fb;
#             color:  #f1f1f1;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row0_col8{
#             background-color:  #6565fa;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row0_col12{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row0_col13{
#             background-color:  #6060fa;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col0{
#             background-color:  #7373f9;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col1{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col3{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col4,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col13{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col9{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col10,#T_14879826_484c_11eb_823c_c49ded8dff66row2_col1{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col11{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row1_col14{
#             background-color:  #afaff6;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col0{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col2,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col5{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col4{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col5{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col6,#T_14879826_484c_11eb_823c_c49ded8dff66row3_col3,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col6{
#             background-color:  #7171f9;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col7{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col11,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col10{
#             background-color:  #3c3cfc;
#             color:  #f1f1f1;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row2_col14{
#             background-color:  #7a7af9;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col0{
#             background-color:  #9191f8;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col1{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col2{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col5{
#             background-color:  #d4d4f4;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col7{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col8,#T_14879826_484c_11eb_823c_c49ded8dff66row4_col2{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col9{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col10{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col11{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col12{
#             background-color:  #7272f9;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row3_col13{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row4_col3{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row4_col8{
#             background-color:  #6f6ff9;
#             color:  #000000;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row4_col9{
#             background-color:  #2c2cfd;
#             color:  #f1f1f1;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row4_col12{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_14879826_484c_11eb_823c_c49ded8dff66row4_col14{
#             background-color:  #4c4cfb;
#             color:  #f1f1f1;
#         }</style><table id="T_14879826_484c_11eb_823c_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14879826_484c_11eb_823c_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->ich<

# %%
_ = translate_info("i want to eat apple",attention_type=ATTENTION_EQUAL_DISTRIBUTED,draw_charts=True)
#since no real attention network cannot predict well
# Out:
# source = ['i', 'want', 'to', 'eat', 'apple']
# predicted target = ['ich', 'essen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col0,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col9{
#             background-color:  #1717fe;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col1{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col2,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col3,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col5,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col6,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col7,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col8,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col13,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col0,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col4,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col14,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col1,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col9,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col10,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col11,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col12{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col4,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col6,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col8,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col10,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col1,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col12,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col13,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col14,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col0,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col2,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col5,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col7,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col9,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col11,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col2,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col5{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col7{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col9{
#             background-color:  #3c3cfc;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col11,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col3{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col12{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col13{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row0_col14{
#             background-color:  #3333fc;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col0,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col3,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col6{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col2{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col3,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col6{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col4{
#             background-color:  #7272f9;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col9{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col10{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row1_col11{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col1{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col4{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col5{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col7,#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col4{
#             background-color:  #a7a7f7;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col8{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col10{
#             background-color:  #2525fd;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col11{
#             background-color:  #2f2ffd;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col12{
#             background-color:  #1818fe;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row2_col14{
#             background-color:  #5656fb;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col1{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col2{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col6{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col8{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col10{
#             background-color:  #6363fa;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col12{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row3_col13{
#             background-color:  #3e3efc;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col0{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col5{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col7{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col8{
#             background-color:  #7b7bf9;
#             color:  #000000;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col13{
#             background-color:  #2121fd;
#             color:  #f1f1f1;
#         }#T_14a55c90_484c_11eb_ac5b_c49ded8dff66row4_col14{
#             background-color:  #1111fe;
#             color:  #f1f1f1;
#         }</style><table id="T_14a55c90_484c_11eb_ac5b_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14a55c90_484c_11eb_ac5b_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->ich<

# %%
#_ = translate_info("i can read book",attention_type=ATTENTION_AT_END,draw_charts=True)
_ = translate_info("i want to eat apple",attention_type=ATTENTION_AT_BEGINNING,draw_charts=True)
# Out:
# source = ['i', 'want', 'to', 'eat', 'apple']
# predicted target = ['ich', 'trinken', '<eos>']
# Logits
# <style  type="text/css" >
# #T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col0,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col2,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col3,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col9,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col4,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col5,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col6,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col7,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col8,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col11,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col1,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col10,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col12,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col13,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col14{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col1{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col4,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col6,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col10,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col13,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col0,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col1,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col2,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col3,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col9,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col12,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col14,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col5,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col7,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col8,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col11{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col5{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col7{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col8{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col11{
#             background-color:  #1c1cfe;
#             color:  #f1f1f1;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col12{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col14{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col10{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col13{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col0{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col2{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col3{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col4,#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col9{
#             background-color:  #3333fc;
#             color:  #f1f1f1;
#         }#T_14c3e3f8_484c_11eb_864c_c49ded8dff66row2_col6{
#             background-color:  #8686f8;
#             color:  #000000;
#         }</style><table id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->ich</th>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col0" class="data row0 col0" >-0.33</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col1" class="data row0 col1" >-2.12</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col2" class="data row0 col2" >5.44</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col3" class="data row0 col3" >3.37</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col4" class="data row0 col4" >-0.35</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col5" class="data row0 col5" >-0.55</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col6" class="data row0 col6" >-0.54</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col7" class="data row0 col7" >-1.64</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col8" class="data row0 col8" >-0.35</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col9" class="data row0 col9" >2.14</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col10" class="data row0 col10" >-2.01</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col11" class="data row0 col11" >-0.95</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col12" class="data row0 col12" >-0.93</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col13" class="data row0 col13" >-1.74</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row0_col14" class="data row0 col14" >-3.18</td>
#             </tr>
#             <tr>
#                         <th id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66level0_row1" class="row_heading level0 row1" >2)ich->trinken</th>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col0" class="data row1 col0" >-2.90</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col1" class="data row1 col1" >-2.99</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col2" class="data row1 col2" >-1.62</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col3" class="data row1 col3" >-1.76</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col4" class="data row1 col4" >2.84</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col5" class="data row1 col5" >1.56</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col6" class="data row1 col6" >2.06</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col7" class="data row1 col7" >2.62</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col8" class="data row1 col8" >2.94</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col9" class="data row1 col9" >0.45</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col10" class="data row1 col10" >0.28</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded8dff66row1_col11" class="data row1 col11" >-0.70</td>
#                         <td id="T_14c3e3f8_484c_11eb_864c_c49ded

# %%
#utility class for future visualizations
class DebugStepWord:
    def __init__(self,sentence,translation):
        self.q = None
        self.k = None
        self.v = None
        self.energy = None
        self.attention = None
        self.mask = None
        self.x1 = None
        self.sentence = sentence
        self.translation = translation
        self.original_embedding = None 
        self.word_vector = None #only filled if done at world level
        self.word_translation = None #only filled if done at world level
        self.word_embeddding  = None #only filled if done at world level
        
    def summary(self):
        print("q",self.q.shape)
        print("k",self.k.shape)
        print("v",self.v.shape)
        print("attention",self.attention.shape)
        print("energy",self.energy.shape)
        print("mask",self.mask.shape)
        print("x1",self.x1.shape)
        print("x1",self.x1.shape)
        print("word_translation",self.word_translation)
        print("translation",self.translation)

# %%
#for all sentences generate a map
all_sentences = {}
for i, batch in enumerate(train_iterator):
    src = batch.src
    trg = batch.trg
    for i in range( (src.shape[0]) ):
        all_sentences[" ".join(encoding_to_sentence(src[i],SRC)) ] = " ".join(encoding_to_sentence(trg[i],TRG) )

def find_src_sentence_from_trg(trg_sentence):
    for src in all_sentences.keys():
        if all_sentences[src].find( trg_sentence) >= 0:
            return src
    assert 1 == 2 #must not reach here
    
#last word is trimmed so here find full version of sentence    
def find_fullsentence_from_trg(trg_sentence):
    for src in all_sentences.keys():
        if all_sentences[src].find( trg_sentence) >= 0:
            return all_sentences[src]
    assert 1 == 2    

assert find_fullsentence_from_trg("ich essen apfel") == "<sos> ich essen apfel <eos> <pad>"

# %%
#prepare intermediate vector maps
#traverse the vectors generated for data_pipeline
#and generate DebugStepWord object for each, here i know the order of addition
#of these vectors so i create object on QKV and then update.
#here i log these for sentences
steps_decoder_bysentence = []
LANG = TRG
last_sentence_encoding_batch = None
last_sentence_original_batch = None
for i in range(len(data_pipeline)):
    current_label = data_pipeline[i][0]
    if "decoder_encoder_attention@QKV" == current_label: # TODO encoder@QKV
         sentence_batch = last_sentence_encoding_batch
         batch_len = sentence_batch.shape[0]   
         for sent_index in range(batch_len):  
            sentence = sentence_batch[sent_index]
            data_part = data_pipeline[i][1]
            original_embedding = last_sentence_original_batch[sent_index]
            translation = " ".join( encoding_to_sentence(original_embedding,TRG) )
            dstep = DebugStepWord(sentence,translation)
            dstep.original_embedding = original_embedding 
            dstep.q = data_pipeline[i][1][0][sent_index].squeeze().detach()
            dstep.k = data_pipeline[i][1][1][sent_index].squeeze().detach()
            dstep.v = data_pipeline[i][1][2][sent_index].squeeze().detach()
            dstep.energy = data_pipeline[i][1][4][sent_index].squeeze().detach()
            dstep.attention = data_pipeline[i][1][5][sent_index].squeeze().detach()
            dstep.mask = data_pipeline[i][1][6][sent_index].squeeze().detach()
            dstep.x1 = data_pipeline[i][1][7][sent_index].squeeze().detach()
            steps_decoder_bysentence.append(dstep)
    if "Decoder->encoder_attention" == current_label: #TODO Encoder->attention
         last_sentence_encoding_batch = data_pipeline[i][1]
    if "Decoder_original->trg" == current_label: #TODO Encoder->attention
         last_sentence_original_batch = data_pipeline[i][1]

# %%
assert N_EPOCHS * len(steps_decoder_bysentence) * 36
print( " epochs: ",N_EPOCHS , " log length : ", len(steps_decoder_bysentence) )
# num epoch x 36 sentence
# Out:
#  epochs:  30  log length :  1080

# %%
assert steps_decoder_bysentence[0].v.shape[0] == 7
assert steps_decoder_bysentence[0].v.shape[1] == HID_DIM

# %%
#now by using same object, i create these maps for word also
steps_decoder_byword = []
for step in steps_decoder_bysentence:
    word_count = step.q.shape[0]
    for i in range(word_count):        
        word_step = DebugStepWord(step.sentence,step.translation)    
        #print("step.q",step.q.shape)
        word_step.q = step.q[i]
        word_step.k = step.k[i]
        word_step.v = step.v[i]
        word_step.energy = step.energy[i]
        word_step.attention = step.attention[i]
        word_step.mask = step.mask[i]
        word_step.x1 = step.x1[i]
        word_step.sentence = step.sentence
        word_step.translation = step.translation
        word_step.word_vector = step.sentence[i]
        word_step.word_embeddding = step.original_embedding[i]
        #print("step.sentence.squeeze()[i]",word_step.word_embeddding )
        word_step.word_translation = encoding_to_word(word_step.word_embeddding,LANG)
        steps_decoder_byword.append( word_step )

assert steps_decoder_byword[0].q.shape[0] == 64 #indexes must be single dimension
assert steps_decoder_byword[0].word_vector.shape[0] == 64 #indexes must be single dimension

# %%
def get_by_sentence(search_sentence,steps):
    return [ step for step in steps if step.translation.find(search_sentence) >=0 ]
    
def get_by_word(search_sentence,keywords,steps_word):
    steps_for_sample = get_by_sentence(search_sentence,steps_word)
    keyword_map = {}
    for step in steps_for_sample :
        if step.word_translation in keywords :
            if step.word_translation in keyword_map.keys():
                keyword_map[step.word_translation] = keyword_map[step.word_translation]+[step]
            else:    
                keyword_map[step.word_translation] = [step]
            
    return keyword_map

# %%
#for a target sentence(german) find intermediate steps
def steps_for_target(search_sentence):
    steps_for_sample = get_by_sentence(search_sentence,steps_decoder_bysentence)
    for index,step in enumerate(steps_for_sample):
        if index == 0 or (index+1) % 10 == 0:
            print("training epoch :",index+1)
            attention = step.attention.detach().numpy()
            splits = step.translation.split(" ")
            splits = [s.replace("<","").replace(">","") for s in splits]
            
            splits = [ splits[i]+"->"+splits[i+1]  for i in range(len(splits)-1)] + [splits[len(splits)-1]+"->eos"]            
            splits = [ str(index+1)+")"+s for index,s in enumerate(splits)]
            
            src_sentence_splits = find_src_sentence_from_trg(step.translation).split(" ")
            src_sentence_splits = [s.replace("<","").replace(">","").replace("pad","pad"+str(index)) for index,s in enumerate(src_sentence_splits)]            
            draw_df(np.array(attention),columns=src_sentence_splits,indexes=splits)

# %%
#steps_for_target("wir essen apfel")
#steps_for_target("wir mochten apfel essen")
steps_for_target("wir konnen apfel essen")
# Out:
# training epoch : 1
# <style  type="text/css" >
# #T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col0,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col1,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col3,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col4,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col2,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col1{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col2,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col5,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col6,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col0,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col6,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col1,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col3,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col6,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col4,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col6,#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col3{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col4{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col2{
#             background-color:  #9a9af7;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col5{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col0{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col2{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col4{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col5{
#             background-color:  #bcbcf5;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col0{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col1{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col3{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col0{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col1{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col2{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col3{
#             background-color:  #2e2efd;
#             color:  #f1f1f1;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col4{
#             background-color:  #7a7af9;
#             color:  #000000;
#         }#T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col5{
#             background-color:  #9292f8;
#             color:  #000000;
#         }</style><table id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >apple</th>        <th class="col_heading level0 col5" >eos</th>        <th class="col_heading level0 col6" >pad6</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->wir</th>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col0" class="data row0 col0" >0.74</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col1" class="data row0 col1" >0.03</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col2" class="data row0 col2" >0.02</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col3" class="data row0 col3" >0.14</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col4" class="data row0 col4" >0.06</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col5" class="data row0 col5" >0.02</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row0_col6" class="data row0 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66level0_row1" class="row_heading level0 row1" >2)wir->konnen</th>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col0" class="data row1 col0" >0.06</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col1" class="data row1 col1" >0.15</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col2" class="data row1 col2" >0.08</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col3" class="data row1 col3" >0.39</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col4" class="data row1 col4" >0.27</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col5" class="data row1 col5" >0.05</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row1_col6" class="data row1 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66level0_row2" class="row_heading level0 row2" >3)konnen->apfel</th>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col0" class="data row2 col0" >0.71</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col1" class="data row2 col1" >0.02</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col2" class="data row2 col2" >0.04</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col3" class="data row2 col3" >0.12</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col4" class="data row2 col4" >0.07</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col5" class="data row2 col5" >0.05</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row2_col6" class="data row2 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66level0_row3" class="row_heading level0 row3" >4)apfel->essen</th>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col0" class="data row3 col0" >0.38</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col1" class="data row3 col1" >0.06</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col2" class="data row3 col2" >0.20</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col3" class="data row3 col3" >0.17</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col4" class="data row3 col4" >0.05</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col5" class="data row3 col5" >0.13</td>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row3_col6" class="data row3 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66level0_row4" class="row_heading level0 row4" >5)essen->eos</th>
#                         <td id="T_1527d5ec_484c_11eb_b10e_c49ded8dff66row4_col0" class="data row4 col0" >0.38</t
# training epoch : 10
# <style  type="text/css" >
# #T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col0,#T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col6,#T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col6,#T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col6,#T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col3,#T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col4,#T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col5,#T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col6,#T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col1,#T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col2,#T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col1,#T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col3,#T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col4,#T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col5,#T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col2,#T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col2{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col4{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col5{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col0{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col1{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col2{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col3{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col0{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col1{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col3{
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col4{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col5{
#             background-color:  #bbbbf5;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col0{
#             background-color:  #1212fe;
#             color:  #f1f1f1;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col1{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col2{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col3{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col4{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col5{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }</style><table id="T_152ada70_484c_11eb_96b2_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >apple</th>        <th class="col_heading level0 col5" >eos</th>        <th class="col_heading level0 col6" >pad6</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_152ada70_484c_11eb_96b2_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->wir</th>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col0" class="data row0 col0" >0.02</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col1" class="data row0 col1" >0.65</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col2" class="data row0 col2" >0.07</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col3" class="data row0 col3" >0.11</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col4" class="data row0 col4" >0.07</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col5" class="data row0 col5" >0.07</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row0_col6" class="data row0 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152ada70_484c_11eb_96b2_c49ded8dff66level0_row1" class="row_heading level0 row1" >2)wir->konnen</th>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col0" class="data row1 col0" >0.04</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col1" class="data row1 col1" >0.04</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col2" class="data row1 col2" >0.44</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col3" class="data row1 col3" >0.08</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col4" class="data row1 col4" >0.10</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col5" class="data row1 col5" >0.30</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row1_col6" class="data row1 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152ada70_484c_11eb_96b2_c49ded8dff66level0_row2" class="row_heading level0 row2" >3)konnen->apfel</th>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col0" class="data row2 col0" >0.17</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col1" class="data row2 col1" >0.11</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col2" class="data row2 col2" >0.46</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col3" class="data row2 col3" >0.11</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col4" class="data row2 col4" >0.07</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col5" class="data row2 col5" >0.08</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row2_col6" class="data row2 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152ada70_484c_11eb_96b2_c49ded8dff66level0_row3" class="row_heading level0 row3" >4)apfel->essen</th>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col0" class="data row3 col0" >0.76</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col1" class="data row3 col1" >0.03</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col2" class="data row3 col2" >0.14</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col3" class="data row3 col3" >0.04</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col4" class="data row3 col4" >0.01</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col5" class="data row3 col5" >0.02</td>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row3_col6" class="data row3 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152ada70_484c_11eb_96b2_c49ded8dff66level0_row4" class="row_heading level0 row4" >5)essen->eos</th>
#                         <td id="T_152ada70_484c_11eb_96b2_c49ded8dff66row4_col0" class="data row4 col0" >0.82</t
# training epoch : 20
# <style  type="text/css" >
# #T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col0,#T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col2,#T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col3,#T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col4,#T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col6,#T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col5,#T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col6,#T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col6,#T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col6,#T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col1,#T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col1,#T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col2,#T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col4,#T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col3,#T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col0,#T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col5{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col0,#T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col2{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col1,#T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col3,#T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col4{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col0{
#             background-color:  #5353fb;
#             color:  #f1f1f1;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col1{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col2{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col3{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col5{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col0{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col1{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col4{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col5{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col2{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col3{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col4{
#             background-color:  #b3b3f6;
#             color:  #000000;
#         }</style><table id="T_152f7906_484c_11eb_8f27_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >apple</th>        <th class="col_heading level0 col5" >eos</th>        <th class="col_heading level0 col6" >pad6</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_152f7906_484c_11eb_8f27_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->wir</th>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col1" class="data row0 col1" >0.97</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col2" class="data row0 col2" >0.00</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col3" class="data row0 col3" >0.01</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col4" class="data row0 col4" >0.00</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col5" class="data row0 col5" >0.01</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row0_col6" class="data row0 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152f7906_484c_11eb_8f27_c49ded8dff66level0_row1" class="row_heading level0 row1" >2)wir->konnen</th>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col0" class="data row1 col0" >0.01</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col1" class="data row1 col1" >0.02</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col2" class="data row1 col2" >0.93</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col3" class="data row1 col3" >0.03</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col4" class="data row1 col4" >0.01</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col5" class="data row1 col5" >0.00</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row1_col6" class="data row1 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152f7906_484c_11eb_8f27_c49ded8dff66level0_row2" class="row_heading level0 row2" >3)konnen->apfel</th>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col0" class="data row2 col0" >0.35</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col1" class="data row2 col1" >0.27</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col2" class="data row2 col2" >0.05</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col3" class="data row2 col3" >0.07</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col4" class="data row2 col4" >0.13</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col5" class="data row2 col5" >0.12</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row2_col6" class="data row2 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152f7906_484c_11eb_8f27_c49ded8dff66level0_row3" class="row_heading level0 row3" >4)apfel->essen</th>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col0" class="data row3 col0" >0.13</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col1" class="data row3 col1" >0.07</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col2" class="data row3 col2" >0.01</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col3" class="data row3 col3" >0.75</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col4" class="data row3 col4" >0.02</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col5" class="data row3 col5" >0.01</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row3_col6" class="data row3 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_152f7906_484c_11eb_8f27_c49ded8dff66level0_row4" class="row_heading level0 row4" >5)essen->eos</th>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col0" class="data row4 col0" >0.54</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col1" class="data row4 col1" >0.01</td>
#                         <td id="T_152f7906_484c_11eb_8f27_c49ded8dff66row4_col2" class="data row4 col2" >0.03</td>
# training epoch : 30
# <style  type="text/css" >
# #T_15327a76_484c_11eb_811d_c49ded8dff66row0_col0,#T_15327a76_484c_11eb_811d_c49ded8dff66row0_col3,#T_15327a76_484c_11eb_811d_c49ded8dff66row0_col4,#T_15327a76_484c_11eb_811d_c49ded8dff66row0_col5,#T_15327a76_484c_11eb_811d_c49ded8dff66row0_col6,#T_15327a76_484c_11eb_811d_c49ded8dff66row1_col6,#T_15327a76_484c_11eb_811d_c49ded8dff66row2_col3,#T_15327a76_484c_11eb_811d_c49ded8dff66row2_col6,#T_15327a76_484c_11eb_811d_c49ded8dff66row3_col2,#T_15327a76_484c_11eb_811d_c49ded8dff66row3_col6,#T_15327a76_484c_11eb_811d_c49ded8dff66row4_col1,#T_15327a76_484c_11eb_811d_c49ded8dff66row4_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row0_col1,#T_15327a76_484c_11eb_811d_c49ded8dff66row1_col2,#T_15327a76_484c_11eb_811d_c49ded8dff66row2_col4,#T_15327a76_484c_11eb_811d_c49ded8dff66row3_col3,#T_15327a76_484c_11eb_811d_c49ded8dff66row4_col0,#T_15327a76_484c_11eb_811d_c49ded8dff66row4_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row0_col2{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row1_col0,#T_15327a76_484c_11eb_811d_c49ded8dff66row1_col1{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row1_col3{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row1_col4,#T_15327a76_484c_11eb_811d_c49ded8dff66row4_col3{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row1_col5{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row2_col0{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row2_col1,#T_15327a76_484c_11eb_811d_c49ded8dff66row3_col4{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row2_col2{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row2_col5{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row3_col0{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row3_col1{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row3_col5{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row4_col2{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_15327a76_484c_11eb_811d_c49ded8dff66row4_col4{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }</style><table id="T_15327a76_484c_11eb_811d_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >apple</th>        <th class="col_heading level0 col5" >eos</th>        <th class="col_heading level0 col6" >pad6</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15327a76_484c_11eb_811d_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->wir</th>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row0_col1" class="data row0 col1" >0.88</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row0_col2" class="data row0 col2" >0.04</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row0_col3" class="data row0 col3" >0.05</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row0_col4" class="data row0 col4" >0.01</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row0_col5" class="data row0 col5" >0.02</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row0_col6" class="data row0 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_15327a76_484c_11eb_811d_c49ded8dff66level0_row1" class="row_heading level0 row1" >2)wir->konnen</th>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row1_col0" class="data row1 col0" >0.02</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row1_col1" class="data row1 col1" >0.03</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row1_col2" class="data row1 col2" >0.69</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row1_col3" class="data row1 col3" >0.20</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row1_col4" class="data row1 col4" >0.02</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row1_col5" class="data row1 col5" >0.04</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row1_col6" class="data row1 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_15327a76_484c_11eb_811d_c49ded8dff66level0_row2" class="row_heading level0 row2" >3)konnen->apfel</th>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row2_col0" class="data row2 col0" >0.22</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row2_col1" class="data row2 col1" >0.10</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row2_col2" class="data row2 col2" >0.11</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row2_col3" class="data row2 col3" >0.05</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row2_col4" class="data row2 col4" >0.41</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row2_col5" class="data row2 col5" >0.11</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row2_col6" class="data row2 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_15327a76_484c_11eb_811d_c49ded8dff66level0_row3" class="row_heading level0 row3" >4)apfel->essen</th>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row3_col0" class="data row3 col0" >0.21</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row3_col1" class="data row3 col1" >0.01</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row3_col2" class="data row3 col2" >0.01</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row3_col3" class="data row3 col3" >0.66</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row3_col4" class="data row3 col4" >0.05</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row3_col5" class="data row3 col5" >0.06</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row3_col6" class="data row3 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_15327a76_484c_11eb_811d_c49ded8dff66level0_row4" class="row_heading level0 row4" >5)essen->eos</th>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row4_col0" class="data row4 col0" >0.53</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row4_col1" class="data row4 col1" >0.01</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row4_col2" class="data row4 col2" >0.04</td>
#                         <td id="T_15327a76_484c_11eb_811d_c49ded8dff66row4_col3" cl

# %%
#includes : list of vectors to add Q,K,V,A
#get steps for stated vectors
def map_word_by_sentence(steps_for_sample,includes="QV",ranks=[1,15,N_EPOCHS]):
    Xs = []
    Ys = []
    for key in steps_for_sample.keys():
        for index,step in enumerate(steps_for_sample[key]):
            #print("index:",index)            
            if "Q" in includes:
                Xs.append( step.q.numpy())
                Ys.append( key+"@Q@"+str(index+1) )
            if "K" in includes:
                Xs.append( step.k.numpy())
                Ys.append( key+"@K@"+str(index+1) )
            if "V" in includes:
                Xs.append( step.v.numpy())
                Ys.append( key+"@V@"+str(index+1) )
            if "X" in includes:
                Xs.append( step.x1.numpy())
                Ys.append( key+"@X1@"+str(index+1) )     
    return filter_by_indexes(Xs,Ys,ranks)

def filter_by_indexes(Xs,Ys,ranks):
    Xnew = []
    Ynew = []
    for val,key in zip(Xs,Ys):        
        item_rank = key.split("@")[2]
        if int(item_rank) in ranks:
            Xnew.append(val)
            Ynew.append(key)
    return Xnew,Ynew    

def filter_by_key(Xs,Ys,keys):
    X_new,Y_new = [],[]
    for val,key in zip(Xs,Ys):
        if key.split("@")[0] in keys:
            X_new.append(val)
            Y_new.append(key)
    return X_new,Y_new        

def get_as_map(Xs,Ys,map_keys):
    xy_map = {}
    for val,key in zip(Xs,Ys):
        if key in map_keys:
            xy_map[key]=val
    return xy_map

# %%
#altough wir and essen are same words, their embedding changed over time
#mapping on 2d changes over time, and network learns to differentiate better on final encoding
#final encoding is on 30th step. Here mapping is with wir and essen
search_sentence = "wir konnen apfel essen"
steps_for_sample = get_by_word(search_sentence,["essen","wir"],steps_decoder_byword)
X_s1,Y_s1 = map_word_by_sentence(steps_for_sample,includes="QKVX",ranks=[1,15,30])

search_sentence2 = "wir konnen brot essen"
steps_for_sample2 = get_by_word(search_sentence2,["essen","wir"],steps_decoder_byword)
X_s2,Y_s2 = map_word_by_sentence(steps_for_sample2,includes="QKVX",ranks=[1,15,30])

Xs = X_s1 + X_s2
Ys = [ s for s in Y_s1] + [ s for s in Y_s2]
color_mapping = [ "#0000ff" for s in Y_s1] + [ "#ff0000" for s in Y_s2]


pca = PCA(n_components=2)
X_transformed = pca.fit_transform(np.array(Xs))
map_on_2d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[15,15]) 

pca = PCA(n_components=3)
X_transformed = pca.fit_transform(np.array(Xs))
map_on_3d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[15,15])

# %%
#show only essen
search_sentence = "wir konnen apfel essen"
steps_for_sample = get_by_word(search_sentence,["essen"],steps_decoder_byword)
X_s1,Y_s1 = map_word_by_sentence(steps_for_sample,includes="QKVX",ranks=[1,15,30])

search_sentence2 = "wir konnen brot essen"
steps_for_sample2 = get_by_word(search_sentence2,["essen"],steps_decoder_byword)
X_s2,Y_s2 = map_word_by_sentence(steps_for_sample2,includes="QKVX",ranks=[1,15,30])

Xs = X_s1 + X_s2
Ys = [ s for s in Y_s1] + [ s for s in Y_s2]
color_mapping = [ "#0000ff" for s in Y_s1] + [ "#ff0000" for s in Y_s2]

pca = PCA(n_components=2)
X_transformed = pca.fit_transform(np.array(Xs))
map_on_2d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[12,12]) 

pca = PCA(n_components=3)
X_transformed = pca.fit_transform(np.array(Xs))
map_on_3d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[12,12])

# %%
#get embeddings of all valid sentences for DecoderLayer@trg4
valid_sentences = [ " ".join( tabular_set[i].src) for i in range(len(tabular_set)) ]
    
valid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs,_ = translate_info(tabular_set[i].src,draw_charts=False,dump_result=False)
    trg4 = test_logger.get_summary(labels=["DecoderLayer@trg4"],show_data=False)
    valid_sentences_embeddings.append(trg4[0].numpy().flatten())
    
#get embeddings of all applied equal attention sentences for DecoderLayer@trg4
invalid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs,_ = translate_info(tabular_set[i].src,draw_charts=False,
                                              attention_type=ATTENTION_EQUAL_DISTRIBUTED ,dump_result=False)    
    trg4 = test_logger.get_summary(labels=["DecoderLayer@trg4"],show_data=False)

    invalid_sentences_embeddings.append(trg4[0].numpy().flatten())

# %%
show_on_vis_multi([],[],valid_sentences_embeddings,valid_sentences)
#show sentences with attention applied

# %%
show_on_vis_multi(invalid_sentences_embeddings,valid_sentences,valid_sentences_embeddings,valid_sentences)
#show sentences with attention applied and NOT attention applied

# %%
#test all flow types
flow_types = [1,2,3,4,5,6,8,10,11,12,13,14]
apply_map = {}
apply_map[APPLY_EVERYTHING] = "APPLY_EVERYTHING"
apply_map[APPLY_NOT_DECODER_SELFATTENTION] = "APPLY_NOT_DECODER_SELFATTENTION"
apply_map[APPLY_ONLY_NORM_DECODER_SELFATTENTION] = "APPLY_ONLY_NORM_DECODER_SELFATTENTION"
apply_map[APPLY_ONLY_DECODER_SELFATTENTION] = "APPLY_ONLY_DECODER_SELFATTENTION"
apply_map[APPLY_ONLY_DROPOUT_DECODER_SELFATTENTION] = "APPLY_ONLY_DROPOUT_DECODER_SELFATTENTION"
apply_map[APPLY_NOT_POSITIONWISE] = "APPLY_NOT_POSITIONWISE"


apply_map[APPLY_ONLY_TARGET_WITHOUT_SCALE] = "APPLY_ONLY_TARGET_WITHOUT_SCALE"
apply_map[APPLY_ONLY_TARGET_EMBEDDING] = "APPLY_ONLY_TARGET_EMBEDDING"
apply_map[APPLY_ONLY_SOURCE_EMBEDDING] = "APPLY_ONLY_SOURCE_EMBEDDING"
apply_map[APPLY_ONLY_POS_EMBEDDING] = "APPLY_ONLY_POS_EMBEDDING"

apply_map[APPLY_ONLY_TARGET_WITH_SCALE] = "APPLY_ONLY_TARGET_WITH_SCALE"
apply_map[APPLY_NOT_ATTENTION] = "APPLY_NOT_ATTENTION"


#Open above to check all types enable/disable
for flow_type in flow_types:
    print("------------- flow type : ",apply_map[flow_type])
    _,_,_ = translate_info("we want to eat apple",attention_type=1,draw_charts=True,flow_type=flow_type)
    _,_,_ = translate_info("we can eat apple",attention_type=1,draw_charts=True,flow_type=flow_type)
# Out:
# ------------- flow type :  APPLY_EVERYTHING
# source = ['we', 'want', 'to', 'eat', 'apple']
# predicted target = ['wir', 'mochten', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col0{
#             background-color:  #6060fa;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col1{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col2,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col3,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col5,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col6,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col7,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col8,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col14,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col0,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col9,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col10,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col12,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col13,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col4,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col1,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col4,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col10,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col0,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col1,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col9,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col11,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col12,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col13,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col2,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col7,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col8,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col6,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col14,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col3,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col4,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col5,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col5,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col5{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col6{
#             background-color:  #2b2bfd;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col7{
#             background-color:  #8080f8;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col8{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col9{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col11{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col12{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col13{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row0_col14{
#             background-color:  #6969fa;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col2{
#             background-color:  #8282f8;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col3{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col4{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row1_col10{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col1{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col3{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col4{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col6{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col11,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col9{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row2_col14{
#             background-color:  #3838fc;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col0{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col1{
#             background-color:  #7171f9;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col2{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col3{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col5{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col7{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col8,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col9{
#             background-color:  #9c9cf7;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col10{
#             background-color:  #9696f7;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col11{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col12{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row3_col13{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col0,#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col10{
#             background-color:  #4c4cfb;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col2{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col6{
#             background-color:  #5252fb;
#             color:  #f1f1f1;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col8{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col12{
#             background-color:  #6262fa;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col13{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1726f9f6_484c_11eb_8b59_c49ded8dff66row4_col14{
#             background-color:  #7272f9;
#             color:  #000000;
#         }</style><table id="T_1726f9f6_484c_11eb_8b59_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1726f9f6_484c_
# source = ['we', 'can', 'eat', 'apple']
# predicted target = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col0,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col1,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col4,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col9,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col10,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col11,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col12,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col13,#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col2,#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col3,#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col8,#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col5,#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col6,#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col14,#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col4,#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col2,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col3,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col12,#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col14,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col0,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col5,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col6,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col7,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col8,#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col9,#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col10,#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col13,#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col4,#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col1,#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col5,#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col2,#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col7{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col6{
#             background-color:  #3131fd;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col7{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col8{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row0_col13,#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col2{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col1{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col3{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col4{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col9{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col10{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col11{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row1_col14{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col0{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col1{
#             background-color:  #9696f7;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col4{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col5{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col6{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col11{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col12{
#             background-color:  #1e1efd;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row2_col14,#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col12{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col0{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col1{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col3{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col7{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col8{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col9{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col10{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col11{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col12{
#             background-color:  #7373f9;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row3_col13{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col0{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col2{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col3{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col5{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col6{
#             background-color:  #5858fb;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col8{
#             background-color:  #6e6ef9;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col9{
#             background-color:  #2828fd;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col10{
#             background-color:  #4444fc;
#             color:  #f1f1f1;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col13{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_17464b26_484c_11eb_89e4_c49ded8dff66row4_col14{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }</style><table id="T_17464b26_484c_11eb_89e4_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thea
# ------------- flow type :  APPLY_ONLY_TARGET_WITHOUT_SCALE
# source = ['we', 'want', 'to', 'eat', 'apple']
# predicted target = ['wir', 'mochten', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col0{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col1,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col7{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col2,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col3,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col5,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col6,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col7,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col8,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col14,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col0,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col9,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col10,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col12,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col13,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col4,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col1,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col4,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col10,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col0,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col1,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col9,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col11,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col12,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col13,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col8,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col6,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col14,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col2,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col3,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col5,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col5{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col6{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col7{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col8{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col9,#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col12{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col11{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col12{
#             background-color:  #1313fe;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col13{
#             background-color:  #8f8ff8;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row0_col14{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col2{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col3{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col4{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row1_col10{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col1{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col2{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col3{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col4{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col5{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col6{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col11{
#             background-color:  #5353fb;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row2_col14{
#             background-color:  #7474f9;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col0{
#             background-color:  #1717fe;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col1{
#             background-color:  #3d3dfc;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col2{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col3{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col5{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col7{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col8{
#             background-color:  #6969fa;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col9{
#             background-color:  #6d6df9;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col10{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col11{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row3_col13{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col0{
#             background-color:  #7171f9;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col4{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col6{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col8{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col9{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col10{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col12{
#             background-color:  #5959fa;
#             color:  #f1f1f1;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col13{
#             background-color:  #a1a1f7;
#             color:  #000000;
#         }#T_176717c0_484c_11eb_bd1a_c49ded8dff66row4_col14{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }</style><table id="T_176717c0_484c_11eb_bd1a_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>
# source = ['we', 'can', 'eat', 'apple']
# predicted target = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col0,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col14{
#             background-color:  #b2b2f6;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col1,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col4,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col5,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col8,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col9,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col11,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col2,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col10,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col12,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col13,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col3,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col6,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col7,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col14,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col2,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col3,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col12,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col14,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col0,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col5,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col6,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col7,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col9,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col10,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col13,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col4,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col1,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col8,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col6{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col7{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col10,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col2,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col7,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col2,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col7{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col13{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col1{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col3{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col4{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col8,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col12{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col9{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col11{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row1_col14,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col4{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col0{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col1{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col5{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col8{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col11{
#             background-color:  #1d1dfe;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row2_col14{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col0{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col1{
#             background-color:  #3434fc;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col2{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col3,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col5{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col6{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col8{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col9,#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col10{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col11{
#             background-color:  #bbbbf5;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col12{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row3_col13{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col3{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col4{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col5{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col6{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col9{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col10{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col12{
#             background-color:  #4d4dfb;
#             color:  #f1f1f1;
#         }#T_178597a6_484c_11eb_b1dd_c49ded8dff66row4_col13{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }</style><table id="T_178597a6_484c_11eb_b1dd_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_178597a6_484c_11eb_b1dd_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->wir</th>
#                         <td id="T_178597a6_484c_11eb_b1dd_c49ded8dff66row0_col0" class="data row0 col0" >-1.88</td>
#                         <td id="T_178
# ------------- flow type :  APPLY_ONLY_TARGET_EMBEDDING
# source = ['we', 'want', 'to', 'eat', 'apple']
# predicted target = ['wir', 'mochten', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col0{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col1,#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col7{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col2,#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col3,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col5,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col6,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col7,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col8,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col14,#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col0,#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col9,#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col10,#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col12,#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col13,#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col4,#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col1,#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col4,#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col10,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col0,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col1,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col9,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col11,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col12,#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col13,#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col8,#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col6,#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col14,#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col2,#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col3,#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col5,#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col5{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col6{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col7{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col8{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col9,#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col12{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col11{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col12{
#             background-color:  #1313fe;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col13{
#             background-color:  #8f8ff8;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row0_col14{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col2{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col3{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col4{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row1_col10{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col1{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col2{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col3{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col4{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col5{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col6{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col11{
#             background-color:  #5353fb;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row2_col14{
#             background-color:  #7474f9;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col0{
#             background-color:  #1717fe;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col1{
#             background-color:  #3d3dfc;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col2{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col3{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col5{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col7{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col8{
#             background-color:  #6969fa;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col9{
#             background-color:  #6d6df9;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col10{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col11{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row3_col13{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col0{
#             background-color:  #7171f9;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col4{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col6{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col8{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col9{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col10{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col12{
#             background-color:  #5959fa;
#             color:  #f1f1f1;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col13{
#             background-color:  #a1a1f7;
#             color:  #000000;
#         }#T_17a41412_484c_11eb_82a0_c49ded8dff66row4_col14{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }</style><table id="T_17a41412_484c_11eb_82a0_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>
# source = ['we', 'can', 'eat', 'apple']
# predicted target = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col0,#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col14{
#             background-color:  #b2b2f6;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col1,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col4,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col5,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col8,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col9,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col11,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col2,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col10,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col12,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col13,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col3,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col6,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col7,#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col14,#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col2,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col3,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col12,#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col14,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col0,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col5,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col6,#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col7,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col9,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col10,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col13,#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col4,#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col1,#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col8,#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col6{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col7{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col10,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col2,#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col7,#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col2,#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col7{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row0_col13{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col1{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col3{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col4{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col8,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col12{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col9{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col11{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row1_col14,#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col4{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col0{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col1{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col5{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col8{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col11{
#             background-color:  #1d1dfe;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row2_col14{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col0{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col1{
#             background-color:  #3434fc;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col2{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col3,#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col5{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col6{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col8{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col9,#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col10{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col11{
#             background-color:  #bbbbf5;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col12{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row3_col13{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col3{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col4{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col5{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col6{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col9{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col10{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col12{
#             background-color:  #4d4dfb;
#             color:  #f1f1f1;
#         }#T_17c36598_484c_11eb_98b7_c49ded8dff66row4_col13{
#             background-color:  #9d9df7;
#             color:  #000000;
# ...
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col1{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col2{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col3,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col12,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col5,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col7,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col8,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col14,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col0,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col9,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col10,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col11,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col13,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col2,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col4,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col1,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col6{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col4,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col6,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col10,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col0,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col1,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col9,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col11,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col5,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col7,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col8,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col12,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col13,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col14,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col2,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col5{
#             background-color:  #2b2bfd;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col7{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col8{
#             background-color:  #7b7bf9;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col9{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col11,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col14,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col3{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row0_col13{
#             background-color:  #2222fd;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col2{
#             background-color:  #4545fb;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col3{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col4{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col6{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col10{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col12{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row1_col13{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col1{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col2{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col3,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col4{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col4{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col6{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col8,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col5{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col12{
#             background-color:  #5353fb;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row2_col14{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col0{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col1{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col5{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col6{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col7{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col9{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col10{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row3_col11{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col0{
#             background-color:  #0c0cfe;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col7,#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col14{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col8{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col9{
#             background-color:  #2d2dfd;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col10{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col11{
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }#T_19f29ef0_484c_11eb_8c40_c49ded8dff66row4_col12{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }</style><table id="T_19f29ef0_484c_11eb_8c40_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19f29ef0_484c_
# source = ['we', 'can', 'eat', 'apple']
# predicted target = ['wir', 'konnen', 'apfel', 'essen', 'apfel', '<eos>']
# Logits
# <style  type="text/css" >
# #T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col0,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col1,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col6,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col9,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col10,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col4,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col11,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col12,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col8,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col13,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col14,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col2,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col3,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row5_col5,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row5_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col2{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col3,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col12,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col13,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col0,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col5,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col7,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col14,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col8,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col2,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col4,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col6,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col9,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col10,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col11,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row5_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col4{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col5{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col7{
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col8{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col11,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col3{
#             background-color:  #afaff6;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row0_col14{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col1{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col2{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col3,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col0{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col6{
#             background-color:  #5d5dfa;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col8{
#             background-color:  #2121fd;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col9{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col10{
#             background-color:  #5555fb;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row1_col13{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col0{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col1{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col2,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col12{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col3{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col4,#T_1a10598a_484c_11eb_86ec_c49ded8dff66row5_col2{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col5{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col6{
#             background-color:  #1111fe;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col7{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col9{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col10{
#             background-color:  #1616fe;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col11{
#             background-color:  #2a2afd;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col12{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col13{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row2_col14{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col1{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col5{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col6{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col7{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col9{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col10{
#             background-color:  #6363fa;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row3_col11{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col0{
#             background-color:  #6f6ff9;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col1{
#             background-color:  #0909ff;
#             color:  #f1f1f1;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col4{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col5{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col7{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col8{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col12{
#             background-color:  #9090f8;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col13{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row4_col14{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row5_col0{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row5_col3{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_1a10598a_484c_11eb_86ec_c49ded8dff66row5_col4{
#             background-color:  #b3b3f6;
#             color:

# %%
_,_,_ = translate_info("we want to eat apple",attention_type=1,draw_charts=True,
                       flow_type=APPLY_NOT_POSITIONWISE)
#_,_,_ = translate_info("we can eat apple",attention_type=1,draw_charts=True,
#                       flow_type=APPLY_NOT_POSITIONWISE)
#_,_,_ = translate_info("we eat apple",attention_type=1,draw_charts=True,flow_type=APPLY_NOT_POSITIONWISE)
# Out:
# source = ['we', 'want', 'to', 'eat', 'apple']
# predicted target = ['wir', 'mochten', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col0,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col13{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col1{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col2{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col3,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col12,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col5,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col7,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col8,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col14,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col0,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col9,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col10,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col11,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col13,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col2,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col4,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col1,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col6{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col4,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col6,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col10,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col0,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col1,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col9,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col11,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col5,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col7,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col8,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col12,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col13,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col14,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col2,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col5{
#             background-color:  #2b2bfd;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col7{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col8{
#             background-color:  #7b7bf9;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col9{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col11,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col14,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col3{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row0_col13{
#             background-color:  #2222fd;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col2{
#             background-color:  #4545fb;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col3{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col4{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col6{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col10{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col12{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row1_col13{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col1{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col2{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col3,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col4{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col4{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col6{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col8,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col5{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col12{
#             background-color:  #5353fb;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row2_col14{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col0{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col1{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col5{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col6{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col7{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col9{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col10{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row3_col11{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col0{
#             background-color:  #0c0cfe;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col7,#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col14{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col8{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col9{
#             background-color:  #2d2dfd;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col10{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col11{
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }#T_1a343c8a_484c_11eb_a525_c49ded8dff66row4_col12{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }</style><table id="T_1a343c8a_484c_11eb_a525_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a343c8a_484c_

# %%
_ = translate_info("i can read book",attention_type=ATTENTION_DEFAULT,draw_charts=True)
#Open to see other samples
#_ = translate_sentence("i can read book",attention_type=ATTENTION_AT_END,draw_charts=True)
#_ = translate_sentence("i want to read apple",attention_type=ATTENTION_DEFAULT,draw_charts=True)
#_ = translate_sentence("i want to eat book",attention_type=ATTENTION_DEFAULT,draw_charts=True)
#_ = translate_sentence("i can eat book",attention_type=ATTENTION_DEFAULT,draw_charts=True)
#attention_types = [1,2,3,4]
#for attention_type in attention_types:
#    _ = translate_sentence("i can eat bread",attention_type=attention_type,draw_charts=True)
#_ = translate_sentence("we beer can read",attention_type=1,draw_charts=True)
# Out:
# source = ['i', 'can', 'read', 'book']
# predicted target = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col0,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col2,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col4,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col5,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col7,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col9,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col11,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col3,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col10,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col12,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col14,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col6,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col8,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col13,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col1,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col5,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col10,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col2,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col3,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col12,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col13,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col14,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col0,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col4,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col8,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col6,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col7,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col9,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col11{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col3{
#             background-color:  #9494f7;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col6{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col7{
#             background-color:  #5656fb;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col8{
#             background-color:  #5858fb;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col9{
#             background-color:  #a1a1f7;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col11,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col6,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col7{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col12{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col13{
#             background-color:  #7575f9;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row0_col14{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col0{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col1{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col4{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col8{
#             background-color:  #2222fd;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row1_col10{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col1,#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col8{
#             background-color:  #9e9ef7;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col2{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col5{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col6{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col7{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col9{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col11{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row2_col13{
#             background-color:  #6969fa;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col0{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col1{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col2{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col3{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col4{
#             background-color:  #7373f9;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col5{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col9{
#             background-color:  #5050fb;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col10{
#             background-color:  #5d5dfa;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col11{
#             background-color:  #2b2bfd;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col12{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row3_col14{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col0{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col2{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col3{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col4{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col5{
#             background-color:  #8282f8;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col10{
#             background-color:  #4d4dfb;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col12{
#             background-color:  #5a5afa;
#             color:  #f1f1f1;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col13{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1a581fe2_484c_11eb_be34_c49ded8dff66row4_col14{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }</style><table id="T_1a581fe2_484c_11eb_be34_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_head

# %%
_ = translate_info("apple eat can we",attention_type=ATTENTION_DEFAULT,draw_charts=True)
### altough order is not correct network can correct it, but this is a bit overfitting
###and it wont happen if we use a big set.
#Open to see other samples
#_ = test_sentence("apple eat we can",attention_type=ATTENTION_DEFAULT,draw_charts=True)
#_ = test_sentence("apple eat can we",attention_type=1,draw_charts=True)
# Out:
# source = ['apple', 'eat', 'can', 'we']
# predicted target = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col0,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col1,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col9,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col10,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col11,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col11,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col12,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col13,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col2,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col3,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col8,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col5,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col6,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col14,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col4,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col2,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col3,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col12,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col0,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col5,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col6,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col7,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col8,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col9,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col10,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col13,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col4,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col1,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col11,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col14{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col4{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col5{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col6{
#             background-color:  #3232fc;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col7{
#             background-color:  #0c0cfe;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col8{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col13{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row0_col14{
#             background-color:  #1414fe;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col1{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col2{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col3{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col4,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col5{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col9,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col4{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col10,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col7{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row1_col14{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col0,#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col0{
#             background-color:  #6767fa;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col1{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col6{
#             background-color:  #5959fa;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col11{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col12{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row2_col14{
#             background-color:  #2828fd;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col1{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col2{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col3{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col7{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col8{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col9{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col10{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col11{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col12{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row3_col13{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col0{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col2{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col3{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col5{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col6{
#             background-color:  #5858fb;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col8{
#             background-color:  #6666fa;
#             color:  #000000;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col9{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col10{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col12{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_1a79b09e_484c_11eb_b644_c49ded8dff66row4_col13{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }</style><table id="T_1a79b09e_484c_11eb_b644_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thea

# %%
#when no object distinctive, if we put all verbs lesen is chosen over others.
_ = translate_info("eat drink read we can",attention_type=ATTENTION_DEFAULT,draw_charts=True)
# Out:
# source = ['eat', 'drink', 'read', 'we', 'can']
# predicted target = ['wir', 'konnen', 'buch', 'lesen', '<eos>']
# Logits
# <style  type="text/css" >
# #T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col0{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col1,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col10,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col12,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col13,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col14,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col4,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col5,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col8,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col11,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col0,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col9,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col2,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col3,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col6,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col7{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col2,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col3,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col0,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col5,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col7,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col9,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col10,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col12,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col14,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col4,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col6,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col8,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col11,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col13,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col4{
#             background-color:  #7171f9;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col5{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col6{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col7,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col8{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col8{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col9{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col10{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col11{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col12{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col13{
#             background-color:  #afaff6;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row0_col14{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col1{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col2{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col3{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col4{
#             background-color:  #4f4ffb;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col6,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col11{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row1_col11{
#             background-color:  #5959fa;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col0{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col1,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col7{
#             background-color:  #9191f8;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col2{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col3{
#             background-color:  #bbbbf5;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col6{
#             background-color:  #6c6cf9;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col9{
#             background-color:  #4b4bfb;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row2_col13{
#             background-color:  #0f0ffe;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col1{
#             background-color:  #8484f8;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col2{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col3{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col5{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col7{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col10{
#             background-color:  #4343fc;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col12{
#             background-color:  #9c9cf7;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row3_col14{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col0{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col4,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col8{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col5,#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col13{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col9{
#             background-color:  #9a9af7;
#             color:  #000000;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col10{
#             background-color:  #4e4efb;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col12{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_1a9c0698_484c_11eb_b2c9_c49ded8dff66row4_col14{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }</style><table id="T_1a9c0698_484c_11eb_b2c9_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eos</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >wir</th>        <th class="col_heading level0 col4" >essen</th>        <th class="col_heading level0 col5" >konnen</th>        <th class="col_heading level0 col6" >lesen</th>        <th class="col_heading level0 col7" >mochten</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >apfel</th>        <th class="col_heading level0 col10" >bier</th>        <th class="col_heading level0 col11" >brot</th>        <th class="col_heading level0 col12" >buch</th>        <th class="col_heading level0 col13" >wasser</th>        <th class="col_heading level0 col14" >zeitung</th>    </tr></thea

# %%
#show self attentions on encoder layer
#we have 36 sentences, change below values to see different sentence over training
#Change range indexes to see others..
for index in range(25,27):
    
    test_logger,all_outputs,_ = translate_info(tabular_set[index].src,draw_charts=False,attention_type=1)
    encoded_attention = test_logger.get_summary(["EncoderLayer@sattention"],show_data=False)        
    
    output_words = ["sos"]+tabular_set[index].src  +["eos"]
    for head_index in range(encoded_attention[0].shape[1]):
        all_outputs0 = encoded_attention[0][:,head_index,:,:]
        draw_df(all_outputs0.squeeze().numpy(),output_words,output_words)
# Out:
# source = ['i', 'eat', 'apple']
# predicted target = ['ich', 'essen', 'apfel', '<eos>']
# <style  type="text/css" >
# #T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col0{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col1,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col4,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col0,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col2,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col3{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col2,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col0{
#             background-color:  #5c5cfa;
#             color:  #f1f1f1;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col3{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col1,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col3{
#             background-color:  #9e9ef7;
#             color:  #000000;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col2{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col3,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col4,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col0,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col1,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col2,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col4,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col0,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col1{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col4{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col1,#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col2{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col3{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }</style><table id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >eat</th>        <th class="col_heading level0 col3" >apple</th>        <th class="col_heading level0 col4" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col0" class="data row0 col0" >0.04</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col1" class="data row0 col1" >0.29</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col2" class="data row0 col2" >0.09</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col3" class="data row0 col3" >0.13</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row0_col4" class="data row0 col4" >0.44</td>
#             </tr>
#             <tr>
#                         <th id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col0" class="data row1 col0" >0.76</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col1" class="data row1 col1" >0.10</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col2" class="data row1 col2" >0.13</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col3" class="data row1 col3" >0.00</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row1_col4" class="data row1 col4" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66level0_row2" class="row_heading level0 row2" >eat</th>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col0" class="data row2 col0" >0.47</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col1" class="data row2 col1" >0.01</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col2" class="data row2 col2" >0.14</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col3" class="data row2 col3" >0.34</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row2_col4" class="data row2 col4" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66level0_row3" class="row_heading level0 row3" >apple</th>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col0" class="data row3 col0" >0.00</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col1" class="data row3 col1" >0.00</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col2" class="data row3 col2" >0.00</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col3" class="data row3 col3" >0.99</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row3_col4" class="data row3 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66level0_row4" class="row_heading level0 row4" >eos</th>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col0" class="data row4 col0" >0.01</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col1" class="data row4 col1" >0.00</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col2" class="data row4 col2" >0.00</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col3" class="data row4 col3" >0.99</td>
#                         <td id="T_1aba847e_484c_11eb_ae1f_c49ded8dff66row4_col4" class="data row4 col4" >0.01</td>
#             </tr>
#     </tbody></table>
# source = ['i', 'drink', 'water']
# predicted target = ['ich', 'trinken', 'wasser', '<eos>']
# <style  type="text/css" >
# #T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col0,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col2,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col3,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col4,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col2,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col1,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col2{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col1{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col2,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col0,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col1,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col4,#T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col3{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col3{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col4{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col0{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col1{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col3{
#             background-color:  #1a1afe;
#             color:  #f1f1f1;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col0{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col1{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col2{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col3{
#             background-color:  #3535fc;
#             color:  #f1f1f1;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col4{
#             background-color:  #2424fd;
#             color:  #f1f1f1;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col0{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col4{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }</style><table id="T_1abf1e82_484c_11eb_8506_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >drink</th>        <th class="col_heading level0 col3" >water</th>        <th class="col_heading level0 col4" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1abf1e82_484c_11eb_8506_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col1" class="data row0 col1" >0.01</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col2" class="data row0 col2" >0.63</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col3" class="data row0 col3" >0.35</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row0_col4" class="data row0 col4" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1abf1e82_484c_11eb_8506_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col0" class="data row1 col0" >0.67</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col1" class="data row1 col1" >0.09</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col2" class="data row1 col2" >0.01</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col3" class="data row1 col3" >0.22</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row1_col4" class="data row1 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1abf1e82_484c_11eb_8506_c49ded8dff66level0_row2" class="row_heading level0 row2" >drink</th>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col0" class="data row2 col0" >0.07</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col1" class="data row2 col1" >0.01</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col2" class="data row2 col2" >0.01</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col3" class="data row2 col3" >0.89</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row2_col4" class="data row2 col4" >0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_1abf1e82_484c_11eb_8506_c49ded8dff66level0_row3" class="row_heading level0 row3" >water</th>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col0" class="data row3 col0" >0.01</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col1" class="data row3 col1" >0.06</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col2" class="data row3 col2" >0.10</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col3" class="data row3 col3" >0.81</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row3_col4" class="data row3 col4" >0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_1abf1e82_484c_11eb_8506_c49ded8dff66level0_row4" class="row_heading level0 row4" >eos</th>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col0" class="data row4 col0" >0.01</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col1" class="data row4 col1" >0.00</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col2" class="data row4 col2" >0.01</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col3" class="data row4 col3" >0.97</td>
#                         <td id="T_1abf1e82_484c_11eb_8506_c49ded8dff66row4_col4" class="data row4 col4" >0.01</td>
#             </tr>
#     </tbody></table>

# %%
last_sentence_original_batch = None

# %%
#collect encoder data
steps_encoder_bysentence = []
LANG = SRC          
last_sentence_encoding_batch = None

for i in range(len(data_pipeline)):
    current_label = data_pipeline[i][0]
    if "encoder@QKV" == current_label: 
         sentence_batch = last_sentence_original_batch
         batch_len = sentence_batch.shape[0]   
         #assert batch_len == len(data_pipeline[i][1] )         
         for sent_index in range(batch_len):  
            sentence = sentence_batch[sent_index]
            data_part = data_pipeline[i][1]
            original_embedding = last_sentence_original_batch[sent_index]
            translation = " ".join( encoding_to_sentence(original_embedding,LANG) )
            dstep = DebugStepWord(sentence,translation)
            dstep.original_embedding = original_embedding 
            dstep.q = data_pipeline[i][1][0][sent_index].squeeze().detach()
            dstep.k = data_pipeline[i][1][1][sent_index].squeeze().detach()
            dstep.v = data_pipeline[i][1][2][sent_index].squeeze().detach()
            dstep.energy = data_pipeline[i][1][4][sent_index].squeeze().detach()
            dstep.attention = data_pipeline[i][1][5][sent_index].squeeze().detach()
            dstep.mask = data_pipeline[i][1][6][sent_index].squeeze().detach()
            dstep.x1 = data_pipeline[i][1][7][sent_index].squeeze().detach()
            steps_encoder_bysentence.append(dstep)
    if "Encoder->attention" == current_label: 
         last_sentence_original_batch = data_pipeline[i][1]

# %%
assert list(steps_encoder_bysentence[0].q.shape) == [7,64]
assert N_EPOCHS * len(steps_encoder_bysentence) * 36
print( " epochs: ",N_EPOCHS , " log length : ", len(steps_encoder_bysentence) )
assert steps_encoder_bysentence[0].v.shape[0] == 7
assert steps_encoder_bysentence[0].v.shape[1] == HID_DIM
# Out:
#  epochs:  30  log length :  1080

# %%
#collect stats by word
steps_encoder_byword = []
for step in steps_encoder_bysentence:
    word_count = step.q.shape[0]
    for i in range(word_count):        
        word_step = DebugStepWord(step.sentence,step.translation)    
        #print("step.q",step.q.shape)
        word_step.q = step.q[i]
        word_step.k = step.k[i]
        word_step.v = step.v[i]
        word_step.energy = step.energy[i]
        word_step.attention = step.attention[i]
        word_step.mask = step.mask[i]
        word_step.x1 = step.x1[i]
        word_step.sentence = step.sentence
        word_step.translation = step.translation
        word_step.word_vector = step.sentence[i]
        word_step.word_embeddding = step.original_embedding[i]
        #print("step.sentence.squeeze()[i]",word_step.word_embeddding )
        word_step.word_translation = encoding_to_word(word_step.word_embeddding,LANG)
        steps_encoder_byword.append( word_step )

# %%
assert steps_encoder_byword[0].q.shape[0] == 64

# %%
#VECTORS CHANGING OVER TIME, change ranks or indexes to see different combinations

#altough "eat" and "we" are same their encodings differ in space, this sample
#has lets distinctive power than others
search_sentence = "we want to eat apple" #"eat","we","apple","want"
steps_for_sample = get_by_word(search_sentence,["we"],steps_encoder_byword)
X_s1,Y_s1 = map_word_by_sentence(steps_for_sample,includes="QKVX",ranks=[1,5,15.20,25,30])

search_sentence2 = "we want to eat bread"
steps_for_sample2 = get_by_word(search_sentence2,["we"],steps_encoder_byword)
X_s2,Y_s2 = map_word_by_sentence(steps_for_sample2,includes="QKVX",ranks=[1,5,15,20,25,30])

Xs = X_s1 + X_s2
Ys = [ s for s in Y_s1] + [ s for s in Y_s2]
color_mapping = [ "#0000ff" for s in Y_s1] + [ "#ff0000" for s in Y_s2]

pca = PCA(n_components=2)
X_transformed = pca.fit_transform(np.array(Xs))
map_on_2d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[12,8]) 

pca = PCA(n_components=3)
X_transformed = pca.fit_transform(np.array(Xs))
map_on_3d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[12,12]) 
###when we are checking encoder self attention, we see that q,v,k is less saturated,more clustered
#because no other source of input,or effect.

# %%
#collect related vectors
def collect_sentence_data(sentences,vector_name,indexes,keywords,use_last_vector=False,dump_result=False):
    print("vector_name",vector_name)
    Xs = []
    Ys = []
    for sentence_index,sentence in enumerate(sentences):
        test_logger,_,translation = translate_info(sentence,attention_type=1,draw_charts=False,dump_result=dump_result)
        x4 = test_logger.get_summary([vector_name],show_data=False,summary_count=10)
        if use_last_vector:
            x4 = x4[len(x4)-1]
        
        for i,index in enumerate(indexes):
            #if use_last_vector it is decoder so we must use result from translation
            if use_last_vector:
                key = translation[index]
            else:    
                key = keywords[i]
            val = x4[0].squeeze()[index].numpy()
            Xs.append(val)
            Ys.append(key+"@"+str(sentence_index+1))
    return Xs,Ys

#dump vectors both on 2d and 3d
def dump_on_surface(Xs,Ys,dump_3d=True,dump_2d=False):
    colors =["#ff0000","#dd0000","#00ffdd","#0000ff","#ffaaaa"] 
    color_mapping = [ colors[ min(len(colors)-1, int(y.split("@")[1])-1) ] for y in Ys]
    #print(color_mapping)
                             
    if dump_3d:    
        pca = PCA(n_components=3)
        X_transformed = pca.fit_transform(np.array(Xs))
        map_on_3d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[10,10])
    if dump_2d:    
        pca = PCA(n_components=2)
        X_transformed = pca.fit_transform(np.array(Xs))
        map_on_2d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[10,10])

# %%
#For 5 sentences, focus on 2 words on dump their projection and see 
#how model generates different vectors for them     
test_sentences = ["i can eat apple","i can eat bread","i can eat book","i can eat newspaper","i can eat apple book"]

indexes = [2,3]
keywords = ["can","eat"]

Xs,Ys = collect_sentence_data(test_sentences,"encoder@Q",indexes,keywords,dump_result=True)
dump_on_surface( Xs,Ys )
Xs,Ys = collect_sentence_data(test_sentences,"encoder@K",indexes,keywords)
dump_on_surface( Xs,Ys )
Xs,Ys = collect_sentence_data(test_sentences,"encoder@V",indexes,keywords)
dump_on_surface( Xs,Ys )
Xs,Ys = collect_sentence_data(test_sentences,"encoder@x1",indexes,keywords)
dump_on_surface( Xs,Ys )
Xs,Ys = collect_sentence_data(test_sentences,"encoder@x4",indexes,keywords)
dump_on_surface( Xs,Ys )

Xs,Ys = collect_sentence_data(test_sentences,"Encoder@src_final",indexes,keywords)
dump_on_surface( Xs,Ys )
# Out:
# vector_name encoder@Q
# source = ['i', 'can', 'eat', 'apple']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'bread']
# predicted target = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'book']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'newspaper']
# predicted target = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'apple', 'book']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# vector_name encoder@K
# vector_name encoder@V
# vector_name encoder@x1
# vector_name encoder@x4
# vector_name Encoder@src_final

# %%
#Do the same for decoder side , this time no need to give keywords


test_sentences = ["i can eat apple","i can eat bread","i can eat book","i can eat newspaper","i can eat apple book"]

indexes = [1,3]
keywords = None

Xs,Ys = collect_sentence_data(test_sentences,"decoder_encoder_attention@Q",indexes,keywords,use_last_vector=True,dump_result=True)
dump_on_surface( Xs,Ys )
Xs,Ys = collect_sentence_data(test_sentences,"decoder_encoder_attention@K",indexes,keywords,use_last_vector=True)
dump_on_surface( Xs,Ys )
Xs,Ys = collect_sentence_data(test_sentences,"decoder_encoder_attention@V",indexes,keywords,use_last_vector=True)
dump_on_surface( Xs,Ys )

Xs,Ys = collect_sentence_data(test_sentences,"decoder_encoder_attention@x4",indexes,keywords,use_last_vector=True)
dump_on_surface( Xs,Ys )

Xs,Ys = collect_sentence_data(test_sentences,"Decoder@output",indexes,keywords,use_last_vector=True)
dump_on_surface( Xs,Ys )
# Out:
# vector_name decoder_encoder_attention@Q
# source = ['i', 'can', 'eat', 'apple']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'bread']
# predicted target = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'book']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'newspaper']
# predicted target = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'apple', 'book']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# vector_name decoder_encoder_attention@K
# vector_name decoder_encoder_attention@V
# vector_name decoder_encoder_attention@x4
# vector_name Decoder@output

# %%
#how does encoding of EAT changes according to time
#lets do over over simplifaction and map is to 1d
search_sentence = "we can eat apple"
steps_for_sample = get_by_word(search_sentence,["eat","apple"],steps_encoder_byword)
X_s1,Y_s1 = map_word_by_sentence(steps_for_sample,includes="QVKX",ranks=[1,15,29])

X1d,Y1d = filter_by_key(X_s1,Y_s1,["eat"])
pca = PCA(n_components=1)
X_transformed = pca.fit_transform(np.array(X1d))
X_transformed = [x[0] for x in X_transformed]

df = pd.DataFrame()


mapped_vals = get_as_map(X_transformed,Y1d,["eat@Q@1","eat@K@1","eat@V@1","eat@X1@1"])


mapped_vals["qvk"] = mapped_vals["eat@Q@1"] * mapped_vals["eat@K@1"] * mapped_vals["eat@V@1"] 
df["apple_0"] = mapped_vals.keys()
df["apple_0 values"] = mapped_vals.values()

mapped_vals = get_as_map(X_transformed,Y1d,["eat@Q@29","eat@K@29","eat@V@29","eat@X1@29"])

mapped_vals["qvk"] = mapped_vals["eat@Q@29"] * mapped_vals["eat@K@29"] * mapped_vals["eat@V@29"] 


df["apple_29"] = mapped_vals.keys()
df["apple_29 values"] = mapped_vals.values()

#----------------------------
search_sentence = "we can eat bread"
steps_for_sample = get_by_word(search_sentence,["eat","bread"],steps_encoder_byword)
X_s1,Y_s1 = map_word_by_sentence(steps_for_sample,includes="QVKX",ranks=[1,15,29])

X1d,Y1d = filter_by_key(X_s1,Y_s1,["eat"])
pca = PCA(n_components=1)
X_transformed = pca.fit_transform(np.array(X1d))
X_transformed = [x[0] for x in X_transformed]

mapped_vals = get_as_map(X_transformed,Y1d,["eat@Q@1","eat@K@1","eat@V@1","eat@X1@1"])
#print("---mapped_vals",mapped_vals.keys())

mapped_vals["qvk"] = mapped_vals["eat@Q@1"] * mapped_vals["eat@K@1"] * mapped_vals["eat@V@1"] 
df["bread_0"] = mapped_vals.keys()
df["bread_0 values"] = mapped_vals.values()

mapped_vals = get_as_map(X_transformed,Y1d,["eat@Q@29","eat@K@29","eat@V@29","eat@X1@29"])
mapped_vals["qvk"] = mapped_vals["eat@Q@29"] * mapped_vals["eat@K@29"] * mapped_vals["eat@V@29"] 

df["bread_29"] = mapped_vals.keys()
df["bread_29 values"] = mapped_vals.values()
df.head(5)
#at 0 values are -195 and 81 = distance 276 
#at 29           -218 and 43 = distance 261
# Out:
#     apple_0  apple_0 values   apple_29  apple_29 values   bread_0  \
# 0   eat@Q@1            3.06   eat@Q@29             3.86   eat@Q@1
# 1   eat@K@1            8.01   eat@K@29             7.98   eat@K@1
# 2   eat@V@1           -7.97   eat@V@29            -7.09   eat@V@1
# 3  eat@X1@1           -4.36  eat@X1@29            -4.03  eat@X1@1
# 4       qvk         -195.52        qvk          -218.80       qvk
#
#    bread_0 values   bread_29  bread_29 values
# 0           -1.19   eat@Q@29            -0.72
# 1           -7.93   eat@K@29            -7.48
# 2            8.69   eat@V@29             8.11
# 3            0.68  eat@X1@29            -0.34
# 4           81.86        qvk            43.38

# %%
test_sentences = ["i can eat apple","i can eat bread"]

indexes = [0,1,2,3,4]
keywords = None
    
Xs,Ys = collect_sentence_data(test_sentences,"Decoder@trg_embedding",indexes,keywords,use_last_vector=True,dump_result=True)
dump_on_surface( Xs,Ys )
# Out:
# vector_name Decoder@trg_embedding
# source = ['i', 'can', 'eat', 'apple']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'bread']
# predicted target = ['ich', 'konnen', 'brot', 'essen', '<eos>']

# %%
test_sentences = ["i can eat apple","i can eat bread"]
indexes = [2,3]
keywords = ["can","eat"]
    
Xs,Ys = collect_sentence_data(test_sentences,"Encoder@src_embedding",indexes,keywords,use_last_vector=False,dump_result=True)
dump_on_surface( Xs,Ys )
# Out:
# vector_name Encoder@src_embedding
# source = ['i', 'can', 'eat', 'apple']
# predicted target = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# source = ['i', 'can', 'eat', 'bread']
# predicted target = ['ich', 'konnen', 'brot', 'essen', '<eos>']

# %%
#check distribution of all source language vectors
encoder_embedding = model.encoder.tok_embedding
Xs_src = []
Ys_src = []
for key_index,key in enumerate(SRC.vocab.stoi.keys()):
    if key_index < 18:
        input = torch.LongTensor([key_index])
        
        Xs_src.append( encoder_embedding(input).detach().numpy().flatten() )
        Ys_src.append(key+"@"+str(key_index))
dump_on_surface( Xs_src,Ys_src )

# %%
#check distribution of all target language vectors
decoder_embedding = model.decoder.tok_embedding
Xs_trg = []
Ys_trg = []
for key_index,key in enumerate(TRG.vocab.stoi.keys()):
    
    input = torch.LongTensor([key_index])
    Xs_trg.append( decoder_embedding(input).detach().numpy().flatten() )
    Ys_trg.append(key+"@"+str(key_index))
dump_on_surface( Xs_trg,Ys_trg )

# %%
#check similarity or source and tagrget vectors
from sklearn.metrics.pairwise import cosine_similarity
datas = []
for trg_index, y_trg in enumerate(Ys_trg[6:]):
    row_data = []
    for src_index,y_src in enumerate(Ys_src[6:]):
        cell_value = cosine_similarity( Xs_trg[6:][trg_index].reshape(1,64) , Xs_src[6:][src_index].reshape(1,64)  )[0][0]
        row_data.append(cell_value)
    datas.append( row_data )    

draw_df(datas,columns=Ys_src[6:],indexes=Ys_trg[6:])
# Out:
# <style  type="text/css" >
# #T_1df59436_484c_11eb_990d_c49ded8dff66row0_col0{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col1,#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col7{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col2,#T_1df59436_484c_11eb_990d_c49ded8dff66row7_col6{
#             background-color:  #6c6cf9;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col3{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col4{
#             background-color:  #1a1afe;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col5{
#             background-color:  #3636fc;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col6,#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col1,#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col5,#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col9,#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col3,#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col2,#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col7,#T_1df59436_484c_11eb_990d_c49ded8dff66row6_col4,#T_1df59436_484c_11eb_990d_c49ded8dff66row6_col8,#T_1df59436_484c_11eb_990d_c49ded8dff66row9_col0,#T_1df59436_484c_11eb_990d_c49ded8dff66row9_col11,#T_1df59436_484c_11eb_990d_c49ded8dff66row10_col10{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col7{
#             background-color:  #3c3cfc;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col8,#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col0,#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col3,#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col11,#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col6,#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col1,#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col2,#T_1df59436_484c_11eb_990d_c49ded8dff66row6_col7,#T_1df59436_484c_11eb_990d_c49ded8dff66row8_col4,#T_1df59436_484c_11eb_990d_c49ded8dff66row8_col5,#T_1df59436_484c_11eb_990d_c49ded8dff66row8_col10,#T_1df59436_484c_11eb_990d_c49ded8dff66row9_col9{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col9,#T_1df59436_484c_11eb_990d_c49ded8dff66row7_col3{
#             background-color:  #2222fd;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col10{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row0_col11{
#             background-color:  #2020fd;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col1,#T_1df59436_484c_11eb_990d_c49ded8dff66row7_col0{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col2{
#             background-color:  #2b2bfd;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col4,#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col8{
#             background-color:  #6f6ff9;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col5,#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col10{
#             background-color:  #9494f7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col6{
#             background-color:  #2f2ffd;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col7{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col8,#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col8,#T_1df59436_484c_11eb_990d_c49ded8dff66row8_col6{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row1_col9{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col0,#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col11{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col2,#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col11{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col3{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col4,#T_1df59436_484c_11eb_990d_c49ded8dff66row9_col6{
#             background-color:  #7575f9;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col9{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row2_col10{
#             background-color:  #8282f8;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col0,#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col11{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col1,#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col4{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col2{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col3{
#             background-color:  #5151fb;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col5{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col6{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col7{
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col8{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col10{
#             background-color:  #1d1dfe;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row3_col11{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col0,#T_1df59436_484c_11eb_990d_c49ded8dff66row10_col0{
#             background-color:  #5d5dfa;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col4{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col5{
#             background-color:  #8080f8;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col6{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col7,#T_1df59436_484c_11eb_990d_c49ded8dff66row7_col8{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col9{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row4_col10{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col0,#T_1df59436_484c_11eb_990d_c49ded8dff66row6_col6{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col1{
#             background-color:  #6565fa;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col3{
#             background-color:  #9191f8;
#             color:  #000000;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col4{
#             background-color:  #3f3ffc;
#             color:  #f1f1f1;
#         }#T_1df59436_484c_11eb_990d_c49ded8dff66row5_col5{
#             background-color:

# %%
#check similarity  target vectors with each other, as expected diagonal is 1
datas = []
for trg_index, y_trg in enumerate(Ys_trg[4:]):
    row_data = []
    for src_index,y_src in enumerate(Ys_trg[4:]):
        cell_value = cosine_similarity( Xs_trg[4:][trg_index].reshape(1,64) , Xs_trg[4:][src_index].reshape(1,64)  )[0][0]
        row_data.append(cell_value)
    datas.append( row_data )    

draw_df(datas,columns=Ys_trg[4:],indexes=Ys_trg[4:]) 
np.array(datas).shape
# Out:
# <style  type="text/css" >
# #T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col0,#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col1,#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col2,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col3,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col4,#T_1e01c634_484c_11eb_af26_c49ded8dff66row5_col5,#T_1e01c634_484c_11eb_af26_c49ded8dff66row6_col6,#T_1e01c634_484c_11eb_af26_c49ded8dff66row7_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row8_col8,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col9,#T_1e01c634_484c_11eb_af26_c49ded8dff66row10_col10,#T_1e01c634_484c_11eb_af26_c49ded8dff66row11_col11,#T_1e01c634_484c_11eb_af26_c49ded8dff66row12_col12{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col1,#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col0{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col2,#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col11,#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col0,#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col8,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col6,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col1,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col10,#T_1e01c634_484c_11eb_af26_c49ded8dff66row6_col3,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col5,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col12,#T_1e01c634_484c_11eb_af26_c49ded8dff66row10_col3,#T_1e01c634_484c_11eb_af26_c49ded8dff66row10_col4,#T_1e01c634_484c_11eb_af26_c49ded8dff66row11_col5,#T_1e01c634_484c_11eb_af26_c49ded8dff66row12_col9{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col3,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col0{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col4,#T_1e01c634_484c_11eb_af26_c49ded8dff66row5_col10,#T_1e01c634_484c_11eb_af26_c49ded8dff66row5_col12,#T_1e01c634_484c_11eb_af26_c49ded8dff66row7_col11{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col5,#T_1e01c634_484c_11eb_af26_c49ded8dff66row6_col0{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col6,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col8,#T_1e01c634_484c_11eb_af26_c49ded8dff66row5_col2,#T_1e01c634_484c_11eb_af26_c49ded8dff66row12_col5{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row7_col4,#T_1e01c634_484c_11eb_af26_c49ded8dff66row10_col5{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col8,#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col4,#T_1e01c634_484c_11eb_af26_c49ded8dff66row5_col8{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col9,#T_1e01c634_484c_11eb_af26_c49ded8dff66row8_col11,#T_1e01c634_484c_11eb_af26_c49ded8dff66row11_col1{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col10{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row0_col12{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col2,#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col1{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col3,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col1,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col12,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col6,#T_1e01c634_484c_11eb_af26_c49ded8dff66row11_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row12_col1{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col4,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col10{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col5,#T_1e01c634_484c_11eb_af26_c49ded8dff66row6_col11,#T_1e01c634_484c_11eb_af26_c49ded8dff66row8_col2,#T_1e01c634_484c_11eb_af26_c49ded8dff66row10_col6{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col6,#T_1e01c634_484c_11eb_af26_c49ded8dff66row6_col1{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col8,#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col11,#T_1e01c634_484c_11eb_af26_c49ded8dff66row5_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row5_col9,#T_1e01c634_484c_11eb_af26_c49ded8dff66row11_col10{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col9,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col9,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col4,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col11{
#             background-color:  #a1a1f7;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col10,#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col11,#T_1e01c634_484c_11eb_af26_c49ded8dff66row11_col12{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row1_col12,#T_1e01c634_484c_11eb_af26_c49ded8dff66row6_col9{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col3,#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col2,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col0{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col5,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col12{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col6,#T_1e01c634_484c_11eb_af26_c49ded8dff66row6_col2{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col7{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col9,#T_1e01c634_484c_11eb_af26_c49ded8dff66row8_col3,#T_1e01c634_484c_11eb_af26_c49ded8dff66row10_col2{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col10{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row2_col12{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col4{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col5,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col3{
#             background-color:  #bbbbf5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row4_col0,#T_1e01c634_484c_11eb_af26_c49ded8dff66row8_col0,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col2,#T_1e01c634_484c_11eb_af26_c49ded8dff66row10_col7{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col8{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_1e01c634_484c_11eb_af26_c49ded8dff66row3_col11,#T_1e01c634_484c_11eb_af26_c49ded8dff66row9_col7,#T_1e01c634_484c_11eb_af26_c49ded8dff66row12_col11{
#             background-color:  #cecef4;
#             color:
# (13, 13)

# %%
#check similarity  source vectors with each other, as expected diagonal is 1
datas = []
for trg_index, y_trg in enumerate(Ys_src[4:]):
    row_data = []
    for src_index,y_src in enumerate(Ys_src[4:]):
        cell_value = cosine_similarity( Xs_src[4:][trg_index].reshape(1,64) , Xs_src[4:][src_index].reshape(1,64)  )[0][0]
        if trg_index == src_index:
            cell_value = cell_value #0
        row_data.append(cell_value )
    datas.append( row_data )    

draw_df(datas,columns=Ys_src[4:],indexes=Ys_src[4:]) 
np.array(datas).shape
# Out:
# <style  type="text/css" >
# #T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col0,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col1,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col2,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row3_col3,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row4_col4,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col5,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row6_col6,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row7_col7,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row8_col8,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row9_col9,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row10_col10,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row11_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col12,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col13{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col1,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row11_col2,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col8,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col1,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col9{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col2,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col0,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row6_col8{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col3,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row10_col8{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col4,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col11{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col5,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col12,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col13,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col8,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col9,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col12,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col4,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row7_col10,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row7_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row8_col6,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row9_col1,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row11_col3,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row11_col7,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col0,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col2{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col6,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col2,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col10,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row6_col13,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row8_col2{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col7,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col3{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col8{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col9,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col4,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row11_col1{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col10{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row0_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col13,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row6_col10,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row7_col2,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col9,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col11{
#             background-color:  #d4d4f4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col0,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col12,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row8_col11{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col3,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row3_col4,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row6_col7,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row9_col13,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row10_col5{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col4,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row7_col9,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row10_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col12{
#             background-color:  #bcbcf5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col5,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row4_col0{
#             background-color:  #9191f8;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col6,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col12,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col0,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col6{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col7,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row6_col5{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col10,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col3{
#             background-color:  #a1a1f7;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col11{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row1_col13,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row3_col5,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row8_col0{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col1,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row4_col2,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row7_col8,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row8_col4,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row9_col3,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col5{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col5{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col6,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row4_col3{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col7,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row12_col5{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col8,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col3,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row7_col13,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row8_col10,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row9_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row9_col12,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row10_col9{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col9,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col2{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row3_col2{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row2_col13,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row4_col8,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row13_col6{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row3_col0,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row4_col11,#T_1e1415a4_484c_11eb_94c3_c49ded8dff66row5_col6,#T_1e1415a4_484c_11eb_94c3_c49ded8df
# (14, 14)

# %%
#check similarity of vectors generated by 2 sentences
def dump_vector_relation(sentences,vector_name,is_q=False,dump_vector=False):
    print("sentence  :",sentences[0])
    print("sentence  :",sentences[1])
    print("Vector :",vector_name)
    test_logger1,_,t1 = translate_info(sentences[0],attention_type=1,draw_charts=False,dump_result=False)
    val1 = test_logger1.get_summary([vector_name],show_data=False,summary_count=10)

    test_logger2,_,t2 = translate_info(sentences[1],attention_type=1,draw_charts=False,dump_result=False)
    val2 = test_logger2.get_summary([vector_name],show_data=False,summary_count=10)

    data1 = val1[len(val1)-1][0][0]
    data2 = val2[len(val1)-1][0][0]
    
    
    if vector_name.find("x4") > 0:
        data1 = val1[len(val1)-1][0]
        data2 = val2[len(val2)-1][0]
    
    if dump_vector:
        print("data1")
        print(data1)
        print("data2")
        print(data2)
        
    data_matrix = []
    for i in range(data1.shape[0] ):
        sub_data = []
        for j in range(data2.shape[0] ):
            shape_new = data1[i].shape[0]
            sub_data.append( cosine_similarity(data1[i].reshape(1,shape_new), data2[j].reshape(1,shape_new))[0][0] )
        data_matrix.append( sub_data )
    
    
    columns = ["sos"] + sentences[1].split(" ") + ["eos"]
    indexes = ["sos"] + sentences[0].split(" ") + ["eos"]
    if is_q :
        columns = ["sos"] + t2[:-1] + ["eos"]
        indexes = ["sos"] + t1[:-1] + ["eos"]
        columns = [ columns[i]+"->"+columns[i+1] for i in range(len(columns)-1) ]
        indexes = [ indexes[i]+"->"+indexes[i+1] for i in range(len(indexes)-1) ]
        
        
    
        
    draw_df(data_matrix,columns=columns,indexes=indexes) 
    return 0

# %%
   
sentences = ["we can eat apple","we can read bread"]


dump_vector_relation(sentences,"decoder_encoder_attention@x4",True)

dump_vector_relation(sentences,"decoder_encoder_attention@Q",True)

dump_vector_relation(sentences,"decoder_encoder_attention@K")

dump_vector_relation(sentences,"decoder_encoder_attention@V")

dump_vector_relation(sentences,"decoder_encoder_attention@attention",True)



#Q depends on output itself, it is query so always same values
#K  features learned, how output aligns with input
#V  QxK , multiplication of query x features,what was learned

test_logger1,_,t1 = translate_info(sentences[0],attention_type=1,draw_charts=False,dump_result=False)
val1 = test_logger1.get_summary(["decoder_encoder_attention@attention"],show_data=False,summary_count=10)


test_logger2,_,t2 = translate_info(sentences[1],attention_type=1,draw_charts=False,dump_result=False)
val2 = test_logger2.get_summary(["decoder_encoder_attention@attention"],show_data=False,summary_count=10)
# Out:
# sentence  : we can eat apple
# sentence  : we can read bread
# Vector : decoder_encoder_attention@x4
# <style  type="text/css" >
# #T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col0,#T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col2,#T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col3,#T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col1,#T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col1,#T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col3,#T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col4,#T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col0,#T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col2{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col4{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col0,#T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col3{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col2{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col3{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col0,#T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col2{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col1{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col3{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col4,#T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col4{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col0{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col1{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col2{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col1{
#             background-color:  #a1a1f7;
#             color:  #000000;
#         }</style><table id="T_1e24d214_484c_11eb_9865_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->zeitung</th>        <th class="col_heading level0 col3" >zeitung->lesen</th>        <th class="col_heading level0 col4" >lesen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e24d214_484c_11eb_9865_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col1" class="data row0 col1" >-0.14</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col2" class="data row0 col2" >0.35</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col3" class="data row0 col3" >0.23</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row0_col4" class="data row0 col4" >0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_1e24d214_484c_11eb_9865_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col0" class="data row1 col0" >-0.15</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col2" class="data row1 col2" >-0.13</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col3" class="data row1 col3" >-0.11</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row1_col4" class="data row1 col4" >0.63</td>
#             </tr>
#             <tr>
#                         <th id="T_1e24d214_484c_11eb_9865_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col0" class="data row2 col0" >-0.35</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col1" class="data row2 col1" >0.22</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col2" class="data row2 col2" >-0.31</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col3" class="data row2 col3" >-0.16</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row2_col4" class="data row2 col4" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_1e24d214_484c_11eb_9865_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col0" class="data row3 col0" >-0.03</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col1" class="data row3 col1" >0.15</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col2" class="data row3 col2" >-0.31</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col3" class="data row3 col3" >-0.25</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row3_col4" class="data row3 col4" >-0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_1e24d214_484c_11eb_9865_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col0" class="data row4 col0" >-0.42</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col1" class="data row4 col1" >0.24</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col2" class="data row4 col2" >-0.35</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col3" class="data row4 col3" >-0.16</td>
#                         <td id="T_1e24d214_484c_11eb_9865_c49ded8dff66row4_col4" class="data row4 col4" >0.03</td>
#             </tr>
#     </tbody></table>
# sentence  : we can eat apple
# sentence  : we can read bread
# Vector : decoder_encoder_attention@Q
# <style  type="text/css" >
# #T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col0,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col1,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col2,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col3,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col1,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col3{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col2{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col3,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col2,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col1,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col4,#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col4{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col0{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col3{
#             background-color:  #7676f9;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col4{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col0{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col0{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col2{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col3{
#             background-color:  #7373f9;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col2{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col4{
#             background-color:  #3939fc;
#             color:  #f1f1f1;
#         }</style><table id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->zeitung</th>        <th class="col_heading level0 col3" >zeitung->lesen</th>        <th class="col_heading level0 col4" >lesen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col1" class="data row0 col1" >0.25</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col2" class="data row0 col2" >-0.09</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col3" class="data row0 col3" >-0.35</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row0_col4" class="data row0 col4" >-0.06</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col0" class="data row1 col0" >0.25</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col2" class="data row1 col2" >-0.30</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col3" class="data row1 col3" >0.01</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row1_col4" class="data row1 col4" >-0.13</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col0" class="data row2 col0" >-0.09</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col1" class="data row2 col1" >-0.30</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col3" class="data row2 col3" >0.35</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row2_col4" class="data row2 col4" >0.24</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col0" class="data row3 col0" >-0.14</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col1" class="data row3 col1" >-0.09</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col2" class="data row3 col2" >-0.16</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col3" class="data row3 col3" >0.02</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row3_col4" class="data row3 col4" >-0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col0" class="data row4 col0" >-0.33</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col1" class="data row4 col1" >-0.27</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col2" class="data row4 col2" >-0.18</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col3" class="data row4 col3" >-0.06</td>
#                         <td id="T_1e2d40b6_484c_11eb_a870_c49ded8dff66row4_col4" class="data row4 col4" >0.14</td>
#             </tr>
#     </tbody></table>
# sentence  : we can eat apple
# sentence  : we can read bread
# Vector : decoder_encoder_attention@K
# <style  type="text/css" >
# #T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col0,#T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col1,#T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col2,#T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col3,#T_1e35a106_484c_11eb_9469_c49ded8dff66row5_col4,#T_1e35a106_484c_11eb_9469_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col1,#T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col0,#T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col2,#T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col5,#T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col4,#T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col5,#T_1e35a106_484c_11eb_9469_c49ded8dff66row5_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col2,#T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col3{
#             background-color:  #afaff6;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col4{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col5{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col3{
#             background-color:  #7b7bf9;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col4{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col0{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col3{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col0{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col1{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col2{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col3{
#             background-color:  #0909ff;
#             color:  #f1f1f1;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col4{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col5{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col0{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col1{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col2{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col4{
#             background-color:  #0606ff;
#             color:  #f1f1f1;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col5{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row5_col0{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row5_col1{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1e35a106_484c_11eb_9469_c49ded8dff66row5_col2{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }</style><table id="T_1e35a106_484c_11eb_9469_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >read</th>        <th class="col_heading level0 col4" >bread</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e35a106_484c_11eb_9469_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col0" class="data row0 col0" >0.66</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col1" class="data row0 col1" >-0.31</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col2" class="data row0 col2" >0.07</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col3" class="data row0 col3" >-0.05</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col4" class="data row0 col4" >0.14</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row0_col5" class="data row0 col5" >0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_1e35a106_484c_11eb_9469_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col0" class="data row1 col0" >-0.17</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col2" class="data row1 col2" >-0.27</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col3" class="data row1 col3" >-0.01</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col4" class="data row1 col4" >-0.05</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row1_col5" class="data row1 col5" >-0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_1e35a106_484c_11eb_9469_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col0" class="data row2 col0" >-0.14</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col1" class="data row2 col1" >-0.28</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col3" class="data row2 col3" >-0.08</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col4" class="data row2 col4" >-0.27</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row2_col5" class="data row2 col5" >-0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_1e35a106_484c_11eb_9469_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col0" class="data row3 col0" >0.16</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col1" class="data row3 col1" >0.06</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col2" class="data row3 col2" >0.05</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col3" class="data row3 col3" >0.08</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col4" class="data row3 col4" >0.02</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row3_col5" class="data row3 col5" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_1e35a106_484c_11eb_9469_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col0" class="data row4 col0" >0.20</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8dff66row4_col1" class="data row4 col1" >-0.27</td>
#                         <td id="T_1e35a106_484c_11eb_9469_c49ded8
# sentence  : we can eat apple
# sentence  : we can read bread
# Vector : decoder_encoder_attention@V
# <style  type="text/css" >
# #T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col0,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col1,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col3,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col2,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col4,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col1{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col2{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col3{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col4{
#             background-color:  #1515fe;
#             color:  #f1f1f1;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col5{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col0,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col0{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col2,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col5,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col0,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col4,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row5_col1,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row5_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col4{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col1{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col3{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col5{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col0{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col1{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col2{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col3{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col5{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col1{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col2{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col3,#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row5_col0{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col4{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col5{
#             background-color:  #7070f9;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row5_col2{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_1e3dfed8_484c_11eb_b633_c49ded8dff66row5_col4{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }</style><table id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >read</th>        <th class="col_heading level0 col4" >bread</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col0" class="data row0 col0" >0.55</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col1" class="data row0 col1" >-0.27</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col2" class="data row0 col2" >0.14</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col3" class="data row0 col3" >-0.04</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col4" class="data row0 col4" >0.16</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row0_col5" class="data row0 col5" >0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col0" class="data row1 col0" >-0.12</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col2" class="data row1 col2" >-0.13</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col3" class="data row1 col3" >0.34</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col4" class="data row1 col4" >-0.03</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row1_col5" class="data row1 col5" >-0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col0" class="data row2 col0" >-0.20</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col1" class="data row2 col1" >-0.14</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col3" class="data row2 col3" >-0.01</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col4" class="data row2 col4" >-0.10</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row2_col5" class="data row2 col5" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col0" class="data row3 col0" >0.06</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col1" class="data row3 col1" >-0.10</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col2" class="data row3 col2" >0.11</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col3" class="data row3 col3" >-0.14</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col4" class="data row3 col4" >0.19</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row3_col5" class="data row3 col5" >-0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col0" class="data row4 col0" >-0.12</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49ded8dff66row4_col1" class="data row4 col1" >-0.14</td>
#                         <td id="T_1e3dfed8_484c_11eb_b633_c49de
# sentence  : we can eat apple
# sentence  : we can read bread
# Vector : decoder_encoder_attention@attention
# <style  type="text/css" >
# #T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col0,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col1,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col4,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col2,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col3{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col1,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col2,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col3,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col4,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col2{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col3{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col0,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col0{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col1{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col2{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col3{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col4{
#             background-color:  #8080f8;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col1,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col0,#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col4{
#             background-color:  #3838fc;
#             color:  #f1f1f1;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col2{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col3{
#             background-color:  #7474f9;
#             color:  #000000;
#         }#T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col4{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }</style><table id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->zeitung</th>        <th class="col_heading level0 col3" >zeitung->lesen</th>        <th class="col_heading level0 col4" >lesen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col1" class="data row0 col1" >0.01</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col2" class="data row0 col2" >0.02</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col3" class="data row0 col3" >0.05</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row0_col4" class="data row0 col4" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col0" class="data row1 col0" >0.01</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col2" class="data row1 col2" >0.04</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col3" class="data row1 col3" >0.13</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row1_col4" class="data row1 col4" >0.80</td>
#             </tr>
#             <tr>
#                         <th id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col0" class="data row2 col0" >0.06</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col1" class="data row2 col1" >0.10</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col2" class="data row2 col2" >0.12</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col3" class="data row2 col3" >0.45</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row2_col4" class="data row2 col4" >0.39</td>
#             </tr>
#             <tr>
#                         <th id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col0" class="data row3 col0" >0.06</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col1" class="data row3 col1" >0.04</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col2" class="data row3 col2" >0.99</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col3" class="data row3 col3" >0.92</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row3_col4" class="data row3 col4" >0.62</td>
#             </tr>
#             <tr>
#                         <th id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col0" class="data row4 col0" >0.04</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col1" class="data row4 col1" >0.04</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col2" class="data row4 col2" >0.08</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col3" class="data row4 col3" >0.50</td>
#                         <td id="T_1e4734ba_484c_11eb_85f1_c49ded8dff66row4_col4" class="data row4 col4" >0.23</td>
#             </tr>
#     </tbody></table>

# %%
#same sentence all diagonals must be same
sentences = ["we can eat apple","we can eat apple"]

dump_vector_relation(sentences,"decoder_encoder_attention@Q",True)

dump_vector_relation(sentences,"decoder_encoder_attention@K")

dump_vector_relation(sentences,"decoder_encoder_attention@V")

dump_vector_relation(sentences,"decoder_encoder_attention@x4",True)
# Out:
# sentence  : we can eat apple
# sentence  : we can eat apple
# Vector : decoder_encoder_attention@Q
# <style  type="text/css" >
# #T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col0,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col1,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col2,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col3,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col1{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col2{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col3{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col4,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col2,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col1,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col3,#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col0{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col3{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col4{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col0{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col0{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col2{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col4{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col2{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col3{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }</style><table id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->apfel</th>        <th class="col_heading level0 col3" >apfel->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col1" class="data row0 col1" >0.25</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col2" class="data row0 col2" >-0.09</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col3" class="data row0 col3" >-0.14</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row0_col4" class="data row0 col4" >-0.33</td>
#             </tr>
#             <tr>
#                         <th id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col0" class="data row1 col0" >0.25</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col2" class="data row1 col2" >-0.30</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col3" class="data row1 col3" >-0.09</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row1_col4" class="data row1 col4" >-0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col0" class="data row2 col0" >-0.09</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col1" class="data row2 col1" >-0.30</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col3" class="data row2 col3" >-0.16</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row2_col4" class="data row2 col4" >-0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col0" class="data row3 col0" >-0.14</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col1" class="data row3 col1" >-0.09</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col2" class="data row3 col2" >-0.16</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row3_col4" class="data row3 col4" >0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col0" class="data row4 col0" >-0.33</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col1" class="data row4 col1" >-0.27</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col2" class="data row4 col2" >-0.18</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col3" class="data row4 col3" >0.19</td>
#                         <td id="T_1e573bac_484c_11eb_b6e6_c49ded8dff66row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>
# sentence  : we can eat apple
# sentence  : we can eat apple
# Vector : decoder_encoder_attention@K
# <style  type="text/css" >
# #T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col0,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col1,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col2,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col3,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col4,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col1,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col0,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col2,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col4,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col5,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col2{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col3{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col4{
#             background-color:  #6161fa;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col5{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col3{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col0{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col1{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col4,#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col2{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col5{
#             background-color:  #d4d4f4;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col0{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col1{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col2{
#             background-color:  #b2b2f6;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col4{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col5{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col0{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col3{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col5{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row5_col0{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row5_col1{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row5_col2{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row5_col3{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row5_col4{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }</style><table id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >apple</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col1" class="data row0 col1" >-0.30</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col2" class="data row0 col2" >0.08</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col3" class="data row0 col3" >0.32</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col4" class="data row0 col4" >0.49</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row0_col5" class="data row0 col5" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col0" class="data row1 col0" >-0.30</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col2" class="data row1 col2" >-0.27</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col3" class="data row1 col3" >0.07</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col4" class="data row1 col4" >-0.27</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row1_col5" class="data row1 col5" >-0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col0" class="data row2 col0" >0.08</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col1" class="data row2 col1" >-0.27</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col3" class="data row2 col3" >0.06</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col4" class="data row2 col4" >-0.03</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row2_col5" class="data row2 col5" >-0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col0" class="data row3 col0" >0.32</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col1" class="data row3 col1" >0.07</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col2" class="data row3 col2" >0.06</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col4" class="data row3 col4" >0.45</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row3_col5" class="data row3 col5" >0.34</td>
#             </tr>
#             <tr>
#                         <th id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col0" class="data row4 col0" >0.49</td>
#                         <td id="T_1e5f9a64_484c_11eb_a1a6_c49ded8dff66row4_col1" class="data row4 col1" >-0
# sentence  : we can eat apple
# sentence  : we can eat apple
# Vector : decoder_encoder_attention@V
# <style  type="text/css" >
# #T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col0,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col1,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col2,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col3,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col4,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col1{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col2,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col3{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col3{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col4{
#             background-color:  #9c9cf7;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col5{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col0,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col2,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col3,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col4,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col5,#T_1e697fd4_484c_11eb_918c_c49ded8dff66row5_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col0{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col1{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col3{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col4{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col5{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col0{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col1{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col2{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col4{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col5{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col0{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col2{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col5{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row5_col0{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row5_col2{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row5_col3{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_1e697fd4_484c_11eb_918c_c49ded8dff66row5_col4{
#             background-color:  #4f4ffb;
#             color:  #f1f1f1;
#         }</style><table id="T_1e697fd4_484c_11eb_918c_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >apple</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e697fd4_484c_11eb_918c_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col1" class="data row0 col1" >-0.26</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col2" class="data row0 col2" >0.15</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col3" class="data row0 col3" >0.18</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col4" class="data row0 col4" >0.27</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row0_col5" class="data row0 col5" >0.51</td>
#             </tr>
#             <tr>
#                         <th id="T_1e697fd4_484c_11eb_918c_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col0" class="data row1 col0" >-0.26</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col2" class="data row1 col2" >-0.13</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col3" class="data row1 col3" >-0.09</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col4" class="data row1 col4" >-0.14</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row1_col5" class="data row1 col5" >-0.37</td>
#             </tr>
#             <tr>
#                         <th id="T_1e697fd4_484c_11eb_918c_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col0" class="data row2 col0" >0.15</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col1" class="data row2 col1" >-0.13</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col3" class="data row2 col3" >0.12</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col4" class="data row2 col4" >0.02</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row2_col5" class="data row2 col5" >0.25</td>
#             </tr>
#             <tr>
#                         <th id="T_1e697fd4_484c_11eb_918c_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col0" class="data row3 col0" >0.18</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col1" class="data row3 col1" >-0.09</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col2" class="data row3 col2" >0.12</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col4" class="data row3 col4" >0.18</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row3_col5" class="data row3 col5" >0.22</td>
#             </tr>
#             <tr>
#                         <th id="T_1e697fd4_484c_11eb_918c_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col0" class="data row4 col0" >0.27</td>
#                         <td id="T_1e697fd4_484c_11eb_918c_c49ded8dff66row4_col1" class="data row4 col1" >-0
# sentence  : we can eat apple
# sentence  : we can eat apple
# Vector : decoder_encoder_attention@x4
# <style  type="text/css" >
# #T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col0,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col1,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col2,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col3,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col1,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col2,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col3,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col4,#T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col0{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col2{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col3{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col4{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col0{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col1{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col3{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col4{
#             background-color:  #0505ff;
#             color:  #f1f1f1;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col0{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col1{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col2{
#             background-color:  #5d5dfa;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col4{
#             background-color:  #5c5cfa;
#             color:  #f1f1f1;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col1{
#             background-color:  #9c9cf7;
#             color:  #000000;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col2{
#             background-color:  #0606ff;
#             color:  #f1f1f1;
#         }#T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col3{
#             background-color:  #8383f8;
#             color:  #000000;
#         }</style><table id="T_1e71dd52_484c_11eb_add6_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->apfel</th>        <th class="col_heading level0 col3" >apfel->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e71dd52_484c_11eb_add6_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col1" class="data row0 col1" >-0.14</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col2" class="data row0 col2" >-0.32</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col3" class="data row0 col3" >0.02</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row0_col4" class="data row0 col4" >-0.40</td>
#             </tr>
#             <tr>
#                         <th id="T_1e71dd52_484c_11eb_add6_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col0" class="data row1 col0" >-0.14</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col2" class="data row1 col2" >0.25</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col3" class="data row1 col3" >0.20</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row1_col4" class="data row1 col4" >0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_1e71dd52_484c_11eb_add6_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col0" class="data row2 col0" >-0.32</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col1" class="data row2 col1" >0.25</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col3" class="data row2 col3" >0.49</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row2_col4" class="data row2 col4" >0.97</td>
#             </tr>
#             <tr>
#                         <th id="T_1e71dd52_484c_11eb_add6_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col0" class="data row3 col0" >0.02</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col1" class="data row3 col1" >0.20</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col2" class="data row3 col2" >0.49</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row3_col4" class="data row3 col4" >0.46</td>
#             </tr>
#             <tr>
#                         <th id="T_1e71dd52_484c_11eb_add6_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col0" class="data row4 col0" >-0.40</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col1" class="data row4 col1" >0.27</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col2" class="data row4 col2" >0.97</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col3" class="data row4 col3" >0.46</td>
#                         <td id="T_1e71dd52_484c_11eb_add6_c49ded8dff66row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>
# 0

# %%
#order and  object is different
sentences = ["we can eat apple","eat bread can we"]

dump_vector_relation(sentences,"decoder_encoder_attention@Q",True)

dump_vector_relation(sentences,"decoder_encoder_attention@K")

dump_vector_relation(sentences,"decoder_encoder_attention@V")

dump_vector_relation(sentences,"decoder_encoder_attention@x4",True)

dump_vector_relation(sentences,"decoder_encoder_attention@attention",True,dump_vector=False)
# Out:
# sentence  : we can eat apple
# sentence  : eat bread can we
# Vector : decoder_encoder_attention@Q
# <style  type="text/css" >
# #T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col0,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col1,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col3,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col2,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col1{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col2{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col3{
#             background-color:  #6767fa;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col4,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col2,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col1,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col0,#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col0{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col4{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col0{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col3{
#             background-color:  #bbbbf5;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col0{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col2{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col3{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col4{
#             background-color:  #9494f7;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col2{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }</style><table id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->brot</th>        <th class="col_heading level0 col3" >brot->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col1" class="data row0 col1" >0.25</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col2" class="data row0 col2" >-0.09</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col3" class="data row0 col3" >0.18</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row0_col4" class="data row0 col4" >-0.33</td>
#             </tr>
#             <tr>
#                         <th id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col0" class="data row1 col0" >0.25</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col2" class="data row1 col2" >-0.30</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col3" class="data row1 col3" >0.49</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row1_col4" class="data row1 col4" >-0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col0" class="data row2 col0" >-0.09</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col1" class="data row2 col1" >-0.30</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col3" class="data row2 col3" >-0.07</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row2_col4" class="data row2 col4" >-0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col0" class="data row3 col0" >-0.14</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col1" class="data row3 col1" >-0.09</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col2" class="data row3 col2" >-0.16</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col3" class="data row3 col3" >0.12</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row3_col4" class="data row3 col4" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col0" class="data row4 col0" >-0.33</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col1" class="data row4 col1" >-0.27</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col2" class="data row4 col2" >-0.18</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col3" class="data row4 col3" >-0.23</td>
#                         <td id="T_1e7c8f62_484c_11eb_835c_c49ded8dff66row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>
# sentence  : we can eat apple
# sentence  : eat bread can we
# Vector : decoder_encoder_attention@K
# <style  type="text/css" >
# #T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col0,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col4,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col3,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col1,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row4_col2,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col1{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col2{
#             background-color:  #5656fb;
#             color:  #f1f1f1;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col3{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col4{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col5{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col0,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col3,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col5,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col1,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col2,#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col1{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col2{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col0{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col5{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col0{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col2{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col3{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col4{
#             background-color:  #afaff6;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col5{
#             background-color:  #9c9cf7;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row4_col0{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row4_col1{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row4_col3{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row4_col4{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row4_col5{
#             background-color:  #6060fa;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row5_col0{
#             background-color:  #6868fa;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row5_col1{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row5_col2{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row5_col3{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row5_col4{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }</style><table id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eat</th>        <th class="col_heading level0 col2" >bread</th>        <th class="col_heading level0 col3" >can</th>        <th class="col_heading level0 col4" >we</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col0" class="data row0 col0" >0.67</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col1" class="data row0 col1" >0.22</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col2" class="data row0 col2" >0.12</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col3" class="data row0 col3" >0.10</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col4" class="data row0 col4" >-0.26</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row0_col5" class="data row0 col5" >0.43</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col0" class="data row1 col0" >-0.18</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col1" class="data row1 col1" >0.15</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col2" class="data row1 col2" >-0.07</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col3" class="data row1 col3" >-0.29</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col4" class="data row1 col4" >0.99</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row1_col5" class="data row1 col5" >-0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col0" class="data row2 col0" >-0.13</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col1" class="data row2 col1" >0.06</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col2" class="data row2 col2" >-0.22</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col3" class="data row2 col3" >1.00</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col4" class="data row2 col4" >-0.27</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row2_col5" class="data row2 col5" >-0.09</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col0" class="data row3 col0" >0.17</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col1" class="data row3 col1" >0.98</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col2" class="data row3 col2" >0.04</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col3" class="data row3 col3" >0.05</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col4" class="data row3 col4" >0.07</td>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row3_col5" class="data row3 col5" >0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1e8501d2_484c_11eb_8ee1_c49ded8dff66row4_col0" class="data row4 col0" >0.21</td>
#                         <td
# sentence  : we can eat apple
# sentence  : eat bread can we
# Vector : decoder_encoder_attention@V
# <style  type="text/css" >
# #T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col0,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col4,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col3,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col1,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col2,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col1,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col0{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col2{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col3{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col4{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col5{
#             background-color:  #7676f9;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col1,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col3,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col5,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col0,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col2,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row5_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col2{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col1,#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row5_col1{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col4{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col5{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col0{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col3{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col4{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col5{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col0{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col1{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col2{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col3{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col4{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col5{
#             background-color:  #6f6ff9;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row5_col0{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row5_col2{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }#T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row5_col3{
#             background-color:  #9898f7;
#             color:  #000000;
#         }</style><table id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >eat</th>        <th class="col_heading level0 col2" >bread</th>        <th class="col_heading level0 col3" >can</th>        <th class="col_heading level0 col4" >we</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col0" class="data row0 col0" >0.56</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col1" class="data row0 col1" >0.06</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col2" class="data row0 col2" >0.16</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col3" class="data row0 col3" >0.16</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col4" class="data row0 col4" >-0.24</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row0_col5" class="data row0 col5" >0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col0" class="data row1 col0" >-0.12</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col1" class="data row1 col1" >-0.03</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col2" class="data row1 col2" >-0.01</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col3" class="data row1 col3" >-0.16</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col4" class="data row1 col4" >0.99</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row1_col5" class="data row1 col5" >-0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col0" class="data row2 col0" >-0.19</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col1" class="data row2 col1" >0.08</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col2" class="data row2 col2" >-0.07</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col3" class="data row2 col3" >1.00</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col4" class="data row2 col4" >-0.12</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row2_col5" class="data row2 col5" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col0" class="data row3 col0" >0.06</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col1" class="data row3 col1" >0.97</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col2" class="data row3 col2" >0.19</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col3" class="data row3 col3" >0.12</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col4" class="data row3 col4" >-0.10</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row3_col5" class="data row3 col5" >-0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col0" class="data row4 col0" >-0.11</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8dff66row4_col1" class="data row4 col1" >0.10</td>
#                         <td id="T_1e8ee7a4_484c_11eb_985a_c49ded8df
# sentence  : we can eat apple
# sentence  : eat bread can we
# Vector : decoder_encoder_attention@x4
# <style  type="text/css" >
# #T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col0,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col1,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col3,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col2,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col1,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col2,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col4,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col0,#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col2{
#             background-color:  #6c6cf9;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col3{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col4{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col0{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col3{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col0{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col1{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col2{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col3{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col4{
#             background-color:  #2626fd;
#             color:  #f1f1f1;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col0{
#             background-color:  #a7a7f7;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col1{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col2{
#             background-color:  #3f3ffc;
#             color:  #f1f1f1;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col4{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col1{
#             background-color:  #9696f7;
#             color:  #000000;
#         }</style><table id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->brot</th>        <th class="col_heading level0 col3" >brot->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col0" class="data row0 col0" >0.99</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col1" class="data row0 col1" >-0.16</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col2" class="data row0 col2" >0.03</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col3" class="data row0 col3" >0.16</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row0_col4" class="data row0 col4" >-0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col0" class="data row1 col0" >-0.14</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col2" class="data row1 col2" >-0.14</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col3" class="data row1 col3" >0.11</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row1_col4" class="data row1 col4" >-0.16</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col0" class="data row2 col0" >-0.30</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col1" class="data row2 col1" >0.26</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col2" class="data row2 col2" >0.13</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col3" class="data row2 col3" >0.13</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row2_col4" class="data row2 col4" >0.22</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col0" class="data row3 col0" >0.05</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col1" class="data row3 col1" >0.22</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col2" class="data row3 col2" >0.09</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col3" class="data row3 col3" >0.91</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row3_col4" class="data row3 col4" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col0" class="data row4 col0" >-0.37</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col1" class="data row4 col1" >0.27</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col2" class="data row4 col2" >0.17</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col3" class="data row4 col3" >0.10</td>
#                         <td id="T_1e9748c0_484c_11eb_84b1_c49ded8dff66row4_col4" class="data row4 col4" >0.29</td>
#             </tr>
#     </tbody></table>
# sentence  : we can eat apple
# sentence  : eat bread can we
# Vector : decoder_encoder_attention@attention
# <style  type="text/css" >
# #T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col0{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col1{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col2,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col4,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col0,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col1,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col3,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col2,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col0,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col1,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col4{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col1{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col2{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col3{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col4{
#             background-color:  #3e3efc;
#             color:  #f1f1f1;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col0{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col2,#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col0{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col3{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col4{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col1{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col2{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col3{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }</style><table id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->brot</th>        <th class="col_heading level0 col3" >brot->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col0" class="data row0 col0" >0.06</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col1" class="data row0 col1" >0.08</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col2" class="data row0 col2" >0.03</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col3" class="data row0 col3" >1.00</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row0_col4" class="data row0 col4" >0.08</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col0" class="data row1 col0" >0.01</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col1" class="data row1 col1" >0.04</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col2" class="data row1 col2" >0.88</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col3" class="data row1 col3" >0.03</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row1_col4" class="data row1 col4" >0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col0" class="data row2 col0" >0.67</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col1" class="data row2 col1" >0.07</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col2" class="data row2 col2" >0.45</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col3" class="data row2 col3" >0.12</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row2_col4" class="data row2 col4" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col0" class="data row3 col0" >0.08</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col1" class="data row3 col1" >0.98</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col2" class="data row3 col2" >0.15</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col3" class="data row3 col3" >0.11</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row3_col4" class="data row3 col4" >0.21</td>
#             </tr>
#             <tr>
#                         <th id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col0" class="data row4 col0" >0.11</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col1" class="data row4 col1" >0.06</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col2" class="data row4 col2" >0.46</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col3" class="data row4 col3" >0.08</td>
#                         <td id="T_1e9fa56c_484c_11eb_9319_c49ded8dff66row4_col4" class="data row4 col4" >0.99</td>
#             </tr>
#     </tbody></table>
# 0

# %%
#same words in different order
sentences = ["we can eat apple","apple eat can we"]



dump_vector_relation(sentences,"decoder_encoder_attention@Q",True)

dump_vector_relation(sentences,"decoder_encoder_attention@K")

dump_vector_relation(sentences,"decoder_encoder_attention@V")

dump_vector_relation(sentences,"decoder_encoder_attention@x4",True)

dump_vector_relation(sentences,"decoder_encoder_attention@attention",True,dump_vector=True)
# Out:
# sentence  : we can eat apple
# sentence  : apple eat can we
# Vector : decoder_encoder_attention@Q
# <style  type="text/css" >
# #T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col0,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col1,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col2,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col3,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col1{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col2{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col3{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col4,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col2,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col1,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col3,#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col0{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col3{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col4{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col0{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col0{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col2{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col4{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col2{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col3{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }</style><table id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->apfel</th>        <th class="col_heading level0 col3" >apfel->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col1" class="data row0 col1" >0.25</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col2" class="data row0 col2" >-0.09</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col3" class="data row0 col3" >-0.14</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row0_col4" class="data row0 col4" >-0.33</td>
#             </tr>
#             <tr>
#                         <th id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col0" class="data row1 col0" >0.25</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col2" class="data row1 col2" >-0.30</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col3" class="data row1 col3" >-0.09</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row1_col4" class="data row1 col4" >-0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col0" class="data row2 col0" >-0.09</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col1" class="data row2 col1" >-0.30</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col3" class="data row2 col3" >-0.16</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row2_col4" class="data row2 col4" >-0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col0" class="data row3 col0" >-0.14</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col1" class="data row3 col1" >-0.09</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col2" class="data row3 col2" >-0.16</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row3_col4" class="data row3 col4" >0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col0" class="data row4 col0" >-0.33</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col1" class="data row4 col1" >-0.27</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col2" class="data row4 col2" >-0.18</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col3" class="data row4 col3" >0.19</td>
#                         <td id="T_1eabeb86_484c_11eb_b4f8_c49ded8dff66row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>
# sentence  : we can eat apple
# sentence  : apple eat can we
# Vector : decoder_encoder_attention@K
# <style  type="text/css" >
# #T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col0,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col4,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col3,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col2,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col1,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col1{
#             background-color:  #6666fa;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col2{
#             background-color:  #bcbcf5;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col3{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col4{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col5,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col5{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col0,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col1,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col2,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col3,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col5,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col2,#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col0{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col1{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col5{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col0{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col1{
#             background-color:  #6767fa;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col3{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col4{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col5{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col0{
#             background-color:  #5f5ffa;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col2{
#             background-color:  #9c9cf7;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col3{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col4{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row5_col0{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row5_col1{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row5_col2{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row5_col3{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1eb50c36_484c_11eb_99a1_c49ded8dff66row5_col4{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }</style><table id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >apple</th>        <th class="col_heading level0 col2" >eat</th>        <th class="col_heading level0 col3" >can</th>        <th class="col_heading level0 col4" >we</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col1" class="data row0 col1" >0.46</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col2" class="data row0 col2" >0.29</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col3" class="data row0 col3" >0.10</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col4" class="data row0 col4" >-0.26</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row0_col5" class="data row0 col5" >0.65</td>
#             </tr>
#             <tr>
#                         <th id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col0" class="data row1 col0" >-0.30</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col1" class="data row1 col1" >-0.27</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col2" class="data row1 col2" >0.09</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col3" class="data row1 col3" >-0.29</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col4" class="data row1 col4" >0.99</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row1_col5" class="data row1 col5" >-0.19</td>
#             </tr>
#             <tr>
#                         <th id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col0" class="data row2 col0" >0.09</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col1" class="data row2 col1" >-0.03</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col2" class="data row2 col2" >0.09</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col3" class="data row2 col3" >1.00</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col4" class="data row2 col4" >-0.27</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row2_col5" class="data row2 col5" >-0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col0" class="data row3 col0" >0.32</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col1" class="data row3 col1" >0.45</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col2" class="data row3 col2" >1.00</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col3" class="data row3 col3" >0.06</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col4" class="data row3 col4" >0.08</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row3_col5" class="data row3 col5" >0.33</td>
#             </tr>
#             <tr>
#                         <th id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col0" class="data row4 col0" >0.48</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66row4_col1" class="data row4 col1" >0.99</td>
#                         <td id="T_1eb50c36_484c_11eb_99a1_c49ded8dff66r
# sentence  : we can eat apple
# sentence  : apple eat can we
# Vector : decoder_encoder_attention@V
# <style  type="text/css" >
# #T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col0,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col4,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col3,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col2,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col1,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col1{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col2,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col2{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col3{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col4{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col5{
#             background-color:  #5858fb;
#             color:  #f1f1f1;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col0,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col1,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col2,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col3,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col5,#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row5_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col0{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col1{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col2{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col4{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col5{
#             background-color:  #8484f8;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col0{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col1{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col3{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col4{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col5{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col0{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col3{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col4{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col5{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row5_col0{
#             background-color:  #5f5ffa;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row5_col1{
#             background-color:  #5454fb;
#             color:  #f1f1f1;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row5_col2{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row5_col3{
#             background-color:  #9999f7;
#             color:  #000000;
#         }</style><table id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >apple</th>        <th class="col_heading level0 col2" >eat</th>        <th class="col_heading level0 col3" >can</th>        <th class="col_heading level0 col4" >we</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col1" class="data row0 col1" >0.24</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col2" class="data row0 col2" >0.16</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col3" class="data row0 col3" >0.16</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col4" class="data row0 col4" >-0.23</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row0_col5" class="data row0 col5" >0.50</td>
#             </tr>
#             <tr>
#                         <th id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col0" class="data row1 col0" >-0.26</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col1" class="data row1 col1" >-0.14</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col2" class="data row1 col2" >-0.07</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col3" class="data row1 col3" >-0.16</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col4" class="data row1 col4" >0.99</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row1_col5" class="data row1 col5" >-0.36</td>
#             </tr>
#             <tr>
#                         <th id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col0" class="data row2 col0" >0.15</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col1" class="data row2 col1" >0.01</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col2" class="data row2 col2" >0.15</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col3" class="data row2 col3" >1.00</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col4" class="data row2 col4" >-0.12</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row2_col5" class="data row2 col5" >0.25</td>
#             </tr>
#             <tr>
#                         <th id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col0" class="data row3 col0" >0.18</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col1" class="data row3 col1" >0.19</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col2" class="data row3 col2" >1.00</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col3" class="data row3 col3" >0.12</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col4" class="data row3 col4" >-0.10</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row3_col5" class="data row3 col5" >0.21</td>
#             </tr>
#             <tr>
#                         <th id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col0" class="data row4 col0" >0.26</td>
#                         <td id="T_1ebef10a_484c_11eb_8a0f_c49ded8dff66row4_col1" class="data row4 col1" >1.
# sentence  : we can eat apple
# sentence  : apple eat can we
# Vector : decoder_encoder_attention@x4
# <style  type="text/css" >
# #T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col0,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col1,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col2,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col3,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col1,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col2,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col3,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col4,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col0{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col2{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col3{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col4{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col0{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col1{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col3{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col4,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col2{
#             background-color:  #0606ff;
#             color:  #f1f1f1;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col0{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col1{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col2,#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col4{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col1{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col3{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }</style><table id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->apfel</th>        <th class="col_heading level0 col3" >apfel->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col0" class="data row0 col0" >0.99</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col1" class="data row0 col1" >-0.17</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col2" class="data row0 col2" >-0.32</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col3" class="data row0 col3" >0.05</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row0_col4" class="data row0 col4" >-0.39</td>
#             </tr>
#             <tr>
#                         <th id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col0" class="data row1 col0" >-0.13</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col2" class="data row1 col2" >0.25</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col3" class="data row1 col3" >0.23</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row1_col4" class="data row1 col4" >0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col0" class="data row2 col0" >-0.28</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col1" class="data row2 col1" >0.28</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col3" class="data row2 col3" >0.47</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row2_col4" class="data row2 col4" >0.97</td>
#             </tr>
#             <tr>
#                         <th id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col0" class="data row3 col0" >0.04</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col1" class="data row3 col1" >0.22</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col2" class="data row3 col2" >0.48</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row3_col4" class="data row3 col4" >0.45</td>
#             </tr>
#             <tr>
#                         <th id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col0" class="data row4 col0" >-0.36</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col1" class="data row4 col1" >0.29</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col2" class="data row4 col2" >0.96</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col3" class="data row4 col3" >0.44</td>
#                         <td id="T_1ec8d7fa_484c_11eb_97a6_c49ded8dff66row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>
# sentence  : we can eat apple
# sentence  : apple eat can we
# Vector : decoder_encoder_attention@attention
# data1
# tensor([[0.0026, 0.9656, 0.0070, 0.0191, 0.0019, 0.0038],
#         [0.0066, 0.0059, 0.9456, 0.0379, 0.0026, 0.0014],
#         [0.3318, 0.0261, 0.0510, 0.0341, 0.3486, 0.2084],
#         [0.1323, 0.0341, 0.0239, 0.7284, 0.0513, 0.0299],
#         [0.3704, 0.0176, 0.0209, 0.0333, 0.0590, 0.4989]])
# data2
# tensor([[0.0035, 0.0037, 0.0345, 0.0072, 0.9461, 0.0050],
#         [0.0070, 0.0034, 0.0503, 0.9327, 0.0052, 0.0015],
#         [0.3235, 0.3576, 0.0327, 0.0477, 0.0258, 0.2127],
#         [0.1432, 0.0463, 0.7046, 0.0280, 0.0464, 0.0315],
#         [0.3779, 0.0500, 0.0313, 0.0218, 0.0200, 0.4989]])
# <style  type="text/css" >
# #T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col0,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col1,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col3,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col2,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col2{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col4{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col0{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col1{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col3,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col0,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col1,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col2,#T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col1{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col2{
#             background-color:  #2323fd;
#             color:  #f1f1f1;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col3{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col4{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col0{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col2{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col3{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col4{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col0{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col1{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col3{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }</style><table id="T_1ed149fa_484c_11eb_962c_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos->wir</th>        <th class="col_heading level0 col1" >wir->konnen</th>        <th class="col_heading level0 col2" >konnen->apfel</th>        <th class="col_heading level0 col3" >apfel->essen</th>        <th class="col_heading level0 col4" >essen->eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ed149fa_484c_11eb_962c_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos->wir</th>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col0" class="data row0 col0" >0.01</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col1" class="data row0 col1" >0.02</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col2" class="data row0 col2" >0.68</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col3" class="data row0 col3" >0.07</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row0_col4" class="data row0 col4" >0.09</td>
#             </tr>
#             <tr>
#                         <th id="T_1ed149fa_484c_11eb_962c_c49ded8dff66level0_row1" class="row_heading level0 row1" >wir->konnen</th>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col0" class="data row1 col0" >0.04</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col1" class="data row1 col1" >0.09</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col2" class="data row1 col2" >0.07</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col3" class="data row1 col3" >0.98</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row1_col4" class="data row1 col4" >0.06</td>
#             </tr>
#             <tr>
#                         <th id="T_1ed149fa_484c_11eb_962c_c49ded8dff66level0_row2" class="row_heading level0 row2" >konnen->apfel</th>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col0" class="data row2 col0" >0.67</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col1" class="data row2 col1" >0.08</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col2" class="data row2 col2" >0.62</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col3" class="data row2 col3" >0.28</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row2_col4" class="data row2 col4" >0.72</td>
#             </tr>
#             <tr>
#                         <th id="T_1ed149fa_484c_11eb_962c_c49ded8dff66level0_row3" class="row_heading level0 row3" >apfel->essen</th>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col0" class="data row3 col0" >0.08</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col1" class="data row3 col1" >0.98</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col2" class="data row3 col2" >0.25</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col3" class="data row3 col3" >0.11</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row3_col4" class="data row3 col4" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_1ed149fa_484c_11eb_962c_c49ded8dff66level0_row4" class="row_heading level0 row4" >essen->eos</th>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col0" class="data row4 col0" >0.10</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col1" class="data row4 col1" >0.06</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col2" class="data row4 col2" >0.71</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col3" class="data row4 col3" >0.19</td>
#                         <td id="T_1ed149fa_484c_11eb_962c_c49ded8dff66row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>
# 0

# %%
#do the vector relation logic for encoder layers
def dump_vector_relation_encoder(sentences,vector_name,is_q=False):
    print("Vector :",vector_name)
    test_logger1,_,t1 = translate_info(sentences[0],attention_type=1,draw_charts=False,dump_result=False)
    val1 = test_logger1.get_summary([vector_name],show_data=False,summary_count=10)

    test_logger2,_,t2 = translate_info(sentences[1],attention_type=1,draw_charts=False,dump_result=False)
    val2 = test_logger2.get_summary([vector_name],show_data=False,summary_count=10)

    data1 = val1[len(val1)-1][0][0]
    data2 = val2[len(val1)-1][0][0]
    data_matrix = []
    for i in range(data1.shape[0] ):
        sub_data = []
        for j in range(data2.shape[0] ):
            sub_data.append( cosine_similarity(data1[i].reshape(1,64), data2[j].reshape(1,64))[0][0] )
        data_matrix.append( sub_data )
    
    print("data1",data1.shape)
    columns = ["sos"] + sentences[1].split(" ") + ["eos"]
    indexes = ["sos"] + sentences[0].split(" ") + ["eos"]
    if is_q :
        columns =  ["sos"]+sentences[1].split(" ") + ["eos"]
        indexes =  ["sos"]+sentences[0].split(" ") + ["eos"]
        
    draw_df(data_matrix,columns=columns,indexes=indexes) 
    
#sentences = ["we can eat apple","i can read book"]
sentences = ["we can eat apple","we can eat bread"]

dump_vector_relation_encoder(sentences,"encoder@Q",True)

dump_vector_relation_encoder(sentences,"encoder@K")

dump_vector_relation_encoder(sentences,"encoder@V")
# Out:
# Vector : encoder@Q
# data1 torch.Size([6, 64])
# <style  type="text/css" >
# #T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col0,#T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col1,#T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col2,#T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col3,#T_1ee02124_484c_11eb_a135_c49ded8dff66row5_col4,#T_1ee02124_484c_11eb_a135_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col1{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col2,#T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col0,#T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col3,#T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col5,#T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col1,#T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col4,#T_1ee02124_484c_11eb_a135_c49ded8dff66row5_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col3,#T_1ee02124_484c_11eb_a135_c49ded8dff66row5_col1{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col4{
#             background-color:  #6262fa;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col5{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col2{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col4{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col0,#T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col5{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col1,#T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col4{
#             background-color:  #afaff6;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col3{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col4{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col5{
#             background-color:  #bcbcf5;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col0{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col1{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col2{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col0{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col2{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col3{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col5{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row5_col0{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1ee02124_484c_11eb_a135_c49ded8dff66row5_col2{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }</style><table id="T_1ee02124_484c_11eb_a135_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >bread</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ee02124_484c_11eb_a135_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col1" class="data row0 col1" >-0.10</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col2" class="data row0 col2" >0.01</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col3" class="data row0 col3" >0.09</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col4" class="data row0 col4" >0.09</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row0_col5" class="data row0 col5" >0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee02124_484c_11eb_a135_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col0" class="data row1 col0" >-0.10</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col2" class="data row1 col2" >0.17</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col3" class="data row1 col3" >0.04</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col4" class="data row1 col4" >0.04</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row1_col5" class="data row1 col5" >-0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee02124_484c_11eb_a135_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col0" class="data row2 col0" >0.01</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col1" class="data row2 col1" >0.17</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col3" class="data row2 col3" >0.05</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col4" class="data row2 col4" >-0.01</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row2_col5" class="data row2 col5" >0.17</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee02124_484c_11eb_a135_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col0" class="data row3 col0" >0.09</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col1" class="data row3 col1" >0.04</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col2" class="data row3 col2" >0.05</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col4" class="data row3 col4" >-0.00</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row3_col5" class="data row3 col5" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee02124_484c_11eb_a135_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col0" class="data row4 col0" >-0.09</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col1" class="data row4 col1" >-0.14</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col2" class="data row4 col2" >0.03</td>
#                         <td id="T_1ee02124_484c_11eb_a135_c49ded8dff66row4_col3" class="data row4 col3" >0.08</td>
# Vector : encoder@K
# data1 torch.Size([6, 64])
# <style  type="text/css" >
# #T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col0,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col1,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col2,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col3,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row5_col4,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col1{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col2{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col3{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col4,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col0{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col5{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col0,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col2,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col4,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col5,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col1,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row5_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col3{
#             background-color:  #b2b2f6;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col4{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col5{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col1{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col3{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col4{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col5,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row5_col0{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col0,#T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col0{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col1{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col2{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col2{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col3{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col4{
#             background-color:  #6868fa;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col5{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row5_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_1ee9b578_484c_11eb_b371_c49ded8dff66row5_col2{
#             background-color:  #ababf6;
#             color:  #000000;
#         }</style><table id="T_1ee9b578_484c_11eb_b371_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >bread</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ee9b578_484c_11eb_b371_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col1" class="data row0 col1" >-0.05</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col2" class="data row0 col2" >0.04</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col3" class="data row0 col3" >0.12</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col4" class="data row0 col4" >-0.12</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row0_col5" class="data row0 col5" >0.29</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee9b578_484c_11eb_b371_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col0" class="data row1 col0" >-0.05</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col2" class="data row1 col2" >-0.07</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col3" class="data row1 col3" >0.17</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col4" class="data row1 col4" >-0.08</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row1_col5" class="data row1 col5" >-0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee9b578_484c_11eb_b371_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col0" class="data row2 col0" >0.04</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col1" class="data row2 col1" >-0.07</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col3" class="data row2 col3" >-0.04</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col4" class="data row2 col4" >-0.12</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row2_col5" class="data row2 col5" >0.24</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee9b578_484c_11eb_b371_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col0" class="data row3 col0" >0.12</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col1" class="data row3 col1" >0.17</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col2" class="data row3 col2" >-0.04</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col4" class="data row3 col4" >-0.15</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row3_col5" class="data row3 col5" >-0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_1ee9b578_484c_11eb_b371_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col0" class="data row4 col0" >0.12</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col1" class="data row4 col1" >-0.25</td>
#                         <td id="T_1ee9b578_484c_11eb_b371_c49ded8dff66row4_col2" class="data row4 col2" >0.04</td>
#                         <td id
# Vector : encoder@V
# data1 torch.Size([6, 64])
# <style  type="text/css" >
# #T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col0,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col1,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col2,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col3,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row5_col4,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col1{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col2{
#             background-color:  #b3b3f6;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col3,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col4,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col5,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col0,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col2,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col5{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col0{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col2{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col3{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col4{
#             background-color:  #3232fc;
#             color:  #f1f1f1;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col0{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col1,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col5,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col2{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col3,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col4,#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col5{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col1{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col4{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col0{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col3{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col4{
#             background-color:  #1616fe;
#             color:  #f1f1f1;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col5{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row5_col0{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row5_col1{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row5_col2{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row5_col3{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }</style><table id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >eat</th>        <th class="col_heading level0 col4" >bread</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col1" class="data row0 col1" >-0.13</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col2" class="data row0 col2" >0.15</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col3" class="data row0 col3" >-0.24</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col4" class="data row0 col4" >-0.23</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row0_col5" class="data row0 col5" >-0.06</td>
#             </tr>
#             <tr>
#                         <th id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col0" class="data row1 col0" >-0.13</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col2" class="data row1 col2" >0.09</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col3" class="data row1 col3" >0.07</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col4" class="data row1 col4" >-0.11</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row1_col5" class="data row1 col5" >-0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col0" class="data row2 col0" >0.15</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col1" class="data row2 col1" >0.09</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col3" class="data row2 col3" >-0.13</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col4" class="data row2 col4" >-0.21</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row2_col5" class="data row2 col5" >0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66level0_row3" class="row_heading level0 row3" >eat</th>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col0" class="data row3 col0" >-0.24</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col1" class="data row3 col1" >0.07</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col2" class="data row3 col2" >-0.13</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col4" class="data row3 col4" >-0.18</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row3_col5" class="data row3 col5" >-0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66level0_row4" class="row_heading level0 row4" >apple</th>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col0" class="data row4 col0" >0.01</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col1" class="data row4 col1" >-0.17</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col2" class="data row4 col2" >0.12</td>
#                         <td id="T_1ef2d3a6_484c_11eb_aa3a_c49ded8dff66row4_col3" class="data row4 col3" >0.0

# %%
#test_logger.get_default_summary(show_data=True)
for index in range(20,22):
    
    test_logger,all_outputs,_ = translate_info(tabular_set[index].src,draw_charts=False,attention_type=1)
    encoded_attention = test_logger.get_summary(["EncoderLayer@sattention"],show_data=False)
    
    src_masks = test_logger.get_summary(["EncoderLayer@src_mask"],show_data=False,summary_count=10)
    #print("EncoderLayersrc_masks",src_masks)
    
    decodersrc_masks = test_logger.get_summary(["DecoderLayer@src_mask"],show_data=False,summary_count=10)
    #print("decodersrc_masks",decodersrc_masks)
    
    
    decoder_attention = test_logger.get_summary(["Decoder@attention"],show_data=False,summary_count=10)
    #print("decoder_attention",decoder_attention[0].shape)
    #print("decoder_attention",decoder_attention[0])
    
    decodertrg_masks = test_logger.get_summary(["DecoderLayer@trg_mask"],show_data=False,summary_count=10)
    #for index2,dm in enumerate(decodertrg_masks):
    #    print("decodertrg_masks",index2)
    #    print(dm)
    
    output_words = ["sos"]+tabular_set[index].src  +["eos"]
    for head_index in range(encoded_attention[0].shape[1]):
        all_outputs0 = encoded_attention[0][:,head_index,:,:]
        draw_df(all_outputs0.squeeze().numpy(),output_words,output_words)
    
    ### OPEN THIS COMMENT FOR MULTI HEAD all_outputs1 = encoded_attention[0][:,1,:,:]
    ###draw_df(all_outputs1.squeeze().numpy(),output_words,output_words)


#i want to read newspaper  diagonal
#i can eat bread  diagonal
#we can eat bread diagonal
#we can read book , very diagonal
#we can read newspaper , very diagonal
#i eat bread , very diagonal
#when want to comes into ,patterns change
# Out:
# source = ['we', 'can', 'drink', 'water']
# predicted target = ['wir', 'konnen', 'wasser', 'trinken', '<eos>']
# <style  type="text/css" >
# #T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col0,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col1,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col2,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col4,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col5,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col1,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col3,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row5_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col3,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col1,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col2,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col5,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col0,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row5_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col4{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col5{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col0{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col2{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col3,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col2{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col0,#T_1efa7e38_484c_11eb_b349_c49ded8dff66row5_col3{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col1{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col3{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col4{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col4{
#             background-color:  #1212fe;
#             color:  #f1f1f1;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col5{
#             background-color:  #0404ff;
#             color:  #f1f1f1;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col0{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col1{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col2{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col3{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col4{
#             background-color:  #2727fd;
#             color:  #f1f1f1;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col5{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row5_col0{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row5_col2{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_1efa7e38_484c_11eb_b349_c49ded8dff66row5_col5{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }</style><table id="T_1efa7e38_484c_11eb_b349_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >drink</th>        <th class="col_heading level0 col4" >water</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1efa7e38_484c_11eb_b349_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col2" class="data row0 col2" >0.01</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col3" class="data row0 col3" >0.57</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col4" class="data row0 col4" >0.41</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row0_col5" class="data row0 col5" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1efa7e38_484c_11eb_b349_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col0" class="data row1 col0" >0.00</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col1" class="data row1 col1" >0.94</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col2" class="data row1 col2" >0.04</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col3" class="data row1 col3" >0.01</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col4" class="data row1 col4" >0.00</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row1_col5" class="data row1 col5" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1efa7e38_484c_11eb_b349_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col0" class="data row2 col0" >0.00</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col1" class="data row2 col1" >0.18</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col2" class="data row2 col2" >0.73</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col3" class="data row2 col3" >0.03</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col4" class="data row2 col4" >0.02</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row2_col5" class="data row2 col5" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_1efa7e38_484c_11eb_b349_c49ded8dff66level0_row3" class="row_heading level0 row3" >drink</th>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col0" class="data row3 col0" >0.07</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col1" class="data row3 col1" >0.00</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col2" class="data row3 col2" >0.01</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col3" class="data row3 col3" >0.01</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col4" class="data row3 col4" >0.86</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row3_col5" class="data row3 col5" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_1efa7e38_484c_11eb_b349_c49ded8dff66level0_row4" class="row_heading level0 row4" >water</th>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col0" class="data row4 col0" >0.01</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col1" class="data row4 col1" >0.04</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col2" class="data row4 col2" >0.06</td>
#                         <td id="T_1efa7e38_484c_11eb_b349_c49ded8dff66row4_col3" class="data row4 col3" >0.09</td>
# source = ['we', 'can', 'drink', 'beer']
# predicted target = ['wir', 'konnen', 'bier', 'trinken', '<eos>']
# <style  type="text/css" >
# #T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col0,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col1,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col2,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col4,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col5,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col1,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col2,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col3,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row5_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col3,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col1,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col2,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col0,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col4,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col4,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col3,#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col0{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col5{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col0{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col2{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col1{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col3{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col4{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col5{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col5{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col0{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col1{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col2{
#             background-color:  #5a5afa;
#             color:  #f1f1f1;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col3{
#             background-color:  #acacf6;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col4{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col5{
#             background-color:  #6c6cf9;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row5_col0{
#             background-color:  #6262fa;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row5_col2{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row5_col3{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_1f014f1c_484c_11eb_aa49_c49ded8dff66row5_col4{
#             background-color:  #2a2afd;
#             color:  #f1f1f1;
#         }</style><table id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >we</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >drink</th>        <th class="col_heading level0 col4" >beer</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col2" class="data row0 col2" >0.01</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col3" class="data row0 col3" >0.95</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col4" class="data row0 col4" >0.01</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row0_col5" class="data row0 col5" >0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66level0_row1" class="row_heading level0 row1" >we</th>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col0" class="data row1 col0" >0.00</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col1" class="data row1 col1" >0.94</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col2" class="data row1 col2" >0.04</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col3" class="data row1 col3" >0.01</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col4" class="data row1 col4" >0.00</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row1_col5" class="data row1 col5" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col0" class="data row2 col0" >0.00</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col1" class="data row2 col1" >0.18</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col2" class="data row2 col2" >0.73</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col3" class="data row2 col3" >0.03</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col4" class="data row2 col4" >0.02</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row2_col5" class="data row2 col5" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66level0_row3" class="row_heading level0 row3" >drink</th>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col0" class="data row3 col0" >0.07</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col1" class="data row3 col1" >0.00</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col2" class="data row3 col2" >0.01</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col3" class="data row3 col3" >0.01</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col4" class="data row3 col4" >0.87</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row3_col5" class="data row3 col5" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66level0_row4" class="row_heading level0 row4" >beer</th>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col0" class="data row4 col0" >0.01</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col1" class="data row4 col1" >0.02</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col2" class="data row4 col2" >0.46</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col3" class="data row4 col3" >0.28</td>
#                         <td id="T_1f014f1c_484c_11eb_aa49_c49ded8dff66row4_col4" cla
