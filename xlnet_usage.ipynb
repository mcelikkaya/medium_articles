# %%
#In this notebook, I have explained usage of XLNet
#you can check explanations in 
#   https://celikkam.medium.com/

# %%
from transformers import XLNetTokenizer, XLNetModel
import torch
from scipy.spatial.distance import cosine
import torch
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import spacy
import numpy as np
import matplotlib

# %%
def map_on_3d(data_2d,words,color_mapping:None,exceptional_words=[],use_word_colors=False,fig_size=[19,11],title=""):
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(fig_size[0], fig_size[1])

    ax = plt.axes(projection ="3d")
    #scatter result words
    ax.scatter3D(data_2d[:, 0], data_2d[:, 1], data_2d[:, 2])
    plt.title(title)        
    #put an annotation on x,y cordinates for words
    for i, word in enumerate(words):
        if color_mapping is not None:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color=color_mapping[i] )
        elif word in exceptional_words:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#0000ff' )
        elif use_word_colors:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color=get_color(word))
        elif "eat" in word:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#0000ff')
        elif "drink" in word:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#00ff00')
        elif "read" in word:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#ff0000')     
        else:
            ax.text(data_2d[i, 0], data_2d[i, 1], data_2d[i, 2],word,color='#ff00dd')
    plt.show()

def get_color_mapping(Ys,color_by="verb"):
  
  mapped_colors = []
  if color_by == "verb":    
    colors =["#ff0000","#00dd00","#0000dd"] 
    verbs = ["eat","drink"," read"] #bread has "read" process carefully
    for y in Ys:
      indexes = [i for i,verb in enumerate(verbs) if y.find(verb) > -1]
      mapped_colors.append(colors[indexes[0]] )
  elif color_by == "object":    
    colors =["#ff0000","#aaaa00","#00ff00","#000220","#0000ff","#00aaaa"] 
    objects = ["apple","bread","water","beer","book","newspaper"]
    for y in Ys:
      indexes = [i for i,object in enumerate(objects) if y.find(object) > -1]
      mapped_colors.append(colors[indexes[0]] )    
  elif color_by == "index10":    
    colors =["#ff0000","#00ff00","#0000ff"]     
    for index,y in enumerate(Ys):
      index_color = index // 10 
      mapped_colors.append(colors[index_color] )
  elif color_by == "index6":    
    colors =["#ff0000","#00ff00","#0000ff"]     
    for index,y in enumerate(Ys):
      index_color = index // 6 
      mapped_colors.append(colors[index_color] )      
  else:
    colors =["#ff0000","#aaaa00","#00ff00","#000220","#0000ff","#00aaaa"] 
    for index,y in enumerate(Ys):      
      mapped_colors.append(colors[ index % len(colors)] )    
    
  return mapped_colors  

def map_on_2d(data_2d,words,color_mapping:None,exceptional_words=[],use_word_colors=False,fig_size=[16,11],title=""):
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(fig_size[0], fig_size[1])

    #scatter result words
    plt.scatter(data_2d[:, 0], data_2d[:, 1])        
    plt.title(title)
    #put an annotation on x,y cordinates for words
    for i, word in enumerate(words):
        if color_mapping is not None:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color=color_mapping[i] )
        elif word in exceptional_words:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#0000ff' )
        elif use_word_colors:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color=get_color(word))
        elif "eat" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff0000')     
        else:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff00dd')
    plt.show()   

def dump_on_surface(Xs,Ys,fitting="tsne",dump_3d=True,dump_2d=True,color_by="verb",title=""):    
    color_mapping = get_color_mapping(Ys,color_by)
    #print(color_mapping)
    X_transformed = None                         
    if dump_3d:    
        X_transformed = None
        if fitting == "tsne" :
            X_transformed = TSNE(n_components=3).fit_transform(np.array(Xs))
        elif fitting == "pcatsne" :    
            X_transformed = PCA(n_components=20).fit_transform(np.array(Xs))   
            X_transformed = TSNE(n_components=3).fit_transform(np.array(X_transformed))
        else:
            X_transformed = PCA(n_components=3).fit_transform(np.array(Xs))          
        map_on_3d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[9,9],title=title)
        
    if dump_2d:    
        X_transformed = None
        if fitting == "tsne" :
            X_transformed = TSNE(n_components=2).fit_transform(np.array(Xs))
        elif fitting == "pcatsne" :    
            X_transformed = PCA(n_components=20).fit_transform(np.array(Xs))   
            X_transformed = TSNE(n_components=2).fit_transform(np.array(X_transformed))    
        else:
            pca = PCA(n_components=2)
            X_transformed = pca.fit_transform(np.array(Xs))        
            #pca.explained_variance_
        map_on_2d(np.array(X_transformed),Ys,color_mapping=color_mapping,use_word_colors=False,fig_size=[9,9],title=title)
    return X_transformed

# %%
#get output as object
def get_output(tokenizer_,model_,sentence):
  inputs = tokenizer_(sentence, return_tensors="pt",add_special_tokens=True)
  outputs = model_(**inputs,mems=None,return_dict=True)
  return outputs  

#get sentence embedding from [CLS]
def get_sentence_output(tokenizer_,model_,sentence):
  outputs = get_output(tokenizer_,model_,sentence)  
  return outputs[0][:, -1].squeeze()

#get sentence embedding as a mean of outputs
def get_sentence_output_bymean(tokenizer_,model_,sentence):
  outputs = get_output(tokenizer_,model_,sentence)  
  return outputs[0].mean(1).squeeze()

class EmbeddingPair:
  def __init__(self,word,vector):
    self.word = word
    self.vector = vector
    
#return token -> token_embedding as pairs.    
#since XLNet use SentencePiece tokenizer
def get_embeddings_as_pair(tokenizer_,model_,sentence,embeddings,id_to_token):
  embeddings_pair = []
  for i in range(embeddings.squeeze().shape[0]):
    word = tokenizer.convert_tokens_to_string(id_to_token[i])
    vector = embeddings.squeeze()[i]
    embed = EmbeddingPair(word , vector)
    embeddings_pair.append( embed )

  return embeddings_pair


#given a sentence only return the embeddings of specified word
#just my utility method for easy visualization
#if input sentence : "i eat apple"
# we get a tokenizer as below :
#['▁', 'i', '▁eat', '▁apple', '<sep>', '<cls>']
def get_word_embeddings(tokenizer_,model_,sentence,keyword):
  outputs = get_output(tokenizer_,model_,sentence)
  inputs = tokenizer(sentence, return_tensors="pt",add_special_tokens=True) 
  id_to_token = tokenizer.convert_ids_to_tokens( inputs['input_ids'].squeeze() )
  tokens_to_string = tokenizer.convert_tokens_to_string(id_to_token)
  last_hidden_states = outputs["last_hidden_state"]
  
  embeddings_as_pairs = get_embeddings_as_pair(tokenizer_,model_,sentence,last_hidden_states,id_to_token)
  word_embeddings = []
  for pair in embeddings_as_pairs:
    if pair.word.endswith( keyword ) :
      word_embeddings.append( pair )
  return word_embeddings  

def get_similarity(vector1,vector2):
  return 1 - cosine(vector1, vector2)

# %%
tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased') 
print(tokenizer)
model = XLNetModel.from_pretrained('xlnet-base-cased')
# Out:
# PreTrainedTokenizer(name_or_path='xlnet-base-cased', vocab_size=32000, model_max_len=1000000000000000019884624838656, is_fast=False, padding_side='left', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '<sep>', 'pad_token': '<pad>', 'cls_token': '<cls>', 'mask_token': '<mask>', 'additional_special_tokens': ['<eop>', '<eod>']})

# %%
#XLNet uses a SentencePiece tokenizer which splits the words into subword units. 
#"i eat apple"  sentence will be tokenized as:
#'▁', 'i', '▁eat', '▁apple', '<sep>', '<cls>'
#Below is one cycle of getting embedding
inputs = tokenizer("i eat apple", return_tensors="pt",add_special_tokens=True)
print("inputs vectors :",inputs)
outputs = model(**inputs,mems=None,return_dict=True)
print( "output dictionary keys : ", outputs.keys())
print("last hidden state :",outputs["last_hidden_state"].shape)
print("[CLS]",outputs[0][:, -1].shape)
print("input_ids tokens ",inputs['input_ids'])
id_to_token = tokenizer.convert_ids_to_tokens( inputs['input_ids'].squeeze() )
print("id -> token",id_to_token)
tokens_to_string = tokenizer.convert_tokens_to_string(id_to_token)
print("tokens : ",tokens_to_string)

last_hidden_states = outputs["last_hidden_state"]
for i in range(last_hidden_states.squeeze().shape[0]):
    print(tokenizer.convert_tokens_to_string(id_to_token[i]), "->" ,last_hidden_states.squeeze()[i].shape)
    

#uncomment if you want see mems.
#print("mems",len ( outputs["mems"]) )
#for i in range( len ( outputs["mems"]) ):
#    print( outputs["mems"][i].shape )
# Out:
# inputs vectors : {'input_ids': tensor([[   17,   150,  2514, 10782,     4,     3]]), 'token_type_ids': tensor([[0, 0, 0, 0, 0, 2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
# output dictionary keys :  odict_keys(['last_hidden_state', 'mems'])
# last hidden state : torch.Size([1, 6, 768])
# [CLS] torch.Size([1, 768])
# input_ids tokens  tensor([[   17,   150,  2514, 10782,     4,     3]])
# id -> token ['▁', 'i', '▁eat', '▁apple', '<sep>', '<cls>']
# tokens :  i eat apple<sep><cls>
#  -> torch.Size([768])
# i -> torch.Size([768])
# eat -> torch.Size([768])
# apple -> torch.Size([768])
# <sep> -> torch.Size([768])
# <cls> -> torch.Size([768])

# %%
sentences = [ 
    "the shop is at right",   
"they turned to right",
"he was walking in streets realized a shop at right",   
"they passed street school was at right",
"he was walking in streets and having leisure by checking shops he realized a shop at right",   
"when he checks map he realized he will drive for 1 hour and stop at right of market",
"they passed the street they were not sure what they were doing the school was at right",
"the lion suddenly began to run to right for catching deer",
"turn left walk straight then turn right you will see school",
"he was using his right arm for daily works left arm for tennis",
"i have the right to enter library",
"he still have the right to enter library",
"as i valid passport holder i have the right to enter",
"i think even if he leaves school he must still have the right to enter library",
"as i valid passport holder i have the right to enter that country as much as i want",
"even they are divorced he has the right to see his children",
"human right is the difference between developed and undeveloped countries",
"You're right to be annoyed for bad behavior",
"She campaigned for women's right in her country",
"Everyone has a right to get education",
"for difficult question he gave right answer",
"for complicated problems he gave right decision",
"he skipped some questions but gave right answer",
"they finally came up with right decision",
"he skipped some questions he was so excited at the interview but at the end he gave right answer",
"after lots of discussion everyone believed they finally came up with right decision",
"this is not the right attitude for talking with children when they make a mistake",
"every problem is unique so right approach depends on complexity of problem",
"although he deserved to be fired this was the right way to do so",
"he is not the right person to ask this question"
]

# %%
#1)Get [CLS] as sentence embedding
outputs = [ get_sentence_output(tokenizer,model,s).detach().numpy() for s in sentences]
_ = dump_on_surface(outputs,sentences,fitting="tsne",dump_3d=False,dump_2d=True,
                    color_by="index10",title="Sentence by [CLS]")

# %%
#1)Get mean as sentence embedding
outputs = [ get_sentence_output_bymean(tokenizer,model,s).detach().numpy() for s in sentences]
_ = dump_on_surface(outputs,sentences,fitting="tsne",dump_3d=False,dump_2d=True,
                    color_by="index10",title="Sentence by mean")

# %%
#given sentences,and keywords , get embedding of word in that sentence
#and then reduce the dimension by fitting method(PCA,TSNE or both)
def reduce_dim_draw(sample_sentences,keywords,tokenizer_,model_,fitting="pca",color_by="other"):
    filtered_sentences = []
    word_embeddings = []
    for sent in sample_sentences:
        for keyword in keywords:
            if sent.find(keyword) > -1 :                
                #filtered_sentences.append( sent )
                v = get_word_embeddings(tokenizer_,model_,sent,keyword)[0].vector.detach().numpy()
                word_embeddings.append( v )
                filtered_sentences.append( sent )
    
    word_embeddings = np.array( word_embeddings )
    
    x_reduced = dump_on_surface(word_embeddings,filtered_sentences,dump_3d=False,fitting=fitting,color_by=color_by)
    
    return word_embeddings,filtered_sentences,x_reduced

#given a set of embeddings, calculate cosine of every sentences with each other
def draw_inner_cosine(word_embeddings_,sentences_):
    comparisions = []
    for i in range(len(word_embeddings_)):
        comparision_row = []
        for j in range(len(word_embeddings_)):
            sim = get_similarity(word_embeddings_[i],word_embeddings_[j])
            comparision_row.append(sim)
        comparisions.append( comparision_row )       
    pd.options.display.float_format = '{:,.3f}'.format
    cm = sns.light_palette("blue", as_cmap=True)
    df_eat = pd.DataFrame(data=comparisions ,index=sentences_,columns=sentences_)
    styled_df_eat = df_eat.style.background_gradient(cmap=cm).set_precision(3)
    return styled_df_eat

# %%
#first get an embedding of word "right" on short sentences
right_sentences_short = [ 
"he send ball with right hand",       
"they turned to right",
"as manager he has right to fire anyone",
"he has right to keep silent",
"he gave right answer",
"he gave right decision"]
keywords = ["right"]

word_embeddings,_,x_reduced  = reduce_dim_draw( right_sentences_short,keywords ,tokenizer,model)
df = draw_inner_cosine(x_reduced ,right_sentences_short)
display( df )
# Out:
# <style  type="text/css" >
# #T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col0,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col1,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col2,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col3,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row4_col4,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col1{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col2,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col3,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col5,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col4,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col0,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row5_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col4{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col5{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col0{
#             background-color:  #3636fc;
#             color:  #f1f1f1;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col2{
#             background-color:  #8f8ff8;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col3{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col4{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col0{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col1{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col3,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col2{
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col5{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col1{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col4{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col5{
#             background-color:  #a2a2f7;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row4_col0{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row4_col1{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row4_col2{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row4_col3{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row4_col5,#T_7003feb4_6854_11eb_bf19_c49ded8dff66row5_col4{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row5_col0{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row5_col2{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_7003feb4_6854_11eb_bf19_c49ded8dff66row5_col3{
#             background-color:  #9797f7;
#             color:  #000000;
#         }</style><table id="T_7003feb4_6854_11eb_bf19_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >he send ball with right hand</th>        <th class="col_heading level0 col1" >they turned to right</th>        <th class="col_heading level0 col2" >as manager he has right to fire anyone</th>        <th class="col_heading level0 col3" >he has right to keep silent</th>        <th class="col_heading level0 col4" >he gave right answer</th>        <th class="col_heading level0 col5" >he gave right decision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7003feb4_6854_11eb_bf19_c49ded8dff66level0_row0" class="row_heading level0 row0" >he send ball with right hand</th>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col1" class="data row0 col1" >0.561</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col2" class="data row0 col2" >-0.895</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col3" class="data row0 col3" >-0.970</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col4" class="data row0 col4" >0.474</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row0_col5" class="data row0 col5" >-0.012</td>
#             </tr>
#             <tr>
#                         <th id="T_7003feb4_6854_11eb_bf19_c49ded8dff66level0_row1" class="row_heading level0 row1" >they turned to right</th>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col0" class="data row1 col0" >0.561</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col2" class="data row1 col2" >-0.132</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col3" class="data row1 col3" >-0.343</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col4" class="data row1 col4" >-0.463</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row1_col5" class="data row1 col5" >-0.834</td>
#             </tr>
#             <tr>
#                         <th id="T_7003feb4_6854_11eb_bf19_c49ded8dff66level0_row2" class="row_heading level0 row2" >as manager he has right to fire anyone</th>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col0" class="data row2 col0" >-0.895</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col1" class="data row2 col1" >-0.132</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col3" class="data row2 col3" >0.977</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col4" class="data row2 col4" >-0.818</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row2_col5" class="data row2 col5" >-0.437</td>
#             </tr>
#             <tr>
#                         <th id="T_7003feb4_6854_11eb_bf19_c49ded8dff66level0_row3" class="row_heading level0 row3" >he has right to keep silent</th>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col0" class="data row3 col0" >-0.970</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col1" class="data row3 col1" >-0.343</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col2" class="data row3 col2" >0.977</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col4" class="data row3 col4" >-0.674</td>
#                         <td id="T_7003feb4_6854_11eb_bf19_c49ded8dff66row3_col5" class="data row3 col5" >-0.232</td>
#             </tr>
#             <tr>
#                         <th id="T_7003feb4_6854_11eb_bf19_c49ded8dff66level0_row4" class="row_heading level0 row4" >he gave right answer</th>

# %%
#lets add some more content,make sentence a little bit longer
#get an embedding of word "right" on medium size sentences
right_sentences_medium = [ 
"he send ball with right hand at the end of fast break",       
"they turned to right after passing school",
"as manager he has right to fire anyone in this company",
"he has right to keep silent in the court",
"he skipped some questions but gave right answer",
"they finally came up with right decision"]
keywords = ["right"]

word_embeddings,_,x_reduced  = reduce_dim_draw( right_sentences_medium,keywords ,tokenizer,model)
df = draw_inner_cosine(x_reduced ,right_sentences_medium)
display( df )
# Out:
# <style  type="text/css" >
# #T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col0,#T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col5,#T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col1,#T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col2,#T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col3,#T_70810e98_6854_11eb_bda8_c49ded8dff66row4_col4,#T_70810e98_6854_11eb_bda8_c49ded8dff66row5_col0,#T_70810e98_6854_11eb_bda8_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col1{
#             background-color:  #0909ff;
#             color:  #f1f1f1;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col2{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col3{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col4{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col0,#T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col3,#T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col2{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col2{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col3{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col4,#T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col0,#T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col5,#T_70810e98_6854_11eb_bda8_c49ded8dff66row4_col1,#T_70810e98_6854_11eb_bda8_c49ded8dff66row5_col2,#T_70810e98_6854_11eb_bda8_c49ded8dff66row5_col3{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col5{
#             background-color:  #0a0afe;
#             color:  #f1f1f1;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col1{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col4{
#             background-color:  #6d6df9;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col0{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col1{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col4{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col5{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row4_col0{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row4_col2{
#             background-color:  #6565fa;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row4_col3{
#             background-color:  #9e9ef7;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row4_col5{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row5_col1{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_70810e98_6854_11eb_bda8_c49ded8dff66row5_col4{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }</style><table id="T_70810e98_6854_11eb_bda8_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >he send ball with right hand at the end of fast break</th>        <th class="col_heading level0 col1" >they turned to right after passing school</th>        <th class="col_heading level0 col2" >as manager he has right to fire anyone in this company</th>        <th class="col_heading level0 col3" >he has right to keep silent in the court</th>        <th class="col_heading level0 col4" >he skipped some questions but gave right answer</th>        <th class="col_heading level0 col5" >they finally came up with right decision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70810e98_6854_11eb_bda8_c49ded8dff66level0_row0" class="row_heading level0 row0" >he send ball with right hand at the end of fast break</th>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col1" class="data row0 col1" >0.926</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col2" class="data row0 col2" >-0.934</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col3" class="data row0 col3" >-0.753</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col4" class="data row0 col4" >-0.520</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row0_col5" class="data row0 col5" >0.999</td>
#             </tr>
#             <tr>
#                         <th id="T_70810e98_6854_11eb_bda8_c49ded8dff66level0_row1" class="row_heading level0 row1" >they turned to right after passing school</th>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col0" class="data row1 col0" >0.926</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col2" class="data row1 col2" >-0.730</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col3" class="data row1 col3" >-0.448</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col4" class="data row1 col4" >-0.804</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row1_col5" class="data row1 col5" >0.909</td>
#             </tr>
#             <tr>
#                         <th id="T_70810e98_6854_11eb_bda8_c49ded8dff66level0_row2" class="row_heading level0 row2" >as manager he has right to fire anyone in this company</th>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col0" class="data row2 col0" >-0.934</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col1" class="data row2 col1" >-0.730</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col3" class="data row2 col3" >0.938</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col4" class="data row2 col4" >0.181</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row2_col5" class="data row2 col5" >-0.948</td>
#             </tr>
#             <tr>
#                         <th id="T_70810e98_6854_11eb_bda8_c49ded8dff66level0_row3" class="row_heading level0 row3" >he has right to keep silent in the court</th>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col0" class="data row3 col0" >-0.753</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col1" class="data row3 col1" >-0.448</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col2" class="data row3 col2" >0.938</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col4" class="data row3 col4" >-0.171</td>
#                         <td id="T_70810e98_6854_11eb_bda8_c49ded8dff66row3_col5" class="data row3 col5" >-0.779</td>
#             </tr>
#             <tr>
#                         <th id="T_70810e98_6854_11eb_bda8_c49ded8dff66level0_row4" class="row_heading level0 row4" >he skipp

# %%
#lets add some more and MORE content,make sentences  longer
#get an embedding of word "right" on long size sentences,
#see how embeddings changed too much
right_sentences_long = [ 
"at the final match he send ball with right hand at the end of fast break",       
"after crossing the bridge  they turned to right before final destination",
"as manager he has right to fire anyone in this company without asking the owner",
"he has the right to keep silent in the court even he is known to be guilty",
"after thinking too much he skipped some questions but gave right answer",
"they fight fiercely  and they finally came up with right decision"]
keywords = ["right"]

word_embeddings,_,x_reduced  = reduce_dim_draw( right_sentences_long,keywords ,tokenizer,model)
df = draw_inner_cosine(x_reduced ,right_sentences_long)
display( df )
# Out:
# <style  type="text/css" >
# #T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col0,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col1,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col2,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col3,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row4_col4,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col1,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col0,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col5,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col4,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row4_col3,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row5_col2{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col2{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col3,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col0{
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col4{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col5,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row5_col0{
#             background-color:  #1717fe;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col2{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col3,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row5_col1{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col4,#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row4_col1{
#             background-color:  #1f1ffd;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col0{
#             background-color:  #9e9ef7;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col1{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col3{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col4{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col5{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col1{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col2{
#             background-color:  #9595f7;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col5{
#             background-color:  #2727fd;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row4_col0{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row4_col2{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row4_col5{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row5_col3{
#             background-color:  #2626fd;
#             color:  #f1f1f1;
#         }#T_710aa0e2_6854_11eb_9efb_c49ded8dff66row5_col4{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }</style><table id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >at the final match he send ball with right hand at the end of fast break</th>        <th class="col_heading level0 col1" >after crossing the bridge  they turned to right before final destination</th>        <th class="col_heading level0 col2" >as manager he has right to fire anyone in this company without asking the owner</th>        <th class="col_heading level0 col3" >he has the right to keep silent in the court even he is known to be guilty</th>        <th class="col_heading level0 col4" >after thinking too much he skipped some questions but gave right answer</th>        <th class="col_heading level0 col5" >they fight fiercely  and they finally came up with right decision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66level0_row0" class="row_heading level0 row0" >at the final match he send ball with right hand at the end of fast break</th>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col1" class="data row0 col1" >-0.972</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col2" class="data row0 col2" >-0.299</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col3" class="data row0 col3" >0.983</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col4" class="data row0 col4" >-0.880</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row0_col5" class="data row0 col5" >0.813</td>
#             </tr>
#             <tr>
#                         <th id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66level0_row1" class="row_heading level0 row1" >after crossing the bridge  they turned to right before final destination</th>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col0" class="data row1 col0" >-0.972</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col2" class="data row1 col2" >0.515</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col3" class="data row1 col3" >-0.911</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col4" class="data row1 col4" >0.744</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row1_col5" class="data row1 col5" >-0.927</td>
#             </tr>
#             <tr>
#                         <th id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66level0_row2" class="row_heading level0 row2" >as manager he has right to fire anyone in this company without asking the owner</th>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col0" class="data row2 col0" >-0.299</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col1" class="data row2 col1" >0.515</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col3" class="data row2 col3" >-0.116</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col4" class="data row2 col4" >-0.190</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row2_col5" class="data row2 col5" >-0.798</td>
#             </tr>
#             <tr>
#                         <th id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66level0_row3" class="row_heading level0 row3" >he has the right to keep silent in the court even he is known to be guilty</th>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col0" class="data row3 col0" >0.983</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col1" class="data row3 col1" >-0.911</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col2" class="data row3 col2" >-0.116</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_710aa0e2_6854_11eb_9efb_c49ded8dff66row3_col4" class="data row3 col4" >-0.953</td>

# %%
#also combine all sentences and check how does it look like when plotted together
right_sentences = right_sentences_short + right_sentences_medium + right_sentences_long

keyword = ["right"]

word_embeddings,_,x_reduced = reduce_dim_draw( right_sentences,keyword ,tokenizer,model)

draw_inner_cosine(x_reduced,right_sentences)
# Out:
# <style  type="text/css" >
# #T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col17,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col1,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col13,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row2_col2,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row3_col3,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row4_col4,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row4_col17,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col8,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row9_col9,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row9_col14,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row10_col10,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row12_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row12_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row12_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row12_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row12_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row13_col1,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row13_col13,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row14_col9,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row14_col14,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row15_col15,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row16_col16,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row17_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row17_col4,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row17_col17{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col1{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col2{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col3{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col4,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row2_col3,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row3_col2,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row4_col0{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col0{
#             background-color:  #0d0dfe;
#             color:  #f1f1f1;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col0{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col10,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row10_col1,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row15_col3{
#             background-color:  #1313fe;
#             color:  #f1f1f1;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col8,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row4_col14,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col13,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col13,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col1,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row9_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row13_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row14_col4,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row14_col17,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row15_col10,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row17_col9,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row17_col14{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col9,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col14,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row3_col10,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row4_col8,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col13,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col4,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col17,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row10_col2,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row10_col3,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row13_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row13_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row13_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row13_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row14_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row15_col1,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row15_col16,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row16_col15,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row17_col8{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col10{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col11,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col12,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col17,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row12_col0,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row17_col7{
#             background-color:  #0c0cfe;
#             color:  #f1f1f1;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col13,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col4,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row2_col16{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col15,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row3_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row7_col3,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row15_col0{
#             background-color:  #4848fb;
#             color:  #f1f1f1;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row0_col16,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row16_col0{
#             background-color:  #ababf6;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col0{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col2{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col3{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col5,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row5_col8,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row9_col4,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row12_col8{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col15,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row4_col9,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row8_col6,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row9_col17,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col8{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_724f63ae_6854_11eb_96e4_c49ded8dff66row1_col7,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row6_col1,#T_724f63ae_6854_11eb_96e4_c49ded8dff66row11_col13,#T_724f63ae_6854_11eb_96e4_

# %%
#utility methods for creating dataframe        

def get_df():
    df = pd.DataFrame()
    df["Sentence"] = sentences
    df["Group"] = [ (index // 10) for index,s in enumerate(sentences) ]
    return df

# %%
input_df = None
CLASS_NUMS = None
MAX_LEN = 8

input_df = get_df()
CLASS_NUMS = 3


input_df.head(40)
# Out:
#                                              Sentence  Group
# 0                                the shop is at right      0
# 1                                they turned to right      0
# 2   he was walking in streets realized a shop at r...      0
# 3              they passed street school was at right      0
# 4   he was walking in streets and having leisure b...      0
# 5   when he checks map he realized he will drive f...      0
# 6   they passed the street they were not sure what...      0
# 7   the lion suddenly began to run to right for ca...      0
# 8   turn left walk straight then turn right you wi...      0
# 9   he was using his right arm for daily works lef...      0
# 10                  i have the right to enter library      1
# 11           he still have the right to enter library      1
# 12  as i valid passport holder i have the right to...      1
# 13  i think even if he leaves school he must still...      1
# 14  as i valid passport holder i have the right to...      1
# 15  even they are divorced he has the right to see...      1
# 16  human right is the difference between develope...      1
# 17        You're right to be annoyed for bad behavior      1
# 18    She campaigned for women's right in her country      1
# 19              Everyone has a right to get education      1
# 20        for difficult question he gave right answer      2
# 21    for complicated problems he gave right decision      2
# 22    he skipped some questions but gave right answer      2
# 23           they finally came up with right decision      2
# 24  he skipped some questions he was so excited at...      2
# 25  after lots of discussion everyone believed the...      2
# 26  this is not the right attitude for talking wit...      2
# 27  every problem is unique so right approach depe...      2
# 28  although he deserved to be fired this was the ...      2
# 29    he is not the right person to ask this question      2

# %%
#create a new XLNet model which will be trained(weights will be altered)
xlnet_tokenizer  = XLNetTokenizer.from_pretrained('xlnet-base-cased') 
xlnet_model = XLNetModel.from_pretrained('xlnet-base-cased')

# %%
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler

class SentimentData(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.text = dataframe["Sentence"]
        self.targets = dataframe["Group"]
        self.max_len = max_len

    def __len__(self):
        return len(self.text)

    def __getitem__(self, index):
        text = str(self.text[index])
        target = self.targets[index]

        return text,target

# %%
training_set = SentimentData(input_df, tokenizer, MAX_LEN)
#My dataset is small, I am doing only for visualizing so I dont use test set
train_params = {'batch_size': 4,'shuffle': True}
training_loader = DataLoader(training_set, **train_params)

# %%
class XLNETClassifier(torch.nn.Module):
    def __init__(self,nn_tokenizer,nn_model):
        super(XLNETClassifier, self).__init__()
        nn_model.train()
        self.nn_model = nn_model 
        self.nn_tokenizer = nn_tokenizer
        self.classifier = torch.nn.Linear(768, CLASS_NUMS)

    def forward(self, sentence_list):
        embeddings = [get_word_embeddings(self.nn_tokenizer,self.nn_model,s,"right")[0].vector for s in sentence_list ]        
        embedding_vector = torch.stack(embeddings)
                
        relu_output = torch.nn.ReLU()(embedding_vector)                
        output = self.classifier(relu_output)
        return output

# %%
#train Classfier network
def train(epoch):

    correct_predictions = 0
    classfier.train()
    for _,data in tqdm(enumerate(training_loader, 0)):
        #get data and labels
        sentence_batch = data[0]
        targets = data[1].to(device, dtype = torch.long)
        #call network forward and calculate loss
        outputs = classfier(sentence_batch)
        loss = loss_function(outputs, targets)
        #get predictions and compare with actual        
        _, predicted_groups = torch.max(outputs.data, dim=1)        
        correct_predictions += (predicted_groups  == targets).sum().item()
            
        #do back propagation    
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    epoch_accu = int( ( correct_predictions * 100 )/len(sentences) )        

    return epoch_accu

# %%
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
classfier = XLNETClassifier(xlnet_tokenizer,xlnet_model)
xlnet_model.train()
_ = classfier.to(device)

# %%
classfier
# Out:
# XLNETClassifier(
#   (nn_model): XLNetModel(
#     (word_embedding): Embedding(32000, 768)
#     (layer): ModuleList(
#       (0): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (3): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (4): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (5): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (6): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (7): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (8): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (9): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (10): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (11): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
pytorch_total_params = sum(p.numel() for p in classfier.parameters() if p.requires_grad)    
pytorch_trainable_params = sum(p.numel() for p in classfier.parameters() )    
print("Total number of params", pytorch_total_params)
print("Total number of trainable params", pytorch_trainable_params)
# Out:
# Total number of params 116720643
# Total number of trainable params 116720643

# %%
from tqdm import tqdm

# Creating the loss function and optimizer
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params =  classfier.parameters(), lr=1e-05)

EPOCHS = 14
for epoch in range(EPOCHS):
    epoch_accu = train(epoch)
    print(f"At Epoch {epoch+1}  Accuracy : {epoch_accu}")
    if epoch_accu > 93:
        break
# Out:
# 8it [00:31,  3.95s/it]
# 0it [00:00, ?it/s]
# At Epoch 1  Accuracy : 33
# 8it [00:34,  4.26s/it]
# 0it [00:00, ?it/s]
# At Epoch 2  Accuracy : 46
# 8it [00:35,  4.40s/it]
# 0it [00:00, ?it/s]
# At Epoch 3  Accuracy : 56
# 8it [00:35,  4.38s/it]
# 0it [00:00, ?it/s]
# At Epoch 4  Accuracy : 73
# 8it [00:36,  4.55s/it]
# 0it [00:00, ?it/s]
# At Epoch 5  Accuracy : 80
# 8it [00:36,  4.53s/it]
# 0it [00:00, ?it/s]
# At Epoch 6  Accuracy : 93
# 8it [00:38,  4.85s/it]
# 0it [00:00, ?it/s]
# At Epoch 7  Accuracy : 90
# 8it [00:41,  5.22s/it]
# 0it [00:00, ?it/s]
# At Epoch 8  Accuracy : 93
# 8it [00:48,  6.05s/it]
# At Epoch 9  Accuracy : 100

# %%
#put XLNet trained model into eval mode
_ = xlnet_model.eval()

# %%
#TRY AND COMPARE EVERYTHING DONE BEFORE WITH TRAINED XLNET
#COMPARE THE RESULTS OF CELLS BELOW THIS CELL WITH ONES ABOVE THIS CELL

# %%
outputs = [ get_word_embeddings(xlnet_tokenizer,xlnet_model,s,"right")[0].vector.detach().numpy() for s in sentences]
_ = dump_on_surface(outputs,sentences,fitting="pca",dump_3d=False,dump_2d=True,color_by="index10",
                    title="Sentence by CLS")

# %%
#1)Get Poolmean as sentence embedding
outputs = [ get_sentence_output_bymean(tokenizer,model,s).detach().numpy() for s in sentences]
_ = dump_on_surface(outputs,sentences,fitting="pca",dump_3d=False,dump_2d=True,
                    color_by="index10",title="Sentence by Mean")

# %%
#1)Get CLS as sentence embedding
outputs = [ get_sentence_output(xlnet_tokenizer,xlnet_model,s).detach().numpy() for s in sentences]
_ = dump_on_surface(outputs,sentences,fitting="pca",dump_3d=False,dump_2d=True,color_by="index10",title="Sentence by CLS")

# %%
right_sentences_short = [ 
"he send ball with right hand",       
"they turned to right",
"as manager he has right to fire anyone",
"he has right to keep silent",
"he gave right answer",
"he gave right decision"]
keywords = ["right"]

word_embeddings,_,x_reduced  = reduce_dim_draw( right_sentences_short,keywords ,xlnet_tokenizer,xlnet_model)
df = draw_inner_cosine(x_reduced ,right_sentences_short)
display( df )
# Out:
# <style  type="text/css" >
# #T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col0,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col1,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col2,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col3,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row4_col4,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row4_col5,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row5_col4,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col1{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col2{
#             background-color:  #7a7af9;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col3,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col4,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col5,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col0,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row4_col2,#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row5_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col4{
#             background-color:  #d7d7f4;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col5{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col0{
#             background-color:  #0c0cfe;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col2{
#             background-color:  #3f3ffc;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col3{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col0{
#             background-color:  #6e6ef9;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col1{
#             background-color:  #3838fc;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col3{
#             background-color:  #5959fa;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col5{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col2{
#             background-color:  #6262fa;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col4{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col5{
#             background-color:  #4141fc;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row4_col0{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row4_col1{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row4_col3{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row5_col0{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row5_col2{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row5_col3{
#             background-color:  #4343fc;
#             color:  #f1f1f1;
#         }</style><table id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >he send ball with right hand</th>        <th class="col_heading level0 col1" >they turned to right</th>        <th class="col_heading level0 col2" >as manager he has right to fire anyone</th>        <th class="col_heading level0 col3" >he has right to keep silent</th>        <th class="col_heading level0 col4" >he gave right answer</th>        <th class="col_heading level0 col5" >he gave right decision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66level0_row0" class="row_heading level0 row0" >he send ball with right hand</th>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col1" class="data row0 col1" >0.900</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col2" class="data row0 col2" >0.120</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col3" class="data row0 col3" >-0.915</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col4" class="data row0 col4" >-0.752</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row0_col5" class="data row0 col5" >-0.783</td>
#             </tr>
#             <tr>
#                         <th id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66level0_row1" class="row_heading level0 row1" >they turned to right</th>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col0" class="data row1 col0" >0.900</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col2" class="data row1 col2" >0.541</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col3" class="data row1 col3" >-0.647</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col4" class="data row1 col4" >-0.964</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row1_col5" class="data row1 col5" >-0.976</td>
#             </tr>
#             <tr>
#                         <th id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66level0_row2" class="row_heading level0 row2" >as manager he has right to fire anyone</th>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col0" class="data row2 col0" >0.120</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col1" class="data row2 col1" >0.541</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col3" class="data row2 col3" >0.291</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col4" class="data row2 col4" >-0.745</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row2_col5" class="data row2 col5" >-0.711</td>
#             </tr>
#             <tr>
#                         <th id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66level0_row3" class="row_heading level0 row3" >he has right to keep silent</th>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col0" class="data row3 col0" >-0.915</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col1" class="data row3 col1" >-0.647</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col2" class="data row3 col2" >0.291</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col4" class="data row3 col4" >0.422</td>
#                         <td id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66row3_col5" class="data row3 col5" >0.465</td>
#             </tr>
#             <tr>
#                         <th id="T_486cfdb6_6855_11eb_9cf4_c49ded8dff66level0_row4" class="row_heading level0 row4" >he gave right answer</th>

# %%
right_sentences_medium = [ 
"he send ball with right hand at the end of fast break",       
"they turned to right after passing school",
"as manager he has right to fire anyone in this company",
"he has right to keep silent in the court",
"he skipped some questions but gave right answer",
"they finally came up with right decision"]
keywords = ["right"]

word_embeddings,_,x_reduced  = reduce_dim_draw( right_sentences_medium,keywords ,xlnet_tokenizer,xlnet_model)
df = draw_inner_cosine(x_reduced ,right_sentences_medium)
display( df )
# Out:
# <style  type="text/css" >
# #T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col0,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col1,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col0,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col1,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col2,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col3,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row4_col4,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col2,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col0{
#             background-color:  #5a5afa;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col3,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col4,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col5,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row4_col0,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row4_col1,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row5_col2{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col4{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col5{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col2{
#             background-color:  #4c4cfb;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col3{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col5{
#             background-color:  #d4d4f4;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col1{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col3{
#             background-color:  #5d5dfa;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col4{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col0{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col1{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col2{
#             background-color:  #5959fa;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col4{
#             background-color:  #3535fc;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col5{
#             background-color:  #7272f9;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row4_col2,#T_491aba3a_6855_11eb_8c16_c49ded8dff66row5_col0{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row4_col3{
#             background-color:  #3939fc;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row4_col5{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row5_col1{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row5_col3{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_491aba3a_6855_11eb_8c16_c49ded8dff66row5_col4{
#             background-color:  #0f0ffe;
#             color:  #f1f1f1;
#         }</style><table id="T_491aba3a_6855_11eb_8c16_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >he send ball with right hand at the end of fast break</th>        <th class="col_heading level0 col1" >they turned to right after passing school</th>        <th class="col_heading level0 col2" >as manager he has right to fire anyone in this company</th>        <th class="col_heading level0 col3" >he has right to keep silent in the court</th>        <th class="col_heading level0 col4" >he skipped some questions but gave right answer</th>        <th class="col_heading level0 col5" >they finally came up with right decision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_491aba3a_6855_11eb_8c16_c49ded8dff66level0_row0" class="row_heading level0 row0" >he send ball with right hand at the end of fast break</th>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col1" class="data row0 col1" >0.994</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col2" class="data row0 col2" >0.281</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col3" class="data row0 col3" >-0.838</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col4" class="data row0 col4" >-0.925</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row0_col5" class="data row0 col5" >-0.617</td>
#             </tr>
#             <tr>
#                         <th id="T_491aba3a_6855_11eb_8c16_c49ded8dff66level0_row1" class="row_heading level0 row1" >they turned to right after passing school</th>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col0" class="data row1 col0" >0.994</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col2" class="data row1 col2" >0.388</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col3" class="data row1 col3" >-0.771</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col4" class="data row1 col4" >-0.962</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row1_col5" class="data row1 col5" >-0.702</td>
#             </tr>
#             <tr>
#                         <th id="T_491aba3a_6855_11eb_8c16_c49ded8dff66level0_row2" class="row_heading level0 row2" >as manager he has right to fire anyone in this company</th>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col0" class="data row2 col0" >0.281</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col1" class="data row2 col1" >0.388</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col3" class="data row2 col3" >0.288</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col4" class="data row2 col4" >-0.626</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row2_col5" class="data row2 col5" >-0.929</td>
#             </tr>
#             <tr>
#                         <th id="T_491aba3a_6855_11eb_8c16_c49ded8dff66level0_row3" class="row_heading level0 row3" >he has right to keep silent in the court</th>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col0" class="data row3 col0" >-0.838</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col1" class="data row3 col1" >-0.771</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col2" class="data row3 col2" >0.288</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col4" class="data row3 col4" >0.566</td>
#                         <td id="T_491aba3a_6855_11eb_8c16_c49ded8dff66row3_col5" class="data row3 col5" >0.087</td>
#             </tr>
#             <tr>
#                         <th id="T_491aba3a_6855_11eb_8c16_c49ded8dff66level0_row4" class="row_heading level0 row4" >he skipped

# %%
right_sentences_long = [ 
"at the final match he send ball with right hand at the end of fast break",       
"after choosing wrong way they turned to right after passing school",
"as manager he has right to fire anyone in this company without asking the owner",
"he has right to keep silent in the court even he is known to be guilty",
"after thinking too much he skipped some questions but gave right answer",
"they fight fiercely  and they finally came up with right decision"]

keywords = ["right"]

word_embeddings,_,x_reduced  = reduce_dim_draw( right_sentences_long,keywords ,xlnet_tokenizer,xlnet_model)
df = draw_inner_cosine(x_reduced ,right_sentences_long)
display( df )
# Out:
# <style  type="text/css" >
# #T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col0,#T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col1,#T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col2,#T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col3,#T_49d66a00_6855_11eb_a994_c49ded8dff66row4_col4,#T_49d66a00_6855_11eb_a994_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col1,#T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col0{
#             background-color:  #2727fd;
#             color:  #f1f1f1;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col2,#T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col0{
#             background-color:  #1919fe;
#             color:  #f1f1f1;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col3{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col4,#T_49d66a00_6855_11eb_a994_c49ded8dff66row4_col0{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col5,#T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col3,#T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col4,#T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col1,#T_49d66a00_6855_11eb_a994_c49ded8dff66row4_col2,#T_49d66a00_6855_11eb_a994_c49ded8dff66row5_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col2{
#             background-color:  #6e6ef9;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col4{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col5{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col1{
#             background-color:  #6c6cf9;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col3{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col5,#T_49d66a00_6855_11eb_a994_c49ded8dff66row5_col2{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col0{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col2{
#             background-color:  #8080f8;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col4{
#             background-color:  #5555fb;
#             color:  #f1f1f1;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col5{
#             background-color:  #4545fb;
#             color:  #f1f1f1;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row4_col1{
#             background-color:  #a3a3f7;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row4_col3{
#             background-color:  #5454fb;
#             color:  #f1f1f1;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row4_col5,#T_49d66a00_6855_11eb_a994_c49ded8dff66row5_col4{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row5_col1{
#             background-color:  #b2b2f6;
#             color:  #000000;
#         }#T_49d66a00_6855_11eb_a994_c49ded8dff66row5_col3{
#             background-color:  #4444fc;
#             color:  #f1f1f1;
#         }</style><table id="T_49d66a00_6855_11eb_a994_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >at the final match he send ball with right hand at the end of fast break</th>        <th class="col_heading level0 col1" >after choosing wrong way they turned to right after passing school</th>        <th class="col_heading level0 col2" >as manager he has right to fire anyone in this company without asking the owner</th>        <th class="col_heading level0 col3" >he has right to keep silent in the court even he is known to be guilty</th>        <th class="col_heading level0 col4" >after thinking too much he skipped some questions but gave right answer</th>        <th class="col_heading level0 col5" >they fight fiercely  and they finally came up with right decision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_49d66a00_6855_11eb_a994_c49ded8dff66level0_row0" class="row_heading level0 row0" >at the final match he send ball with right hand at the end of fast break</th>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col1" class="data row0 col1" >0.678</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col2" class="data row0 col2" >0.799</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col3" class="data row0 col3" >-0.639</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col4" class="data row0 col4" >-0.927</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row0_col5" class="data row0 col5" >-0.971</td>
#             </tr>
#             <tr>
#                         <th id="T_49d66a00_6855_11eb_a994_c49ded8dff66level0_row1" class="row_heading level0 row1" >after choosing wrong way they turned to right after passing school</th>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col0" class="data row1 col0" >0.678</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col2" class="data row1 col2" >0.099</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col3" class="data row1 col3" >-0.999</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col4" class="data row1 col4" >-0.351</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row1_col5" class="data row1 col5" >-0.482</td>
#             </tr>
#             <tr>
#                         <th id="T_49d66a00_6855_11eb_a994_c49ded8dff66level0_row2" class="row_heading level0 row2" >as manager he has right to fire anyone in this company without asking the owner</th>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col0" class="data row2 col0" >0.799</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col1" class="data row2 col1" >0.099</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col3" class="data row2 col3" >-0.047</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col4" class="data row2 col4" >-0.966</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row2_col5" class="data row2 col5" >-0.919</td>
#             </tr>
#             <tr>
#                         <th id="T_49d66a00_6855_11eb_a994_c49ded8dff66level0_row3" class="row_heading level0 row3" >he has right to keep silent in the court even he is known to be guilty</th>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col0" class="data row3 col0" >-0.639</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col1" class="data row3 col1" >-0.999</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col2" class="data row3 col2" >-0.047</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col4" class="data row3 col4" >0.302</td>
#                         <td id="T_49d66a00_6855_11eb_a994_c49ded8dff66row3_col5" class="data row3 col5" >0.4

# %%
right_sentences = right_sentences_short + right_sentences_medium + right_sentences_long

keyword = ["right"]

word_embeddings,_,x_reduced = reduce_dim_draw( right_sentences,keyword ,xlnet_tokenizer,xlnet_model,color_by="index6")

draw_inner_cosine(x_reduced,right_sentences)
# Out:
# <style  type="text/css" >
# #T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col0,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col1,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col12,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col2,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col8,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row3_col3,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row3_col9,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row3_col15,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row4_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row4_col5,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row4_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row4_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row4_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col5,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col6,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col12,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row7_col1,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row7_col6,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row7_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row7_col12,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row8_col2,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row8_col8,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row9_col3,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row9_col9,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row9_col15,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row10_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row10_col5,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row10_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row10_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row10_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row11_col11,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row12_col1,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row12_col6,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row12_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row12_col12,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row13_col13,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row14_col14,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row15_col3,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row15_col9,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row15_col15,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row17_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row17_col5,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row17_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row17_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row17_col17{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col1,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col0,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row8_col14,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row14_col8{
#             background-color:  #0a0afe;
#             color:  #f1f1f1;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col2,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col3{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col3,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row4_col14,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row17_col14{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col15,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col8{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col5,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row4_col0,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col2,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row17_col0{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col6,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col0{
#             background-color:  #0404ff;
#             color:  #f1f1f1;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col12,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row7_col0,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row11_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row12_col0,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row13_col0,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col11{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col8{
#             background-color:  #6f6ff9;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col9,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row6_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row14_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col12{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col11,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col13{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col13,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col14,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row14_col2{
#             background-color:  #0707ff;
#             color:  #f1f1f1;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col14,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col12,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row3_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row3_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row7_col2,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row12_col2{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col15,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row8_col11,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row16_col6{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row0_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row2_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row11_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row11_col12{
#             background-color:  #d4d4f4;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col2{
#             background-color:  #3434fc;
#             color:  #f1f1f1;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col3,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col8,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row8_col10{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col4,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col5,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col10,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row1_col17,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row3_col13,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col1,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col6,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col7,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row5_col12,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row9_col0,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row9_col13,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row11_col2,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row11_col8,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row11_col14,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row13_col3,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row13_col9,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row13_col15,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row14_col11,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row14_col16,#T_4bf5a080_6855_11eb_901b_c49ded8dff66row15_col0,#T_
